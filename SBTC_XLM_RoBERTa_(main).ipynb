# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import warnings
warnings.filterwarnings('ignore')

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
#!pip install keras
#!pip install --upgrade tensorflow
#!pip install --upgrade tensorflow-gpu
# !pip install xlrd==1.2.0
# !pip install openpyxl
# !pip install unidecode
# Out:
# Collecting xlrd==1.2.0
#   Downloading xlrd-1.2.0-py2.py3-none-any.whl (103 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.3/103.3 kB 12.5 MB/s eta 0:00:00
# Installing collected packages: xlrd
#   Attempting uninstall: xlrd
#     Found existing installation: xlrd 2.0.1
#     Uninstalling xlrd-2.0.1:
#       Successfully uninstalled xlrd-2.0.1
# Successfully installed xlrd-1.2.0
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.10/dist-packages (3.0.10)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl) (1.1.0)
# Collecting unidecode
#   Downloading Unidecode-1.3.6-py3-none-any.whl (235 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.9/235.9 kB 11.6 MB/s eta 0:00:00
# Installing collected packages: unidecode
# Successfully installed unidecode-1.3.6

# %%
import pandas as pd
from pandas import read_excel
import numpy as np
import re
from re import sub
import multiprocessing
from unidecode import unidecode
import os
from time import time
from collections import Counter

from sklearn import metrics
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import LSTM,Dense,Dropout,Activation,Embedding,Flatten,Bidirectional,MaxPooling2D, Conv1D, MaxPooling1D
from tensorflow.keras.models import Sequential

from tensorflow.keras.optimizers import SGD,Adam
from tensorflow.keras import regularizers

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical


import h5py
import csv
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import accuracy_score


from nltk.corpus import stopwords
import nltk
import re
from nltk.stem import WordNetLemmatizer
import string
from nltk.tokenize import word_tokenize
from nltk.util import ngrams

# %%
data = pd.read_csv('SBTC - Sheet1.csv')

# %%
print("Categories:")
print(data.final_label.unique())
category_list=data.final_label.unique()
# Out:
# Categories:
# ['Physics' 'Chemistry' 'Biology' 'ICT' 'Mathematics' 'Others']

# %%
def text_to_word_list(text):
    text = text.split()
    return text

def replace_strings(text):
    emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           u"\u00C0-\u017F"          #latin
                           u"\u2000-\u206F"          #generalPunctuations

                           "]+", flags=re.UNICODE)
    english_pattern=re.compile('[a-zA-Z0-9]+', flags=re.I)
    #latin_pattern=re.compile('[A-Za-z\u00C0-\u00D6\u00D8-\u00f6\u00f8-\u00ff\s]*',)

    text=emoji_pattern.sub(r'', text)
    text=english_pattern.sub(r'', text)
    text = re.sub(r'₀|₁|₂|₃|₄|₅|₆|₇|₈|₉', '', text)
    text = re.sub(r'⁰|¹|²|³|⁴|⁵|⁶|⁷|⁸|⁹|⁻|⁺|ⁿ|ᵗ', '', text)

    return text

def remove_punctuations(my_str):
    # define punctuation
    punctuations = '''````£|¢|Ñ+-*/=EROero৳০১২৩৪৫৬৭৮৯012–34567•89।!()-−[]{};:'"“\’,<>./?@#$%^&*_~‘—॥”‰θ→°π∈∝α≤≥Δβε≠�￰৷￰'''

    no_punct = ""
    for char in my_str:
        if char not in punctuations:
            no_punct = no_punct + char

    # display the unpunctuated string
    return no_punct



def joining(text):
    out=' '.join(text)
    return out

def preprocessing(text):
    out=remove_punctuations(replace_strings(text))
    return out

# %%
data['cleantext'] = data.text.apply(lambda x: preprocessing(str(x)))
# print some cleaned reviews from the dataset
sample_data = range(5000,6000)
for i in sample_data:
  print(data.cleantext[i])
# Out:
# সনাতন বা আদিম সমাজে মানুষের জীবনযাপন ছিল অত্যন্ত সহজ সরল
# খাবার দাবার কাপড় চোপড় এবং বাড়িঘর এসবই ছিল মানুষের মৌলিক চাহিদা
# মূলত মানুষের কায়িক পরিশ্রম ছিল উৎপাদনের একমাত্র উপকরণ
# দশে মিলে করি কাজ হারিজিতি নাহি লাজ এই ছিল আদিম সমাজের মূলমন্ত্র
# উৎপাদন ভোগ ও দৈনন্দিন সংসার পরিচালনার বিদ্যাকেই তখন অর্থনীতি বলা হতো
# প্রাচীন ভারতে চতুর্থ খ্রিষ্টপূর্বে কৌটিল্যের অর্থশাস্ত্রে বৃহত্তর পরিসরে সারা দেশের রাজনীতি সমাজ অর্থনীতি ও সামরিক বিষয়ের উপর আলোকপাত করা হয়
# দেশের ধনসম্পদ বৃদ্ধি রাষ্ট্রের ক্ষমতা বৃদ্ধি ও বাণিজ্য উদ্বৃত্তকরণের লক্ষ্যে ইংল্যান্ডের ব্যবসায়ীরা বেশি রপ্তানি করত এবং খুব সামান্যই আমদানি করত
# ইংল্যান্ডের উৎপাদিত পণ্য পৃথিবীর বিভিন্ন দেশে প্রচুর পরিমাণে রপ্তানি করে মূল্যবান ধাতু সোনা রূপা হীরা ইত্যাদি আমদানি করা হতো
# অষ্টাদশ শতাব্দীর মধ্যভাগে ফরাসিরা সে দেশের ধনী মানুষের বিলাসী জীবনযাপন অতিরিক্ত করারোপ এবং ইংল্যান্ডের বাণিজ্যবাদের বিপক্ষে অবস্থান নিয়ে ভূমিবাদ মতবাদ প্রচার করেন
# ভূমিবাদীদের মতে কৃষিই খনি ও মৎসক্ষেত্রসহ হলো উৎপাদনশীল খাত
# অন্যদিকে শিল্প ও বাণিজ্য উভয়ই অনুৎপাদনশীল খাত হিসেবে মনে করা হতো
# দুষ্প্রাপ্যতার জন্য মানুষ গুরুত্ব অনুযায়ী পছন্দ বা নির্বাচন করে
# অর্থনীতি শেখায় কীভাবে সীমিত সম্পদের সর্বোচ্চ সদ্ব্যবহার করা যেতে পারে
# যেকোনো দ্রব্য যেমন বই বা সেবাসামগ্রী চিকিৎসা সেবা উৎপাদন করতে সম্পদ দরকার হয়
# সীমিত সম্পদ দিয়ে সীমিত দ্রব্য বা সেবা পাওয়া সম্ভব
# অর্থনীতি এমন একটি বিজ্ঞান যা অসীম অভাব এবং বিকল্প ব্যবহারযোগ্য দুষ্প্রাপ্য সম্পদের মধ্যে সমন্বয় সাধনসংক্রান্ত মানবীয় আচরণ বিশ্লেষণ করে
# অর্থনীতিবিদ স্যামুয়েলসনের মতে সম্পদ সীমিত বলেই সমাজে সম্পদের সবচেয়ে ভালোভাবে ব্যবহারের প্রশ্নটি গুরুত্ব পায়
# যেহেতু মানুষের অভাব অনেক এবং সম্পদ সীমিত তাই সীমিত সম্পদ দিয়ে মানুষের সকল অভাব পূরণ হয় না
# অতিপ্রয়োজনীয় অভাবগুলো মানুষ অগ্রাধিকারভিত্তিতে পূরণ করে
# জ্ঞানবিজ্ঞানের উন্নতির সাথে অর্থনীতি বিষয়ের পরিধিও অনেক বেড়েছে
# অর্থনীতি মানবজীবনের সাধারণ কার্যাবলি আলোচনা করে
# অর্থনীতির মূল আলোচ্য বিষয় মানুষের অর্থ উপার্জন এবং অভাব মোচনের জন্য সেই অর্থের ব্যয়
# অর্থনীতির মূল উদ্দেশ্য হলো মানুষের কল্যাণ সাধন
# বর্তমানে সম্পদের স্বল্পতার সমস্যাই অর্থনীতির মূল সমস্যা
# মানুষের অভাব অসীম এবং অভাবের প্রকৃতি ও পরিমাণ বিভিন্ন রকমের
# অসীম অভাবকে কীভাবে সীমিত সম্পদ দ্বারা সমন্বয় সাধন করা যায় তা অর্থনীতির একটি গুরুত্বপূর্ণ আলোচনার বিষয়
# সম্পদের যোগান সীমিত বলে একই সম্পদ দ্বারা আমাদের বিভিন্ন অভাব পূরণের চেষ্টা করতে হয়
# অভাবের অগ্রাধিকারের ভিত্তিতে তা পূরণ করতে হয়
# মানুষ তার ব্যক্তিগত ও সামাজিক জীবনে এমন কিছু পছন্দ করে যা অর্থনীতিতে আলোচনা হয় না
# আমাদের সমাজে সম্পদ স্বল্পতার পরিপ্রেক্ষিতে অসীম অভাব মোকাবেলা করতে হয়
# সরকার যদি বাজেটে সামরিক খাতে বেশি ব্যয় করে তবে শিক্ষাখাতসহ অন্যান্য বেসামরিক খাতে ব্যয় কমাতে হবে
# সমাজে মানুষ সর্বদা একটি দেওয়ানেওয়ার নীতি মেনে চলেন
# প্রতিটি কাজের জন্য উৎসাহ বা প্রণোদনা গুরুত্বপূর্ণ ভূমিকা রাখে
# অর্থনীতিতে শ্রমিক প্রণোদনা পেলে বেশি উৎপাদন করে
# যুক্তরাষ্ট্র সস্তায় গাড়ি তৈরি করে তবে আমাদের রয়েছে সস্তায় পোশাক তৈরির সামর্থ
# অর্থনৈতিক কাজকর্ম সচরাচর সংগঠিত হয়ে থাকে বাজারব্যবস্থার মাধ্যমে
# ফার্মের মালিকরা বাজারের চাহিদা দেখে দ্রব্য সরবরাহ করে এবং অসংখ্য পরিবার তাদের আয় ও প্রয়োজন অনুসারে এ সমস্ত দ্রব্য ও সেবাসামগ্রী ক্রয় করে
# যেসব দেশের মানুষের দ্রব্য ও সেবা উৎপাদন করার ক্ষমতা বেশি তাদের জীবনযাত্রার মান উন্নত হয়
# মুদ্রা ছাপানোর ক্ষমতা কেন্দ্রীয় ব্যাংকের হাতে থাকে
# কেন্দ্রীয় ব্যাংক যদি অধিক মাত্রায় মুদ্রা ছাপায় তাহলে মুদ্রাস্ফীতি ঘটে অর্থাৎ দ্রব্যের মূল্যস্তর বাড়ে
# মুদ্রাস্ফীতি ঘটলে অর্থের মান বা মূল্য কমে যায়
# জিনিসের দাম বাড়ায় একই জিনিস কিনতে এখন বেশি মুদ্রা লাগবে
# দ্রব্যসামগ্রীর মূল্যস্তর বেড়ে যাওয়ার অবস্থাকে মুদ্রাস্ফীতি বলে
# কোনো শ্রমিক বাজার মজুরিতে কাজ করতে ইচ্ছুক কিন্তু কাজ পায় না এরা হলো বেকার
# সাধারণত অর্থনীতিতে মুদ্রাস্ফীতি কমলে বেকারত্ব বাড়ে
# মুদ্রাস্ফীতি বাড়লে বেকারত্ব কমে
# একটি সরল অর্থনীতিতে দুই ধরনের প্রতিনিধি থাকে
# ভোক্তা বা পরিবার এবং উৎপাদক বা ফার্ম
# অর্থনীতিতে দুধরনের প্রতিনিধি থাকে যথা ফার্মসমূহ ও পরিবারসমূহ
# ফার্ম বা ফার্মের মালিকরা উৎপাদনের উপাদানগুলো ক্রয় করেন
# পরিবারসমূহ তাদের আয়উপার্জনের সাহায্যে ফার্মের কাছ থেকে ক্রয় করেন দ্রব্য বা সেবা
# অর্থনীতি হচ্ছে চয়ন বা নির্বাচনের বিজ্ঞান
# বাজার পদ্ধতি বা ধনতান্ত্রিক পদ্ধতিতে সমস্ত সিদ্ধান্তই বাজারের যুক্তি অনুযায়ী নির্ধারিত হবে
# বাজারের আপেক্ষিক চাহিদাই নির্ধারণ করে দেবে উৎপাদনের বিন্যাস
# যে প্রযুক্তিতে একটি পণ্য তৈরি করার বাজার নির্ধারিত খরচ সর্বনিম্ন সে প্রযুক্তি ব্যবহার করেই ঐ পণ্য তৈরি হবে
# বাজারে যে উৎপাদন উপকরণের দাম যেরকম নির্ধারিত হবে তার মালিকরা ঠিক সেরকম আয় ও ভোগ করবেন
# ক্রেতাবিক্রেতা হচ্ছেন ব্যক্তিগতভাবে সমস্ত সম্পদের তথা উৎপাদন উপকরণের ব্যক্তি মালিক এবং বাজারে তাদের আন্তক্রিয়ার মাধ্যমেই এসবের দাম ও অন্য সবকিছু নির্ধারিত হয়
# নির্দেশমূলক পদ্ধতিতে কি উৎপাদন হবে তা নির্ধারণ করে দেয় কেন্দ্রীয় কর্তৃপক্ষ
# পৃথিবীতে কোনো কোনো প্রাচীন সমাজে যে আদিম অর্থনীতি রয়েছে সেখানে রাষ্ট্রীয় বা পরিকল্পনা কমিশন বা মুক্তবাজারের কোন শক্তিশালী উপস্থিতি নেই
# সেসব সমাজে ব্যক্তি সচরাচর ধর্মীয় মূল্যবোধ বা আবহমানকাল ধরে চলে আসা বাবাদাদাদের প্রথা অনুযায়ী অর্থনৈতিক সিদ্ধান্ত গ্রহণ ও পরিচালনা করেন
# আমাদের দেশে আদিবাসী জনগোষ্ঠীর অর্থনৈতিক ব্যবস্থা বা যুক্তরাষ্ট্রের আমিষ সম্প্রদায়ের অর্থনৈতিক ব্যবস্থা বা কোন কোন ইসলামি দেশে ইসলামি শরিয়া ভিত্তিক অর্থনৈতিক ব্যবস্থাকে আমরা এই ধরনের অর্থনৈতিক ব্যবস্থার অন্তর্ভুক্ত করতে পারি
# বর্তমান পৃথিবীতে মূলত বাজার ও পুঁজিবাদী অর্থনৈতিক ব্যবস্থা এবং কিছু কিছু দেশে সমাজতান্ত্রিক পরিকল্পিত অর্থনৈতিক ব্যবস্থা এবং ইরান ও সৌদি আরবসহ কয়েকটি দেশে ইসলামি অর্থনৈতিক ব্যবস্থা চালু রয়েছে বলে ধরা হয়
# পৃথিবীর সব অর্থনৈতিক ব্যবস্থাই শেষ বিচারে একটি মিশ্র ব্যবস্থা
# ধনতান্ত্রিক অর্থব্যবস্থায় উৎপাদনের উপাদানগুলো ব্যক্তিমালিকানাধীন এবং প্রধানত বেসরকারি উদ্যোগে সরকারি হস্তক্ষেপ ছাড়া স্বয়ংক্রিয় দামব্যবস্থার মাধ্যমে যাবতীয় অর্থনৈতিক কার্যক্রম পরিচালিত হয়
# অষ্টাদশ শতাব্দীর শেষভাগে ফরাসি বিপ্লবের মধ্য দিয়ে সমগ্র ইউরোপে ধনতান্ত্রিক অর্থনীতির সূত্রপাত ঘটে
# ধনতান্ত্রিক অর্থনীতিতে সমাজের অধিকাংশ সম্পদ বা উৎপাদনের উপকরণগুলো ব্যক্তিমালিকানায় থাকে
# ধনতন্ত্রে অধিকাংশ অর্থনৈতিক কর্মকাণ্ড যেমন উৎপাদন বিনিময় বণ্টন ভোগ প্রভৃতি ব্যক্তিগত উদ্যোগে পরিচালিত হয়
# ধনতান্ত্রিক অর্থব্যবস্থায় দ্রব্য ও সেবা উৎপাদনে প্রথমে অনেক ফার্ম অবাধে প্রতিযোগিতা করে
# বাজারে ক্রেতা ও বিক্রেতার দরকষাকষির মাধ্যমে দ্রব্যের দাম নির্ধারিত হয়
# ধনতন্ত্রে উৎপাদক সর্বোচ্চ মুনাফা অর্জনের জন্য উৎপাদন করে
# প্রত্যেক ভোক্তা তার নিজস্ব পছন্দ ইচ্ছা ও রুচি অনুযায়ী অবাধে দ্রব্য ক্রয় ও ভোগ করতে পারে
# ভোক্তার চাহিদা ও মুনাফার সুযোগ অনুযায়ী উৎপাদনকারী দ্রব্য সরবরাহ করে
# ধনতান্ত্রিক সমাজে বিত্তবান ও সাধারণ জনগণের আয়ের মধ্যে বৈষম্য বেশি থাকে  ধনতান্ত্রিক অর্থনীতিতে কিছুটা বেকারত্ব অনিবার্য
# ধনতান্ত্রিক অর্থব্যবস্থায় সরকার আইন শৃঙ্খলা রক্ষা দেশরক্ষা সম্পত্তির অধিকার রক্ষায় নিয়োজিত থাকে
# অর্থনীতির বিভিন্ন ক্ষেত্রে পারস্পরিক নির্ভরশীলতার মধ্য দিয়ে ধনতান্ত্রিক অর্থনীতির কার্যক্রম পরিচালিত হয়
# কেউ নিঃস্বার্থভাবে নয় বরং প্রত্যেকে নিজ নিজ স্বার্থে অর্থনৈতিক কার্যাবলি সম্পাদন করে
# সমাজতান্ত্রিক অর্থনীতিতে সমাজের অধিকাংশ সম্পদ ও উৎপাদনের উপাদানের উপর রাষ্ট্রের বা সমাজের মালিকানা প্রতিষ্ঠিত থাকে
# অধিকাংশ শিল্পকারখানা ও উৎপাদন প্রতিষ্ঠানের মালিক সরকার বা সমাজ এবং সেগুলো সরকারি বা সামাজিক নির্দেশে পরিচালিত হয়ে থাকে
# কোন কোন দ্রব্য কী পরিমাণে কীভাবে এবং কার জন্য উৎপাদিত হবে তা সরকার বা রাষ্ট্র নির্ধারণ করে
# সমাজতান্ত্রিক অর্থনীতিতে অধিকাংশ সম্পদ জমি কলকারখানা খনি ইত্যাদি ও উৎপাদনের উপাদানগুলোর মালিক হলো সরকার সমবায় প্রতিষ্ঠান যৌথ সামাজিক দল ইত্যাদি রাষ্ট্রের অধীনে কাজ করে থাকে
# রাষ্ট্র বা সরকার কেন্দ্রীয়ভাবে সকল পরিকল্পনা করে থাকে
# সমাজতন্ত্রে অধিকাংশ ক্ষেত্রে ভোক্তারা সরকার ও কেন্দ্রীয় পরিকল্পনা নির্ধারিত উৎপাদিত দ্রব্যাদি ভোগ করে থাকে
# কোনো ভোক্তা ইচ্ছাকৃত অর্থ ব্যয় করে বাজারকে প্রভাবিত করে কোনো কিছু উৎপাদন ও ভোগ করতে পারে না
# অধিকাংশ ক্ষেত্রে সরকারি উদ্যোগে উৎপাদন পরিচালিত হওয়ায় সেখানে বহুসংখ্যক বেসরকারি উদ্যোক্তার অবাধ প্রতিযোগিতা থাকে না
# সমাজতন্ত্রে ব্যক্তিগত মুনাফার পরিবর্তে জাতীয় চাহিদা ও সামগ্রিক কল্যাণের জন্য উৎপাদন পরিচালিত হয়ে থাকে
# কৃষি শিল্প ও ব্যবসাবাণিজ্য সবই সরকারের এবং সামাজিক মালিকানার অধীনে থাকে বলে ব্যক্তিগত মুনাফা থাকে না
# যে অর্থব্যবস্থায় ব্যক্তিমালিকানা ও বেসরকারি উদ্যোগের পাশাপাশি সরকারি উদ্যোগ ও সামাজিক নিয়ন্ত্রণ বিরাজ করে তাকে মিশ্র অর্থব্যবস্থা বলে
# পৃথিবীর অধিকাংশ দেশে মিশ্র অর্থব্যবস্থা বিদ্যমান
# মিশ্র অর্থব্যবস্থায় ব্যক্তি তার স্থাবর ও অস্থাবর সম্পত্তি অবাধে ভোগ করতে পারে ও ক্রয়বিক্রয় করতে পারে
# মিশ্র অর্থনীতিতে উৎপাদন ব্যবসাবাণিজ্য বণ্টন ও ভোগসহ অধিকাংশ অর্থনৈতিক কার্যাবলি ব্যক্তিগত উদ্যোগে সংগঠিত ও পরিচালিত হয়
# মিশ্র অর্থনীতিতে ব্যক্তি উদ্যোগের পাশাপাশি সরকারি উদ্যোগ গ্রহণ করা হয়
# দেশের মৌলিক ও ভারী শিল্প জাতীয় নিরাপত্তা ও জনগুরুত্বপূর্ণ প্রতিষ্ঠানসমূহ সরকার পরিচালনা করে থাকে
# মিশ্র অর্থনীতিতে বেসরকারি খাতে অর্থনৈতিক কার্যক্রম পরিচালনা করার মাধ্যমে মুনাফা অর্জন করা সম্ভব হয়
# মিশ্র অর্থব্যবস্থায় ভোক্তা সাধারণ দ্রব্য ক্রয়বিক্রয় ও ভোগের ক্ষেত্রে অবাধ স্বাধীনতা ভোগ করে
# সরকার প্রয়োজন মনে করলে দ্রব্যের দামের উপর প্রভাব বিস্তার করতে পারে এবং প্রয়োজন অনুসারে কোনো দ্রব্যের উৎপাদন কিংবা ভোগ নিয়ন্ত্রণ করতে পারে
# বিশ্বে কোথাও বিশুদ্ধ ধনতন্ত্র বা বিশুদ্ধ সমাজতন্ত্র না থাকায় অনেকে মিশ্র অর্থব্যবস্থাকে একটি উন্নত অর্থব্যবস্থা বলে মনে করেন
# ইসলামের মৌলিক নিয়মকানুনের উপর বিশ্বাসকে ভিত্তি করে গড়ে ওঠা অর্থব্যবস্থাকে ইসলামি অর্থব্যবস্থা বলা হয়
# ইসলামি অর্থনীতির মূলনীতিমালা ইসলাম ধর্মে বিশ্বাসীদের ধর্মীয় দর্শন ধর্মগ্রন্থের বিধান ও ধর্মীয় প্রচলিত প্রথা ও বিধিবিধান অনুযায়ী প্রণীত ও পরিচালিত হয়
# ইসলামি অর্থনীতিতে সুদ গ্রহণের স্বীকৃতি নেই
# ইসলামি অর্থ ব্যবস্থায় যাকাতভিত্তিক বণ্টন ব্যবস্থা প্রবর্তন করা হয়েছে
# যাকাত ও ফিতরার মাধ্যমে ধনীদের নিকট থেকে অর্থ গ্রহণ করে তা দরিদ্রদের মধ্যে বণ্টন করা হয়
# মানুষের আবাসভূমি হিসেবে পৃথিবীর বর্ণনা হলো ভূগোল
# ভৌত ও সামাজিক পরিবেশে মানুষের কর্মকাণ্ড ও জীবনধারা নিয়ে যে বিষয় আলোচনা করে তাই ভূগোল
# ভূগোল একদিকে প্রকৃতির বিজ্ঞান আবার অন্যদিকে পরিবেশ ও সমাজের বিজ্ঞান
# প্রকৃতি পরিবেশ ও সমাজ সম্পর্কে বিশেষ জ্ঞান হলো ভূগোলের আলোচ্য বিষয়
# পৃথিবীপৃষ্ঠে প্রাকৃতিক পরিবেশের উপব্যবস্থাগুলো কীভাবে সংগঠিত এবং এসব প্রাকৃতিক বিষয় বা অবয়বের সঙ্গে মানুষ নিজেকে কীভাবে বিন্যস্ত করে তার ব্যাখ্যা খোঁজে ভূগোল
# মানুষ পৃথিবীতে বাস করে এবং এই পৃথিবীতেই তার জীবনযাত্রা নির্বাহ করে
# পৃথিবীর প্রাকৃতিক পরিবেশ মানুষের জীবনযাত্রাকে প্রভাবিত করে
# পৃথিবীর জলবায়ু ভূপ্রকৃতি উদ্ভিদ প্রাণী নদনদী সাগর খনিজ সম্পদ তার জীবনযাত্রাকে বিভিন্নভাবে প্রভাবিত করে
# ঘরবাড়ি অফিসআদালত রাস্তাঘাট শহরবন্দর নির্মাণ প্রকৃতি ও পরিবেশকে বিভিন্নভাবে পরিবর্তিত করে
# বনভূমি কেটে তৈরি হয় গ্রাম বা শহরের মতো লোকালয়
# পৃথিবীর পরিবেশের সীমার মধ্যে থেকে মানুষের বেঁচে থাকার যে সংগ্রাম চলছে সে সম্পর্কে যুক্তিপূর্ণ আলোচনাই ভূগোল
# মানুষ যেখানেই বাস করুক তাকে ঘিরে একটি পারিপার্শ্বিক অবস্থা বিরাজমান
# প্রকৃতির সকল দান মিলেমিশে তৈরি হয় পরিবেশ
# পরিবেশ বলতে স্থান ও কালের কোনো নির্দিষ্ট বিন্দুতে মানুষকে ঘিরে থাকা সকল অবস্থার যোগফল বোঝায়
# পরিবেশের উপাদান দুই প্রকার যেমন জড় উপাদান ও জীব উপাদান
# জীবদের নিয়ে গড়া পরিবেশ হলো জীব পরিবেশ
# মাটি পানি বায়ু পাহাড় পর্বত নদী সাগর আলো উষ্ণতা আর্দ্রতা হলো পরিবেশের জড় উপাদান
# ভূগোলের যে শাখায় ভৌত পরিবেশ ও এর মধ্যে কার্যরত বিভিন্ন প্রক্রিয়া অন্তর্ভুক্ত থাকে তাকে প্রাকৃতিক ভূগোল বলে
# পৃথিবীর ভূমিরূপ এর গঠন প্রক্রিয়া বায়ুমণ্ডল বারিমণ্ডল জলবায়ু ইত্যাদি প্রাকৃতিক ভূগোলের আলোচ্য বিষয়
# ভূমিরূপবিদগণ একটি গ্রহের নগ্নীভবন এবং ক্ষয়ীভবনের ভূমিরূপের পরিবর্তন সম্পর্কে আলোচনা করে
# জলবায়ুবিদ্যা পৃথিবীর বায়ুমণ্ডলের দীর্ঘমেয়াদি আবহাওয়ার ধরন এবং এর পরিপ্রেক্ষিতে পৃথিবীর প্রভাব সম্পর্কে আলোচনা করে
# পৃথিবীপৃষ্ঠের প্রাণিজগৎ এবং উদ্ভিদের বণ্টন নিয়ে জীবভূগোল আলোচনা করে
# মৃত্তিকা ভূগোলবিদগণ অশ্মমণ্ডলের উপরিভাগের মৃত্তিকা এবং এর বণ্টন ও বিন্যাস সম্পর্কে আলোচনা করে
# পৃথিবীর প্রায় তিনচতুর্থাংশ সমুদ্র
# বিভিন্ন মহাদেশের মধ্যে সমুদ্রপথে যোগাযোগ সমুদ্রপৃষ্ঠের উত্থান অবনমন সমুদ্রের পানির রাসায়নিক গুণাগুণ ও লবণাক্ততা নির্ধারণ সামুদ্রিক সম্পদ ব্যবস্থাপনা সমুদ্রবিদ্যার আলোচ্য বিষয়
# পৃথিবীর বিভিন্ন অঞ্চলে বিভিন্ন পরিবেশে মানুষ কীভাবে বসবাস করছে কীভাবে জীবনযাত্রা নির্বাহ করছে কেন এভাবে জীবনযাত্রা নির্বাহ করছে তার কার্যকারণ অনুসন্ধান মানব ভূগোলের আলোচ্য বিষয়
# প্রাকৃতিক ও সামাজিক পরিবেশের সঙ্গে মানিয়ে নিয়ে পৃথিবীতে বেঁচে থাকার জন্য মানুষ যেসব অর্থনৈতিক কাজ করে তা অর্থনৈতিক ভূগোলের আলোচ্য বিষয়
# জনসংখ্যা জনসংখ্যা বৃদ্ধির গতিপ্রকৃতি তার কার্যকারণ সামাজিক ও অর্থনৈতিক জীবনের উপর এর প্রভাব জনসংখ্যা ভূগোলের আলোচ্য বিষয়
# অঞ্চলভেদে পৃথিবীর ভূপ্রকৃতি জলবায়ু উদ্ভিদ জীবজন্তু মানুষ ও মানুষের জীবনধারণ প্রণালি বিশেষ বৈশিষ্ট্যের অধিকারী
# আঞ্চলিক বৈশিষ্ট্য অনুসারে পৃথিবীর বিভিন্ন অঞ্চলের ভৌগোলিক বিষয়বস্তু অনুশীলন করা আঞ্চলিক ভূগোলের প্রধান বিষয়
# রাজনৈতিক বিবর্তন রাজনৈতিক বিভাগ ও পরিসীমা এবং বিভাগের মধ্যস্থিত ভৌগোলিক বিষয় রাজনৈতিক ভূগোলের প্রধান বিষয়
# সংখ্যাতাত্ত্বিক ভূগোল ভূগোলের এই শাখায় সংখ্যাতাত্ত্বিক কৌশল এবং মডেল ব্যবহার করে প্রমাণার্থ পরীক্ষা করা হয়
# পরিবহন ভূগোলবিদরা সরকারি বেসরকারি যাতায়াত ব্যবস্থা এবং মানুষ ও পণ্যের একস্থান থেকে অন্যস্থানে স্থানান্তর সম্পর্কে আলোচনা করে
# নগর ভূগোল  ভূগোলের এ শাখায় নগরের উৎপত্তি ও বিকাশ নগর ও শহরের শ্রেণিবিভাগ নগর পরিবেশ নগরের কেন্দ্রীয় এলাকা নগরীর বস্তি ইত্যাদি বিষয় চর্চা করা হয়
# দুর্যোগে ক্ষয়ক্ষতির পরিমাণ হ্রাস দুর্যোগ থেকে পরিবেশ ও সমুদ্রকে রক্ষার কৌশল দুর্যোগ ব্যবস্থাপনার আলোচ্য বিষয়
# ভূগোলকে যত ভাগেই বিভক্ত করা হোক না কেন সকল ভূগোলের সঙ্গে পরিবেশ অঙ্গাঙ্গীভাবে জড়িত
# পরিবেশ দুই প্রকার ভৌত বা প্রাকৃতিক পরিবেশ ও সামাজিক পরিবেশ
# প্রকৃতির জড় ও জীব উপাদান নিয়ে যে পরিবেশ তাকে ভৌত বা প্রাকৃতিক পরিবেশ বলে
# প্রাকৃতিক পরিবেশে থাকে মাটি পানি বায়ু পাহাড় পর্বত নদী সাগর আলো গাছপালা পশুপাখি কীটপতঙ্গ মানুষ ও অন্যান্য ক্ষুদ্র প্রাণী
# মানুষের তৈরি পরিবেশ হলো সামাজিক পরিবেশ
# মানুষের আচার আচরণ উৎসবঅনুষ্ঠান রীতিনীতি শিক্ষা মূল্যবোধ অর্থনীতি রাজনীতি ইত্যাদি নিয়ে যে পরিবেশ গড়ে ওঠে তা হলো সামাজিক পরিবেশ
# পৃথিবীর প্রকৃত আকৃতি হলো অনেকটা অভিগত গোলকের মতো
# পৃথিবীর আকৃতি যেহেতু সম্পূর্ণ গোলাকার নয় সেহেতু পৃথিবীর নিরক্ষীয় পূর্বপশ্চিম ব্যাস ও মেরুদেশীয় উত্তরদক্ষিণ ব্যাস ভিন্ন
# সমগ্র পৃথিবীর মধ্যে কোনো একটি স্থানকে নির্দিষ্ট করতে হলে বা এর অবস্থান জানতে হলে আমাদের সবার আগে যে বিষয়গুলো জানতে হবে তা হলো অক্ষরেখা ও দ্রাঘিমারেখা
# দ্রাঘিমারেখার অবস্থান থেকে কোনো স্থানের সময় জানা যায়
# অক্ষরেখার সাহায্যে যেমন নিরক্ষরেখা থেকে উত্তর বা দক্ষিণে অবস্থান জানা যায় তেমনি মূল মধ্যরেখা থেকে পূর্ব বা পশ্চিমে অবস্থান জানা যায়
# পৃথিবীর গোলাকৃতি কেন্দ্র দিয়ে উত্তরদক্ষিণে কল্পিত রেখাকে অক্ষ বা মেরুরেখা বলে
# অক্ষের উত্তরপ্রাপ্ত বিন্দুকে উত্তর মেরু বা সুমেরু এবং দক্ষিণপ্রান্ত বিন্দুকে দক্ষিণ মেরু বা কুমেরু বলে
# দুই মেরু থেকে সমান দূরত্বে পৃথিবীকে পূর্বপশ্চিমে বেষ্টন করে একটি রেখা কল্পনা করা হয়েছে একে নিরক্ষরেখা বা বিষুবরেখা বলে
# নিরক্ষরেখার উত্তরদক্ষিণে পৃথিবীকে সমান দুই ভাগে বিভক্ত করা হয়েছে
# নিরক্ষরেখার উত্তর দিকের পৃথিবীর অর্ধেককে উত্তর গোলার্ধ ও দক্ষিণ দিকের অর্ধেককে দক্ষিণ গোলার্ধ বলে
# একজন ভূগোলবিদের জন্য অক্ষাংশ নির্ণয় করতে জানা খুবই জরুরি
# নিরক্ষরেখার উত্তর দিকে অবস্থিত কোনো একটি স্থানের অক্ষাংশকে উত্তর অক্ষাংশ এবং দক্ষিণ দিকে অবস্থিত কোনো স্থানের অক্ষাংশকে দক্ষিণ অক্ষাংশ বলে
# যে যন্ত্রের সাহায্যে সূর্যের উন্নতি পরিমাপ করা যায় তাকে সেক্সট্যান্ট যন্ত্র বলে
# সূর্য যেদিন যে অক্ষাংশের উপর লম্বভাবে কিরণ দেয় সেটাই সেদিনের সূর্যের বিষুবলম্ব
# ধ্রুবতারার উন্নতি জেনে কোনো স্থানের অক্ষাংশ নির্ণয় করা যায়
# নিরক্ষরেখাকে ডিগ্রি মিনিট ও সেকেন্ডে ভাগ করে প্রত্যেক ভাগবিন্দুর উপর দিয়ে উত্তর মেরু থেকে দক্ষিণ মেরু পর্যন্ত যে সকল রেখা কল্পনা করা হয়েছে সেগুলোই হলো দ্রাঘিমারেখা
# যুক্তরাজ্যের লন্ডন শহরের কাছে গ্রিনিচ মান মন্দিরের উপর দিয়ে উত্তর মেরু থেকে দক্ষিণ মেরু পর্যন্ত বিস্তৃত যে মধ্যরেখা অতিক্রম করেছে তাকে মূল মধ্যরেখা বলে
# গ্রিনিচের মূল মধ্যরেখা থেকে পূর্ব বা পশ্চিমে কোনো স্থানের কৌণিক দূরত্বকে ঐ স্থানের দ্রাঘিমা বলে
# কোনো স্থানে মধ্যাহ্নে যখন সূর্য ঠিক মাথার উপর আসে সেখানে দুপুর টা ধরে প্রতি  মিনিট সময়ের পার্থক্যে দ্রাঘিমার পার্থক্য হয়
# গ্রিনিচের দ্রাঘিমা শূন্য ডিগ্রি  ধরা হয়
# পৃথিবীর ঠিক মাঝখান দিয়ে যে রেখাটি পূর্বপশ্চিমে সমগ্র পৃথিবীকে বেষ্টন করে আছে তাকে নিরক্ষরেখা বলে
# আমরা জানি পৃথিবী গোল তাই এর কোনো একটি স্থানের বিপরীত দিকে অন্য কোনো একটি স্থান রয়েছে
# ভূপৃষ্ঠের কোনো বিন্দু থেকে পৃথিবীর কোনো কল্পিত ব্যাস ভূকেন্দ্র ভেদ করে অপরদিকে ভূপৃষ্ঠকে যে বিন্দুতে স্পর্শ করে সেই বিন্দুকে প্রথম বিন্দুটির প্রতিপাদ স্থান বলে
# কোনো বিশেষ দ্রাঘিমায় অবস্থিত স্থান সেই স্থানের বিপরীত দ্রাঘিমারেখায় অবস্থিত হয়
# পূর্বে মনে করা হতো পৃথিবী স্থির এবং সূর্যই পৃথিবীর চারদিকে ঘুরছে
# পরবর্তীতে প্রমাণিত হয় যে সূর্য সৌরজগতের কেন্দ্রে অবস্থিত এবং পৃথিবীই সূর্যকে কেন্দ্র করে ঘুরছে
# পৃথিবী শুধু সূর্যকে কেন্দ্র করে ঘোরে না নিজ অক্ষ বা মেরুরেখার উপরও আবর্তন করে
# পৃথিবীর গতি দুই প্রকার আহ্নিক গতি বার্ষিক গতি
# নিজ অক্ষের উপর একদিনে আবর্তন করাকে আহ্নিক গতি বলে
# কক্ষপথে এক বছরে সূর্যকে পরিক্রমণ করাকে বার্ষিক গতি বলে
# পৃথিবী তার নিজের মেরুদণ্ডের বা অক্ষের চারদিকে দিনে একবার নির্দিষ্ট গতিতে পশ্চিম থেকে পূর্ব দিকে আবর্তন করে
# ভূপৃষ্ঠে অবস্থান করার কারণে মানুষ জীবজন্তু বায়ুমণ্ডল প্রভৃতি পৃথিবীর সঙ্গে একই গতিতে আবর্তন করছে তাই আমরা পৃথিবীর আবর্তন গতি অনুভব করতে পারি না
# পৃথিবীর আয়তনের তুলনায় আমরা এত বেশি ক্ষুদ্র যে এই গতি অনুভব করি না বা ছিটকে পড়ি না
# পৃথিবীর সামনে স্থির বা সমান কোনো বস্তু নেই যার সাপেক্ষে আমরা পৃথিবীর আবর্তন গতি বুঝতে পারি
# পৃথিবী থেকে যেসব উপগ্রহ ও মহাকাশযান পাঠানো হয়েছে সেগুলোর প্রেরিত ছবি থেকে দেখা যায় যে পৃথিবী পশ্চিম থেকে পূর্ব দিকে আবর্তন করছে
# পৃথিবীর বেশিরভাগ স্থানেই পর্যায়ক্রমে দিন ও রাত্রি হয়
# আমরা জানি সমুদ্রস্রোত এবং বায়ুপ্রবাহ উত্তর গোলার্ধে ডান দিকে এবং দক্ষিণ গোলার্ধে বাম দিকে বেঁকে যায়
# আবর্তন গতির জন্য পৃথিবীর যেদিক সূর্যের সামনে আসে সেদিক সূর্যের আলোতে আলোকিত হয়
# আহ্নিক গতির ফলেই জোয়ারভাটা সংঘটিত হচ্ছে
# পৃথিবীর অভিগত গোলকের কারণে নিরক্ষরেখা থেকে উভয় মেরুর দিকে অক্ষরেখাগুলোর পরিধি ও পৃথিবীর আবর্তনের গতিবেগ ক্রমশ কমতে থাকে
# দিনের বেলায় সূর্যের কিরণ থাকার কারণে তাপমাত্রা বেশি থাকে
# সূর্যের মহাকর্ষ বলের আকর্ষণে পৃথিবী নিজের অক্ষের উপর অবিরাম ঘুরতে ঘুরতে একটি নির্দিষ্ট পথে নির্দিষ্ট দিকে ঘড়ির কাঁটার বিপরীতে এবং নির্দিষ্ট সময়ে সূর্যের চারদিকে ঘুরছে
# বিভিন্ন সময়ে রাতের আকাশে পূর্ব থেকে পশ্চিমে নক্ষত্রগুলোর অবস্থান পরিবর্তন করতে দেখা যায়
# বছরের বিভিন্ন সময়ে সূর্যকে বিভিন্ন অবস্থানে দেখা যায়
# তাপমাত্রার পার্থক্য অনুসারে সারাবছরকে চারটি ভাগে ভাগ করা হয়েছে এগুলো হলো গ্রীষ্মকাল শরৎকাল শীতকাল ও বসন্তকাল
# উত্তর গোলার্ধে যখন বসন্তকাল দক্ষিণ গোলার্ধে তখন শরৎকাল
# উত্তর গোলার্ধে যখন শরৎকাল দক্ষিণ গোলার্ধে তখন বসন্তকাল
# বাংলাদেশের ভৌগোলিক অবস্থান উত্তর গোলার্ধে
# পৃথিবী দিনের বেলায় তাপ গ্রহণ করে ফলে ভূপৃষ্ঠ উত্তপ্ত হয় এবং রাতের বেলায় বিকিরণ করে শীতল হয়
# এ মার্চের পর থেকে পৃথিবী তার নিজ কক্ষপথে এগিয়ে চলার সঙ্গে সঙ্গে উত্তর মেরু ক্রমশ সূর্যের দিকে হেলতে থাকে
# এ জুন থেকে দক্ষিণ মেরু সূর্যের দিকে হেলতে থাকে
# এ সেপ্টেম্বরের পর দক্ষিণ গোলার্ধ ক্রমশ সূর্যের দিকে হেলতে থাকে
# পৃথিবী তার কক্ষপথে চলতে চলতে এ ডিসেম্বরের পর থেকে এ মার্চ পর্যন্ত এমন স্থানে ফিরে আসে যখন সূর্য নিরক্ষরেখার উপর লম্বভাবে কিরণ দিতে থাকে
# মানচিত্র হলো একটি ড্রয়িং বা রেখাঙ্কন যা ভূপৃষ্ঠের কোনো ছোট বা বৃহৎ অঞ্চলকে উপস্থাপন করে থাকে
# মানচিত্র কোনো অঞ্চল বা দেশের ভূপ্রকৃতি জলবায়ু উদ্ভিদ মাটি পানি ও অনেক কিছু সম্পর্কে ধারণা দেয়
# মানচিত্র হলো নির্দিষ্ট স্কেলে অক্ষরেখা বা দ্রাঘিমারেখাসহ কোনো সমতল ক্ষেত্রের উপর পৃথিবী বা এর অংশবিশেষের অঙ্কিত প্রতিরূপ
# রং রেখা ও সংকেত হলো মানচিত্রের ভাষা
# স্কেল অনুসারে মানচিত্র আবার দুই প্রকারের ক বৃহৎ স্কেলের মানচিত্র এবং খ ক্ষুদ্র স্কেলের মানচিত্র
# নৌচলাচল সংক্রান্ত নাবিকদের চার্ট বিমানচলাচল সংক্রান্ত বৈমানিকদের চার্ট মৌজা মানচিত্র বা ক্রাডাস্ট্রাল মানচিত্র প্রভৃতি বৃহৎ স্কেলের মানচিত্র
# একটি ছোট এলাকা অনেক বড় করে দেখানো হয় বলে মানচিত্রের মধ্যে অনেক জায়গা থাকে এবং অনেক কিছু তথ্য এরূপ মানচিত্রে ভালোভাবে দেখানো যায়
# উপস্থাপিত বিষয়বস্তু হিসেবেও মানচিত্রগুলো দুই প্রকারের ক গুণগত মানচিত্র এবং খ পরিমাণগত মানচিত্র
# ভূতাত্ত্বিক মানচিত্র ভূসংস্থানিক মানচিত্র ভূমিরূপের মানচিত্র মৃত্তিকা মানচিত্র দেয়াল মানচিত্র ভূচিত্রাবলি মানচিত্র স্থানীয় বৈচিত্র্যসূচক মানচিত্র এবং মৌজা মানচিত্র গুণগত মানচিত্রের অন্তর্গত
# বায়ুর উত্তাপ বৃষ্টিপাতের পরিমাণ জনসংখ্যার বণ্টন জনসংখ্যার ঘনত্ব খনিজ উৎপাদন বনজ উৎপাদন শিল্পজ উৎপাদন প্রভৃতি পরিসংখ্যান তথ্য যেসব মানচিত্রে দেখানো হয় সেসব মানচিত্র পরিমাণগত মানচিত্রের অন্তর্গত
# ভূসংস্থানিক এর আরেক নাম হচ্ছে স্থানীয় বৈচিত্র্যসূচক মানচিত্র
# ভূপ্রাকৃতিক বৈশিষ্ট্য হিসেবে পাহাড় মালভূমি সমভূমি নদী উপত্যকা হ্রদ প্রভৃতি দেখানো হয়
# দেয়াল মানচিত্রে আমাদের চাহিদা মতো একটি দেশ অথবা একেকটি মহাদেশকে আলাদাভাবে প্রকাশ করা হয় বড় অথবা ছোট স্কেলে
# মানচিত্রের সমষ্টিকে ভূচিত্রাবলি এটলাস বলে
# যে মানচিত্রে কোনো দেশ বা অঞ্চলের বিভিন্ন প্রাকৃতিক ভূমিরূপ যেমন পর্বত মালভূমি মরুভূমি নদী হ্রদ ইত্যাদি সম্পর্কে তথ্য থাকে তাকে প্রাকৃতিক মানচিত্র বলে
# ভূতাত্ত্বিক মানচিত্র  ভূত্বক গঠনকারী শিলাসমূহের অবস্থান ও গঠনের উপর ভিত্তি করে এই ধরনের মানচিত্র তৈরি করা হয়
# বায়ুর তাপ বায়ুর চাপ বায়ুপ্রবাহ বৃষ্টিপাত আর্দ্রতা প্রভৃতির উপর ভিত্তি করে যে মানচিত্র তৈরি করা হয় তাকে জলবায়ুগত মানচিত্র বলে
# বিশ্বের কোথায় কোন ধরনের প্রাকৃতিক উদ্ভিজ্জ আছে তার উপর ভিত্তি করে যে মানচিত্র তৈরি করা হয় তাকে উদ্ভিজ্জ বিষয়ক মানচিত্র বলে
# মৃত্তিকা বিষয়ক মানচিত্র  বিশ্বের কোথায় কোন ধরনের মাটি তার উপর ভিত্তি করে এই মানচিত্র তৈরি করা হয়
# সাধারণত মাটির গুণাগুণের উপর ভিত্তি করেই বিশ্বের কোথায় কোন ধরনের ফসলের চাষ করা যাবে সেজন্য কৃষিবিদরা এই ধরনের মানচিত্র বেশি ব্যবহার করে থাকেন
# বিভিন্ন স্থানের অর্থনৈতিক অবস্থা বিভিন্ন দেশ ও রাষ্ট্রের সীমা ঐতিহাসিক কোনো স্থান বা স্থাপত্য পৃথিবীর বিভিন্ন অঞ্চলের সমাজ ব্যবস্থা ইত্যাদি নিয়ে যে মানচিত্র তৈরি হয় তাকে সাংস্কৃতিক মানচিত্র বলে
# রাজনৈতিক মানচিত্র  বিভিন্ন দেশ ও রাষ্ট্রের সীমা দেখিয়ে এই মানচিত্র তৈরি করা হয়
# যেসব মানচিত্রে জনসংখ্যা শস্য জীবজন্তু শিল্প ইত্যাদির বণ্টন কোনো একটি অঞ্চল বা দেশে দেখানো হয় তাকে বণ্টন মানচিত্র বলে
# ঐতিহাসিক কোনো স্থান বা স্থাপত্যকে নিয়ে যেসব মানচিত্র তৈরি করা হয় তাকে ঐতিহাসিক মানচিত্র বলে
# সামাজিক মানচিত্র  পৃথিবীর বিভিন্ন অঞ্চলের সমাজ ব্যবস্থার উপর ভিত্তি করে মানচিত্রগুলো তৈরি করা হয়
# বিশেষ করে যারা সামাজিক প্রথা ও বৈষম্য জনসংখ্যা এসব নিয়ে গবেষণা করেন তারা সামাজিক মানচিত্র ব্যবহার করেন
# ভূমি ব্যবহার মানচিত্র  কোন ভূমি কী কাজে ব্যবহার করা হচ্ছে বা কোন ভূমি কোন কাজে ব্যবহার করলে সবচেয়ে বেশি উপযোগী তার উপর ভিত্তি করে যে মানচিত্র তৈরি করা হয় তাকে ভূমি ব্যবহার মানচিত্র বলে
# স্থানীয় বৈচিত্র্যসূচক মানচিত্র গঠন ভূগোল শাস্ত্রের একটি প্রধান ও প্রয়োজনীয় বিষয়
# প্রত্যেক মানচিত্রেরই একটি শিরোনাম থাকে
# কোনো অঞ্চলের মানচিত্র তৈরির সময় এর আয়তনকে কমিয়ে ক্ষুদ্র করে আঁকতে হয়
# প্রতিটি মানচিত্রের মাথা বাম দিকের মার্জিনে একটি তীর দেওয়া থাকে
# মানচিত্রে দিক না দেখানো থাকলে উপরের দিককে উত্তর দিক বুঝতে হবে
# মানচিত্রে কোন প্রতীক দিয়ে কী বোঝানো হয়েছে সূচক তা নির্দেশ করে
# সব মানচিত্র তথ্য বা উপাত্তের ভিত্তিতে তৈরি হয়
# পৃথিবী পশ্চিম থেকে পূর্ব দিকে ঘুরছে
# পৃথিবীর যে অংশটি পূর্ব দিকে সেই অংশটিতে আগে সূর্যোদয় বা সকাল হয়
# পৃথিবীর আবর্তনের ফলে কোনো একটি স্থানে সূর্য যখন ঠিক মাথার উপর আসে তখন ঐ স্থানে মধ্যাহ্ন
# দ্রাঘিমারেখার উপর সূর্যের অবস্থানের ভিত্তিতে আমরা সময় ঠিক করি
# সাধারণত কোনো একটি দেশের মধ্যভাগের দ্রাঘিমারেখা অনুযায়ী যে সময় নির্ধারণ করা হয় সে সময়কে ঐ দেশের প্রমাণ সময় ধরা হয়
# দেশের আয়তনের উপর ভিত্তি করে প্রমাণ সময় একাধিক হতে পারে
# সৃষ্টির সময় পৃথিবী ছিল একটি উত্তপ্ত গ্যাসপিণ্ড
# ভূপৃষ্ঠে শিলার যে কঠিন বহিরাবরণ দেখা যায় তাই ভূত্বক
# ভূঅভ্যন্তরের অন্যান্য স্তরের তুলনায় ভূত্বকের পুরুত্ব সবচেয়ে কম গড়ে  কিলোমিটার
# ভূত্বকের নিচে প্রায়  কিলোমিটার পর্যন্ত পুরুমণ্ডলকে গুরুমণ্ডল বলে
# গুরুমণ্ডল মূলত ব্যাসন্ট শিলা দ্বারা গঠিত
# গুরুমণ্ডল অংশে রয়েছে সিলিকা ম্যাগনেসিয়াম লোহা কার্বন ও অন্যান্য খনিজ পদার্থ
# গুরুমণ্ডলের ঠিক পরে রয়েছে কেন্দ্রমণ্ডল
# গুরুমণ্ডলের নিচ থেকে পৃথিবীর কেন্দ্র পর্যন্ত কেন্দ্রমণ্ডল বিস্তৃত
# ভূত্বক শিলা দ্বারা গঠিত
# শিলা বিভিন্ন খনিজের সংমিশ্রণে গঠিত
# কতকগুলো মৌলিক উপাদান প্রাকৃতিক উপায়ে মিলিত হয়ে যে যৌগ গঠন করে তাই খনিজ
# খনিজ হলো একটি প্রাকৃতিক অজৈব পদার্থ যার সুনির্দিষ্ট রাসায়নিক গঠন এবং ভৌত ও রাসায়নিক ধর্ম রয়েছে
# শিলা হলো এক বা একাধিক খনিজের মিশ্রণ
# খনিজ দুই বা ততোধিক মৌলের সমন্বয়ে গঠিত হলেও কিছু কিছু খনিজ একটি মাত্র মৌল দ্বারাও গঠিত হতে পারে
# শিলা গঠনকারী প্রতিটি খনিজের আলাদা আলাদা বৈশিষ্ট্য বজায় থাকে
# খনিজ কঠিন ও স্ফটিকাকার হয় কিছু কিছু শিলা কঠিন হলেও স্ফটিকাকার হয় না
# খনিজের নির্দিষ্ট রাসায়নিক সংকেত আছে শিলার কোনো রাসায়নিক সংকেত নেই
# ভূত্বক যেসব উপাদান দ্বারা গঠিত তাদের সাধারণ নাম শিলা ভূ
# তত্ত্ববিদগণের মতে দুই বা ততোধিক খনিজ দ্রব্যের সংমিশ্রণে এসব শিলার সৃষ্টি হয়
# ভূত্বক গঠনকারী সকল কঠিন ও কোমল পদার্থই শিলা
# গলিত অবস্থা থেকে ঘনীভূত বা কঠিন হয়ে যে শিলা গঠিত হয় তাকে আগ্নেয় শিলা বলে
# আগ্নেয় শিলা পৃথিবীর প্রথম পর্যায়ে সৃষ্টি হয় তাই এই শিলাকে প্রাথমিক শিলাও বলে
# আগ্নেয়গিরি বা ভূমিকম্পের ফলে অনেক সময় ভূত্বকের দুর্বল অংশে ফাটলের সৃষ্টি হয়
# ভূগর্ভের উত্তপ্ত তরল পদার্থ ম্যাগমা আগ্নেয়গিরির অগ্ন্যুৎপাত বা অন্য কোনো কারণে বেরিয়ে এসে শীতল হয়ে জমাট বেঁধে বহিঃজ আগ্নেয় শিলার সৃষ্টি হয় এদের দানা খুব সূক্ষ্ম রং গাঢ়
# উত্তপ্ত ম্যাগমা ভূপৃষ্ঠের বাইরে না এসে ভূগর্ভে জমাট বাঁধলে তৈরি হয় অন্তঃজ আগ্নেয় শিলা
# পলি সঞ্চিত হয়ে যে শিলা গঠিত হয়েছে তাকে পাললিক শিলা বলে
# বৃষ্টি বায়ু তুষার তাপ সমুদ্রের ঢেউ প্রভৃতি শক্তির প্রভাবে আগ্নেয় শিলা ক্ষয়প্রাপ্ত ও বিচূর্ণীভূত হয়ে রূপান্তরিত হয় এবং কাঁকর কাদা বালি ও ধুলায় পরিণত হয়
# ক্ষয়িত শিলাকণা জলস্রোত বায়ু এবং হিমবাহ দ্বারা পরিবাহিত হয়ে পলল বা তলানিরূপে কোনো নিম্নভূমি হ্রদ এবং সাগরগর্ভে সঞ্চিত হতে থাকে
# হিসাববিজ্ঞান হচ্ছে একটি প্রক্রিয়া যেখানে সংঘটিত আর্থিক ঘটনাসমূহের সামগ্রিক প্রভাব এবং ফলাফল নির্ণয়ের পদ্ধতি ও কৌশল আলোচনা করা হয়
# হিসাববিজ্ঞান এমন একটি প্রক্রিয়া যার মাধ্যমে কোনো ব্যক্তি বা প্রতিষ্ঠানের যাবতীয় আর্থিক কার্যাবলি যেমন খরচ পরিশোধ আয় আদায় সম্পদ ক্রয় ও বিক্রয় পণ্য ক্রয় ও বিক্রয় দেনাদার হতে আদায় এবং পাওনাদারকে পরিশোধ ইত্যাদি হিসাবের বইতে সুষ্ঠুভাবে লিপিবন্ধ করা যায় এবং নির্দিষ্ট সময় শেষে আর্থিক কার্যাবলির ফলাফল জানা যায়
# হিসাববিজ্ঞান বিষয়ে ব্যবসায়ের আর্থিক লেনদেন লিপিবদ্ধকরণ শ্রেণিবদ্ধকরণ ব্যাখ্যাকরণের পদ্ধতি আলোচনা করা হয়
# হিসাববিজ্ঞানের জ্ঞান ব্যবহার করে হিসাবের বিভিন্ন বিবরণী ও প্রতিবেদন প্রস্তুত করা হয় যার মাধ্যমে প্রতিষ্ঠানের আর্থিক অবস্থা জানা যায়
# হিসাববিজ্ঞানকে ব্যবসায়ের ভাষা বলা হয়
# সভ্যতার সূচনা হতে মানুষ বিভিন্ন গুরুত্বপূর্ণ ঘটনা বা হিসাব গাছের গায়ে গুহায় বা পাথরে চিহ্ন দিয়ে রাখত
# এক সময় মানুষ সমাজবদ্ধ হয়ে বসবাস শুরু করল এবং কৃষিকাজ আরম্ভ করল
# আস্তে আস্তে মানুষের সংখ্যা বৃদ্ধি পায় সমাজ বিস্তার লাভ করে বিনিময় প্রথা চালু হয় মুদ্রার প্রচলন হয় এবং ব্যবসায়বাণিজ্য শুরু হয়
# সময়ের পরিবর্তনের সাথে সাথে বিজ্ঞান প্রযুক্তি এবং ব্যবসায়বাণিজ্যের অগ্রগতি হয় এবং এরই ফলে হিসাববিজ্ঞানেরও উন্নতি হয়
# ব্যবসায় যেমন ছোট থেকে বড় হতে থাকে তেমনি এর পরিধিও বৃদ্ধি পেতে থাকে
# ব্যক্তিগত ও পারিবারিক জীবনের পাশাপাশি ব্যবসায়ী অব্যবসায়ী সরকারি বেসরকারি মুনাফাভোগী ও অমুনাফাভোগী সকল ধরনের প্রতিষ্ঠানে হিসাববিজ্ঞানের ব্যবহার পরিলক্ষিত হয়
# হিসাবরক্ষক হিসাবের বই এবং সংশ্লিষ্ট কাগজপত্র তৈরি করেন
# ব্যবসায়ের মালিক এবং তাঁর ব্যবস্থাপক এসব হিসাব বিবরণী থেকে ব্যবসায়ের লাভক্ষতি ও আর্থিক অবস্থার পরিমাণ ও পরিবর্তন জানতে পারেন
# প্রতিষ্ঠানকে ঋণ সরবরাহের পূর্বে ঋণ পরিশোধ ক্ষমতা যাচাইয়ের জন্য ঋণ প্রদানকারী প্রতিষ্ঠান ব্যবসায়ের যাবতীয় হিসাব পর্যালোচনা করেই ঋণ সরবরাহ করে থাকে
# সরকারের সংশ্লিষ্ট কর্তৃপক্ষ ব্যবসায়ের হিসাব হতে যথাযথভাবে শুল্ক ভ্যাট কর এবং আয়কর পরিশোধ করা হচ্ছে কি না তা নিশ্চিত হতে এবং প্রয়োজনীয় পদক্ষেপ গ্রহণ করতে পারেন
# বাকিতে পণ্য বিক্রয়ের পূর্বে ব্যবসায়ের দায় পরিশোধ ক্ষমতা যাচাই করেই সরবরাহকারী ব্যক্তি ও প্রতিষ্ঠান পণ্য সরবরাহ করেন
# ব্যবসায়ের শ্রমিক কর্মচারী ও কর্মকর্তাগণ তাদের প্রাপ্ত সুযোগসুবিধার যথার্থতা বিচার এবং ন্যায্য অংশ আদায়ের জন্য আর্থিক বিবরণীর সহায়তা গ্রহণ করে
# হিসাব নিরীক্ষক বিনিয়োগকারী ভোক্তা এবং অন্যান্য সংশ্লিষ্ট ব্যক্তি ও প্রতিষ্ঠান হিসাব তথ্য ব্যবহার করে থাকেন
# জলবায়ুদূষণ রোধে প্রতিষ্ঠান কিছু অর্থ খরচ করবে এবং হিসাববক্ষক তার হিসাব রাখবে এবং সে হিসাব থেকে বুঝা যাবে ব্যবসার মালিক সমাজ এবং পরিবেশ সম্পর্কে কতটুকু সজাগ
# বিশেষ করে তেল কোম্পানিগুলো বায়ুদূষণ রোধে অনেক ব্যয় করে থাকে
# শিল্পকারখানা থেকে নির্গত ধোঁয়া আশপাশের পরিবেশ ও মানবস্বাস্থ্যের ক্ষতি করে
# ব্যবসায়ের মালিক ও হিসাবরক্ষককে এর প্রতিরোধে অর্থ খরচ করতে হয় হিসাব রাখতে হয় এবং এ বিষয়ে সরকারের নিয়মনীতিকে অনুসরণ করে চলতে হয়
# পণ্য তৈরিতে স্বাস্থ্যসম্মত কাঁচামাল ব্যবহার করা হয় যথাসম্ভব কম বিদ্যুৎ খরচ করা হয় যন্ত্রপাতির শব্দ কম হতে হয় এবং আবর্জনা সঠিক স্থানে ফেলতে হয়
# প্রতিটি ব্যবসায় প্রতিষ্ঠানকে সামাজিক দায়বদ্ধতার অংশ হিসেবে সমাজের জন্য কিছু খরচ করতে হয় যেমন গরিব ও মেধাবী ছাত্রদের বৃত্তি প্রদান
# মূল্যবোধ হলো ব্যক্তি ও সমাজের চিন্তা চেতনা বিশ্বাস ধ্যান ধারণা প্রভৃতির সমন্বয়ে দীর্ঘদিন ধরে গড়ে ওঠা একটি মানদণ্ড যার দ্বারা মানুষ কোনো বিষয়ের ভালোমন্দ বিচার করে ভালোকে গ্রহণ ও মন্দকে বর্জন করে
# হিসাবরক্ষণের ক্ষেত্রে হিসাববিজ্ঞানের রীতিনীতি ও কলাকৌশল যথাযথভাবে অনুসরণ করা হলে আর্থিক দুর্নীতি জালিয়াতি সম্পদ ইত্যাদির উপর নিয়ন্ত্রণ থাকে এবং হিসাবের স্বচ্ছতা বৃদ্ধি পায়
# হিসাববিজ্ঞান ঋণগ্রহীতাদের মধ্যে ঋণ পরিশোধে সচেতনতা সৃষ্টি করে এবং তাদের মূল্যবোধ জাগ্রত করে
# সরকারের আয়ের অন্যতম উৎসগুলো হচ্ছে ভ্যাট কাস্টমস ডিউটি আয়কর প্রভৃতি
# সুষ্ঠু হিসাবব্যবস্থা প্রচলিত থাকলে সম্ভাব্য শাস্তি ও দুর্নামের ভয়ে প্রতিষ্ঠানের কর্মচারী ও কর্মকর্তাদের মধ্যে জালিয়াতি তহবিল তছরূপ প্রতারণাসহ বিভিন্ন অনিয়মের প্রবণতা হ্রাস পায়
# কোনো কার্য সম্পাদনের দায়িত্ব সুনির্দিষ্ট হলে কাজের ফলাফলের জন্য সংশ্লিষ্ট ব্যক্তিকে তার কাজের জন্য দায়ী করা যায়
# আধুনিক বিকেন্দ্রীকরণ ব্যবস্থায় আয় ব্যয় ও বিনিয়োগের জন্য নির্দিষ্ট ব্যক্তিগণকে পূর্ণ ক্ষমতা দেওয়া হয় যাতে করে দায়িত্বপালনে পূর্ণ মনোযোগ প্রদান সম্ভব হয় এবং নির্দিষ্ট হিসাবকাল শেষে অর্পিত দায়িত্বের ফলাফল সম্পর্কে ঊর্ধ্বতন কর্তৃপক্ষের প্রশ্নের জবাব প্রদানেও সক্ষম হয়
# প্রতিষ্ঠানের হিসাবরক্ষণ ও ব্যবস্থাপনায় নিয়োজিত ব্যক্তিবর্গের এই মর্মে জবাবদিহি করতে হয় যে প্রস্তুতকৃত বিবরণীতে প্রতিষ্ঠানের সঠিক চিত্র তুলে ধরা হয়েছে কি না বিনিয়োগকৃত অর্থের সঠিক ব্যবহার কতটুকু নিশ্চিত হয়েছে অর্জিত মুনাফা ও প্রাক্কলিত মুনাফার সংগতি রক্ষা হয়েছে কি না ইত্যাদি
# সরকার কর্তৃক নির্ধারিত বিভিন্ন নিয়মনীতি যথাযথভাবে পালন করে প্রতিষ্ঠান পরিচালিত হচ্ছে কি না এবং যথাযথভাবে শুল্ক ভ্যাট ও কর পরিশোধ করা হচ্ছে কি না তা দেখার অধিকার সরকারের সংশ্লিষ্ট পক্ষসমূহের রয়েছে
# মানুষ সুপ্রাচীনকাল থেকেই দৈনন্দিন জীবনে হিসাবব্যবস্থার প্রয়োজনীয়তা অনুভব করে আসছে
# আদিকালে প্রত্যেকে তার প্রাত্যহিক জীবনের প্রয়োজনগুলো মেটানোর জন্য নিজেদের মধ্যে পণ্য বিনিময় করত
# অর্থের অঙ্কে পরিমাপযোগ্য ঘটনা যা ব্যবসায়ের আর্থিক অবস্থার পরিবর্তন করে সেই সমস্ত ঘটনাকেই লেনদেন হিসেবে হিসাবের বহিতে লিপিবদ্ধ করা হয়
# লেনদেন শব্দটির আভিধানিক অর্থ হলো গ্রহণ ও প্রদান অর্থাৎ দেওয়া ও নেওয়া
# লেনদেন দুই ধরনের যথা  বাহ্যিক লেনদেন ও  অভ্যন্তরীণ লেনদেন
# বাহ্যিক লেনদেনে কোন অর্থনৈতিক ঘটনা দুটি পক্ষকে বা দুটি প্রতিষ্ঠানকে প্রভাবিত করে
# নগদ টাকার আদানপ্রদান বা বাকিতে ক্রয়বিক্রয় ছাড়াও সেবা আদানপ্রদানের মাধ্যমে লেনদেনের উদ্ভব হতে পারে
# অর্থের আদানপ্রদান বা অর্থের মাপকাঠিতে পরিমাপযোগ্য কোনো ঘটনা বা সেবা আদান প্রদানের মাধ্যমে কোনো প্রতিষ্ঠানের আর্থিক অবস্থার পরিবর্তন ঘটলে ঐ সমস্ত ঘটনা বা আদানপ্রদানকে লেনদেন বলা হয়
# বস্তুত দ্রব্যসামগ্রী ও সেবাকর্মের বিনিময়ের ফলে কোনো ব্যক্তি প্রতিষ্ঠান বা ব্যবসায়ের আর্থিক অবস্থার পরিবর্তন ঘটলে লেনদেনের সৃষ্টি হয়
# প্রত্যেকটি লেনদেনই ঘটনা কিন্তু প্রত্যেকটি ঘটনা লেনদেন নয়
# লেনদেনের একটি উল্লেখযোগ্য বৈশিষ্ট্য হলো ঘটনাকে অবশ্যই অর্থের অঙ্কে পরিমাপযোগ্য হতে হবে নতুবা উক্ত ঘটনাকে লেনদেন বলা যাবে না
# কোনো ঘটনা দ্বারা যদি কোনো প্রতিষ্ঠানের আর্থিক অবস্থার পরিবর্তন সাধিত হয় তবে সেটিই লেনদেন হবে
# প্রতিটি লেনদেনেই দুটি পক্ষ থাকতে হবে একপক্ষ সুবিধা গ্রহণ করবে এবং অন্য পক্ষ সুবিধা প্রদান করবে
# লেনদেনের আরেকটি উল্লেখযোগ্য বৈশিষ্ট্য হলো প্রতিটি লেনদেন স্বয়ংসম্পূর্ণ অর্থাৎ একটি আরেকটি হতে সম্পূর্ণ আলাদা
# লেনদেন দৃশ্যমান ও অদৃশ্যমান উভয়ই হতে পারে
# যে সকল আর্থিক ঘটনা পূর্বে ঘটে গেছে সেগুলোকে ঐতিহাসিক ঘটনা বলা হয়
# প্রতিটি লেনদেনই হিসাব সমীকরণকে প্রভাবিত করে
# লেনদেনের ফলে হিসাব সমীকরণের বিভিন্ন উপাদানে পরিবর্তন সাধিত হয়
# সম্পদদায়মালিকানা স্বত্ব এটি হলো হিসাব সমীকরণ
# মোট সম্পদ বাড়লে মোট দায় অথবা মালিকানা স্বত্ব বাড়বে
# মোট সম্পদ কমলে মোট দায় অথবা মালিকানা স্বত্ব কমবে
# একটি সম্পদ বাড়লে অপর একটি সম্পদ কমবে
# মালিকানা স্বত্ব বাড়লে মোট দায় কমবে
# মালিকানা স্বত্ব কমলে মোট দায় বাড়বে
# প্রতিটি লেনদেনের সমর্থনে এক বা একাধিক প্রমাণপত্র থাকে
# চালান হলো পণ্য ক্রয় এবং বিক্রয়ের একটি প্রামাণ্য দলিল
# বিক্রেতা যখন পণ্য বিক্রয় করেন তখন পণ্যের পূর্ণ বিবরণসংবলিত একটি লিখিত দলিল ক্রেতাকে হস্তান্তর করেন
# ভাউচার দুইপ্রকার  যথা  ডেবিট ভাউচার ক্রেডিট ভাউচার
# ডেবিট ভাউচার  পণ্য ক্রয়ে এবং বিভিন্ন ব্যয়ের স্বপক্ষে ডেবিট ভাউচার ব্যবহৃত হয়
# ডেবিট ভাউচারের সাথে চালান ক্যাশমেমো যুক্ত করে ধারাবাহিকভাবে ভাউচার নম্বর প্রদানপূর্বক ক্যাশবুক বা নগদান রেজিস্ট্রারের ক্রেডিট দিক বা খরচের দিকে লিপিবদ্ধ করা হয়
# পণ্য বিক্রয় ও বিভিন্ন আয়ের জন্য যে ভাউচার ব্যবহার করা হয় তাকে বলা হয় ক্রেডিট ভাউচার
# ক্রেডিট ভাউচারের সাথে চালানের কপি ক্যাশমেমো ইত্যাদি সংযুক্ত করে তাতে ধারাবাহিকভাবে ক্যাশবুকের ডেবিট দিকে অর্থ প্রাপ্তির দিকে লিপিবদ্ধ করা হয়
# নগদ মূল্যে পণ্য ক্রয়বিক্রয়ের ক্ষেত্রে ক্যাশমেমো ব্যবহৃত হয়
# পণ্য বিক্রেতা পণ্য ক্রেতাকে ক্যাশমেমো দিয়ে থাকে
# ক্যাশমেমোর উপরিভাগে বিক্রয় প্রতিষ্ঠানের নাম ও ঠিকানা মুদ্রিত থাকে
# পণ্য বিক্রেতা বিক্রিত পণ্যের নাম পরিমাণ দর মোট মূল্য নিট মূল্য কমিশন ইত্যাদি উল্লেখপূর্বক স্বাক্ষর করে ক্রেতাকে প্রদান করে
# ক্রেতা ক্যাশমেমো অনুসারে পণ্যমূল্য পরিশোধ করে পণ্য গ্রহণ করে থাকে
# সাধারণত ক্যাশমেমো তিন সেট তৈরি করা হয়
# ক্রয়কৃত পণ্য ফরমায়েশ অনুযায়ী না হলে অথবা নিম্নমানের হলে ক্রেতা বিক্রেতাকে বর্ণিত পণ্য ফেরত পাঠায়
# নোটের মাধ্যমে বিক্রেতাকে জানিয়ে দেওয়া হয় যে তার বা তাদের হিসাব খাত উক্ত ফেরত পণ্যের জন্য ডেবিট করা হয়েছে এরূপ নোটকে ডেবিট নোট বলা হয়
# ডেবিট নোট ক্রেতা তৈরি করে থাকেন
# বিক্রেতার কাছে বিক্রীত পণ্য ফেরত এলে বিক্রেতা প্রাপ্ত মালের পূর্ণ বিবরণ যথা  মালের পরিমাণ দর মূল্য একটি কাগজে লিখে ক্রেতার নিকট প্রেরণ করে জানিয়ে দেয় যে তার বা তাদের হিসাব খাত উক্ত ফেরত মালের মূল্যের জন্য ক্রেডিট করা হয়েছে এরূপ নোটকে ক্রেডিট নোট বলা হয়
# ক্রেডিট নোট বিক্রেতা তৈরি করে থাকে
# ব্যবসায়ের সঠিক ফলাফল ও প্রকৃত আর্থিক অবস্থা জানার জন্য দুতরফা দাখিলা পদ্ধতির কোনো বিকল্প নেই
# প্রতিটি লেনদেনে দুই বা ততোধিক হিসাবখাত থাকে একটি হলো ডেবিট অপরটি ক্রেডিট
# দুতরফা দাখিলা পদ্ধতির মাধ্যমে লেনদেনের দুটি পক্ষ অর্থাৎ ডেবিট ও ক্রেডিট পক্ষ লিপিবদ্ধ করা হয়
# দুতরফা দাখিলা পদ্ধতিতে প্রতিটি ডেবিট লিখনের জন্য সমান অর্থের ক্রেডিট লিখন হবে
# সঠিকভাবে হিসাব প্রণয়নের জন্য যে ব্যবস্থায় লেনদেনসমূহের দ্বৈত স্বত্বা যাথাযথভাবে লিপিবদ্ধ করা হয় তাকে দুতরফা দাখিলা পদ্ধতি বলে
# যেহেতু বেতন ব্যবসায় প্রতিষ্ঠানের একটি ব্যয় সেহেতু ব্যয় বৃদ্ধি পাওয়ায় বেতন হিসাব  টাকা ডেবিট হবে
# যেহেতু বেতন প্রদানের ফলে নগদ টাকা ব্যবসায় হতে চলে গিয়েছে সেহেতু নগদ তথা সম্পদ হ্রাস পাওয়াতে নগদান হিসাব  টাকা ক্রেডিট হবে
# বেতন হিসাব যে পরিমাণ ডেবিট হয়েছে নগদান হিসাবটি সমপরিমাণ ক্রেডিট হয়েছে
# হিসাববিজ্ঞানের সবচেয়ে নির্ভরযোগ্য বিজ্ঞানসম্মত পূর্ণাঙ্গ ও স্বয়ংসম্পূর্ণ হিসাব সংরক্ষণ পদ্ধতিই হচ্ছে দুতরফা দাখিলা পদ্ধতি
# দুতরফা দাখিলা পদ্ধতিতে অর্থ বা আর্থিক মূল্যে পরিমাপযোগ্য প্রতিটি লেনদেনকে দ্বৈত স্বত্বায় প্রকাশ করা হয় ফলে একটি হিসাব খাতকে প্রাপ্ত সুবিধার জন্য ডেবিট এবং অপর হিসাব খাতকে প্রদত্ত সুবিধার জন্য ক্রেডিট করা হয়
# প্রতিটি লেনদেনে কমপক্ষে দুটি হিসাব থাকে
# ডেবিট ও ক্রেডিট নির্ণয় করার পূর্বে প্রতিটি লেনদেনে জড়িত হিসাবখাতসমূহ বের করে তাদের প্রত্যেকটি কোন শ্রেণির হিসাব তা নিরূপণ করতে হয়
# দুতরফা দাখিলা অনুযায়ী প্রতিটি হিসাবের ডেবিট ও ক্রেডিট নির্ণয় করতে হয়
# প্রতিটি লেনদেনে সুবিধা গ্রহণকারী গ্রহীতা ও সুবিধা প্রদানকারী দাতা হিসেবে কাজ করে
# সুবিধা গ্রহণকারী হিসাবকে ডেবিট ও সুবিধা প্রদানকারী হিসাবকে ক্রেডিট করা হয়
# প্রতিটি লেনদেনের ডেবিট ও ক্রেডিট টাকার পরিমাণ সমান হবে
# যেহেতু প্রতিটি লেনদেন ডেবিটক্রেডিট বিশ্লেষণ করে সমপরিমাণ টাকার অঙ্ক দ্বারা লিপিবদ্ধ করা হয় সেহেতু সামগ্রিক ফলাফল নির্ণয় সহজ হয়
# মোট লেনদেনের ডেবিট দিকের যোগফল ক্রেডিট দিকের যোগফলের সমান হয়
# প্রতিটি লেনদেনকে ডেবিট ও ক্রেডিট বিশ্লেষণ করে সমপরিমাণ টাকায় লিপিবদ্ধ করা হয় বলে যেকোন লেনদেনের পূর্ণাঙ্গ হিসাব জানা যায়
# দুতরফা দাখিলা পদ্ধতিতে ব্যবসায়ের মুনাফা জাতীয় আয়ব্যয়ের পরিপূর্ণ ও সঠিক হিসাব সংরক্ষণ করা হয় বলে নির্দিষ্ট সময় পরে বিশদ আয় বিবরণী তৈরির মাধ্যমে ব্যবসায়ের নিট মুনাফা বা নিট লোকসান নির্ণয় করা যায়
# প্রতিটি লেনদেনের ডেবিট পক্ষের বিপরীতে সমপরিমাণ অঙ্কের ক্রেডিট দাখিলা লিপিবদ্ধ করতে হয়
# কোনো নির্দিষ্ট তারিখে রেওয়ামিল প্রস্তুত করে হিসাবের গাণিতিক নির্ভুলতা যাচাই করা যায়
# একটি নির্দিষ্ট তারিখে আর্থিক অবস্থার বিবরণী তৈরির মাধ্যমে কারবারের আর্থিক অবস্থা সম্পর্কে ধারণা পাওয়া যায়
# দুতরফা দাখিলা পদ্ধতিতে হিসাব সংরক্ষণ করলে খুব সহজেই ভুল ত্রুটি ও জালিয়াতি চিহ্নিত করে প্রতিরোধের ব্যবস্থা করা যায়
# দুতরফা দাখিলা পদ্ধতিতে অতিরিক্ত ব্যয় সহজেই নিয়ন্ত্রণ করা যায়
# দুতরফা দাখিলা পদ্ধতিতে হিসাব রাখার ফলে ব্যবসায়ের মালিক যেকোন সময় তার মোট পাওনা ও দেনার পরিমাণ চিহ্নিত করে প্রয়োজনীয় ব্যবস্থা গ্রহণ করতে পারে
# দুতরফা দাখিলা পদ্ধতিতে সঠিক হিসাব রাখার ফলে এর ভিত্তিতে নির্ণীত বিভিন্ন কর যথা আয়কর ভ্যাট আমদানি শুল্ক ও রপ্তানি শুল্ক ইত্যাদি কর কর্তৃপক্ষের নিকট গ্রহণযোগ্য হয়
# দুতরফা দাখিলা পদ্ধতিতে প্রতিটি লেনদেনকে বিজ্ঞানসম্মত উপায়ে ডেবিট ক্রেডিট বিশ্লেষণ করে লিপিবদ্ধ করা হয়
# ছোট বড় সকল প্রতিষ্ঠানেই দুতরফা দাখিলা পদ্ধতি সহজে ব্যবহার করা যায়
# দুতরফা দাখিলা পদ্ধতি একটি বিজ্ঞানসম্মত পূর্ণাঙ্গ নির্ভুল স্বয়ং সম্পূর্ণ ও নির্ভরযোগ্য পদ্ধতি বিধায় সমগ্র বিশ্বে দুতরফা দাখিলা পদ্ধতি একটি সর্বজনস্বীকৃত পদ্ধতি হিসেবে গ্রহণযোগ্যতা পেয়েছে
# লেনদেনের ফলে সম্পদ বাড়তে পারে বা কমতে পারে
# সম্পদ বৃদ্ধি পেলে ডেবিট ও সম্পদ হ্রাস পেলে ক্রেডিট হয়
# সম্পদের মতোই লেনদেনের ফলে দায় বৃদ্ধি বা হ্রাস পেতে পারে
# ব্যাংক থেকে ঋণ নিলে দায় বৃদ্ধি পায় আবার ঋণের কিস্তি পরিশোধ করলে দায় হ্রাস পায়
# সম্পদের সাথে দায়ের সম্পর্ক বিপরীত তাই দায় বৃদ্ধি পেলে ক্রেডিট ও হ্রাস পেলে ডেবিট হয়
# ব্যবসায় শুরু করার জন্য মালিক প্রথমে মূলধন আনে ফলে মালিকানা স্বত্ব বৃদ্ধি পায়
# মালিক ব্যবসায় থেকে ব্যক্তিগত প্রয়োজনে উত্তোলন করলে মালিকানা স্বত্ব হ্রাস পায়
# মালিকানা স্বত্ব প্রতিষ্ঠানের জন্য এক ধরনের দায়
# হিসাববিজ্ঞানের নীতি অনুযায়ী মালিক ও ব্যবসায় প্রতিষ্ঠান আলাদা সত্তা
# মালিকানা স্বত্ব বৃদ্ধি পেলে ক্রেডিট এবং হ্রাস পেলে ডেবিট হয়
# ব্যবসায়ের মূল উদ্দেশ্যই হচ্ছে মুনাফা অর্জন করা
# মুনাফা হচ্ছে রেভিনিউ বা আয়ের ঐ অংশ যা ব্যয় অপেক্ষা অধিক
# রেভিনিউ বা আয় মালিকানা স্বত্বের বৃদ্ধি ঘটায়
# রেভিনিউ বা আয় বৃদ্ধি পেলে ক্রেডিট এবং হ্রাস পেলে ডেবিট হয়
# ব্যয় রেভিনিউ বা আয়ের বিপরীত
# রেভিনিউ বা আয় যেহেতু মালিকানা স্বত্বের বৃদ্ধি ঘটায় তাই ব্যয়ের ফলে মালিকানা স্বত্বের হ্রাস ঘটবে
# ব্যবসায়ের ব্যয় মালিকানা স্বত্বকে কমিয়ে দেয়
# ব্যয় বৃদ্ধি পেলে ডেবিট এবং হ্রাস পেলে ক্রেডিট হয়
# লেনদেন সংঘটিত হওয়ার পর তা চিহ্নিত করে দুই তরফা দাখিলা পদ্ধতির নীতি অনুযায়ী ডেবিট ও ক্রেডিট বিশ্লেষণ করে প্রথম যে বইতে লিপিবদ্ধ করা হয় তাকেই প্রাথমিক হিসাবের বই বা জাবেদা বলে
# ক্রয় জাবেদায় ধারে পণ্য ক্রয়সংক্রান্ত লেনদেন লিপিবদ্ধ করা হয়
# বিক্রয় জাবেদায় ধারে পণ্য বিক্রয়সংক্রান্ত লেনদেন লিপিবদ্ধ করা হয়
# ক্রয় ফেরত জাবেদায় ধারে ক্রীত পণ্য ফেরতসংক্রান্ত লেনদেন লিপিবদ্ধ করা হয়
# বিক্রয় ফেরত জাবেদায় ধারে বিক্রীত পণ্য ফেরত এলে তা লিপিবদ্ধ করা হয়
# নগদ অর্থ প্রাপ্তিসংক্রান্ত লেনদেন নগদ প্রাপ্তি জাবেদায় লিপিবদ্ধ করা হয়
# নগদ অর্থ প্রদানসংক্রান্ত লেনদেন নগদ প্রদান জাবেদায় লিপিবদ্ধ করা হয়
# যে সকল লেনদেন উপরোক্ত কেনো প্রাথমিক বইতে লিপিবদ্ধ করা যায় না সেগুলো প্রকৃত জাবেদায় লিপিবদ্ধ করা হয়
# জাবেদায় লিপিবদ্ধকৃত লেনদেনসমূহকে আলাদা আলাদা শ্রেনিবিন্যাস করে উপযুক্ত শিরোনামের হিসাবের ছকে স্থায়ীভাবে লিপিবদ্ধ করার প্রক্রিয়াকে খতিয়ান বলে
# চলমান ধারণা অনুযায়ী ব্যবসায় প্রতিষ্ঠানের কার্যক্রম অনন্তকাল ধরে চলতে থাকবে বলে অনুমান করা হয়
# ব্যবসায়ের হিসাব সংরক্ষণের ধারাবাহিক আবর্তনকেই হিসাব চক্র বলে
# হিসাব চক্রের প্রথম ধাপে ব্যবসায়ের প্রতিটি ঘটনাকে বিশ্লেষণ করে লেনদেন হিসেবে চিহ্নিত করা হয়
# বিশ্লেষণকৃত হিসাবখাতগুলো দুতরফা দাখিলা অনুসারে প্রযোজ্য হিসাবের প্রাথমিক বইতে ডেবিটক্রেডিট বিশ্লেষণ করে তারিখের ক্রমানুসারে জাবেদায় লিপিবদ্ধ করা হয়
# জাবেদায় লিপিবদ্ধকৃত লেনদেনগুলোকে আলাদা আলাদা হিসাবের শিরোনামে লিপিবদ্ধ করা হয়
# প্রতিটি হিসাবখাতের জন্য আলাদা আলাদা খতিয়ান তৈরি করে প্রতিটি হিসাবের নির্দিষ্ট সময়ান্তে উদ্বৃত্ত নির্ণয় করা হয়
# লেনদেনসমূহ নির্ভুলভাবে হিসাব বহিতে লিপিবদ্ধ হয়েছে কি না তা যাচাই করার উদ্দেশ্যে খতিয়ানের ডেবিট উদ্ধৃত্ত ও ক্রেডিট উদ্বৃত্তের সাহায্যে রেওয়ামিল প্রস্তুত করা হয়
# ব্যবসায়ের প্রকৃত আর্থিক অবস্থা নির্ণয়ের জন্য সংশ্লিষ্ট হিসাবকালের প্রাপ্য আয় বকেয়া খরচ অগ্রিম খরচ এবং অনুপার্জিত আয় ইত্যাদি দফাগুলোকে সমন্বয় করতে সমন্বয় দাখিলা প্রদান করা হয়
# আর্থিক বিবরণী প্রস্তুত সহজতর করার উদ্দেশ্যে ঐচ্ছিক কাজ হিসেবে বহুঘরবিশিষ্ট একটি বিবরণী প্রস্তুত করা হয় যাকে কার্যপত্র বলে
# আর্থিক বিবরণী প্রস্তুতের মাধ্যমে ব্যবসায় প্রতিষ্ঠানের লাভক্ষতি সম্পদ দায় ও মালিকানা স্বত্বের পরিমাণ নির্ণয় করা হয়
# কারবারের মুনাফাজাতীয় আয় এবং মুনাফাজাতীয় ব্যয়গুলোর জের ও উত্তোলন হিসাব বছরান্তে বন্ধ করতে হয়
# সমাপনী দাখিলা প্রদানের মাধ্যমে ব্যবসায়ের আয় ব্যয় ও উত্তোলন হিসাব বন্ধ হয়ে যায়
# ইতিহাস শব্দটির উৎপত্তি ইতিহ শব্দ থেকে যার অর্থ ঐতিহ্য
# ঐতিহ্য হচ্ছে অতীতের অভ্যাস শিক্ষা ভাষা শিল্প সাহিত্যসংস্কৃতি যা ভবিষ্যতের জন্য সংরক্ষিত থাকে
# ঐতিহ্যকে এক প্রজন্ম থেকে আরেক প্রজন্মের কাছে পৌঁছে দেয় ইতিহাস
# ইতিহাস হলো বর্তমান ও অতীতের মধ্যে এক অন্তহীন সংলাপ
# বর্তমানের সকল বিষয়ই অতীতের ক্রমবিবর্তন ও অতীত ঐতিহ্যের ওপর ভিত্তি করে গড়ে উঠেছে
# অতীতের ক্রমবিবর্তন ও ঐতিহ্যের বস্তুনিষ্ঠ বিবরণই হলো ইতিহাস
# যেসব তথ্যপ্রমাণের ওপর ভিত্তি করে ঐতিহাসিক সত্যকে প্রতিষ্ঠিত করা সম্ভব তাকেই ইতিহাসের উপাদান বলা হয়
# ইতিহাসের উপাদানকে আবার দুই ভাগে ভাগ করা যায় যথা  লিখিত উপাদান ও অলিখিত উপাদান
# ইতিহাস রচনার লিখিত উপাদানের মধ্যে রয়েছে সাহিত্য বৈদেশিক বিবরণ দলিলপত্র ইত্যাদি
# যেসব বস্তু বা উপাদান থেকে আমরা বিশেষ সময় স্থান বা ব্যক্তি সম্পর্কে বিভিন্ন ধরনের ঐতিহাসিক তথ্য পাই সেই বস্তু বা উপাদানই প্রত্নতত্ত্ব নিদর্শন
# মানব সমাজ সভ্যতার অগ্রগতির সঙ্গে সঙ্গে নতুন নতুন বিষয়ের ইতিহাস লেখা হচ্ছে
# পঠনপাঠন আলোচনা ও গবেষণাকর্মের সুবিধার্থে ইতিহাসকে প্রধানত দুই ভাগে ভাগ করা যায়  যথা ভৌগোলিক অবস্থানগত ও বিষয়বস্তুগত ইতিহাস
# কোনো বিশেষ বিষয়ের ওপর ভিত্তি করে যে ইতিহাস রচিত হয় তাকে বিষয়বস্তুগত ইতিহাস বলা হয়
# মানবসমাজ ও সভ্যতার ধারাবাহিক পরিবর্তনের প্রমাণ ও লিখিত দলিল হলো ইতিহাস
# সত্যনিষ্ঠ তথ্যের সাহায্যে অতীতের পুনর্গঠন করাই ইতিহাসের বৈশিষ্ট্য
# ইতিহাসের আলোচনার বিষয় হচ্ছে মানবসমাজ ও সভ্যতার অগ্রগতির ধারাবাহিক তথ্যনির্ভর বিবরণ
# ইতিহাস থেমে থাকে না এটি গতিশীল এবং বহমান
# ঘটে যাওয়া ঘটনার সঠিক বিবরণ পরবর্তী প্রজন্মের কাছে তুলে ধরাও ইতিহাসের বৈশিষ্ট্য
# মানুষের চিন্তাভাবনা পরিকল্পনা কার্যক্রম যত শাখাপ্রশাখায় বিস্তৃত ইতিহাসের সীমাও ততদূর পর্যন্ত বিস্তৃত
# আদিম যুগের মানুষ কৃষিকাজ জানত না
# মানুষ পাথর ভেঙে ঘষে ঘষে ধারালো অস্ত্র তৈরি করতে শেখে
# পাথর যুগের প্রথম পর্যায়কে বলা হতো পুরনো পাথরের যুগ বা পুরোপলীয় যুগ
# মানুষ পাথরের অস্ত্র দিয়ে দলবদ্ধভাবে পশু শিকার করত
# পুরনো পাথরের যুগ শেষ হয় মানুষের যাযাবর জীবনের অবসান ঘটিয়ে কৃষিভিত্তিক সমাজ প্রতিষ্ঠার মাধ্যমে এ যুগকে বলা হয় নতুন পাথরের যুগ বা নবোপলীয় যুগ
# কৃষির প্রয়োজনে এ যুগে মানুষ নদীর তীরে বসবাস শুরু করে
# আফ্রিকা মহাদেশের উত্তরপূর্ব অংশে বর্তমানে যে দেশটির নাম ইজিপ্ট সেই দেশেরই প্রাচীন নাম মিশর
# মিশরীয় সভ্যতার গোড়াপত্তন হয় মেনেসের নেতৃত্বে যা প্রায় তিন হাজার বছর ধরে স্বমহিমায় উজ্জ্বল ছিল
# প্রাকরাজবংশীয় যুগে মিশর কতকগুলো ছোট নগর রাষ্ট্রে বিভক্ত ছিল
# মিশরের প্রথম রাজা বা ফারাও মেনেস বা নারমার সমগ্র মিশরকে খ্রিষ্টপূর্ব  অব্দে ঐক্যবদ্ধ করে একটি রাজ্য গড়ে তোলেন যার রাজধানী ছিল দক্ষিণ মিশরের মেম্ফিসে
# পেশার ওপর ভিত্তি করে মিশরীয়দের কয়েকটি শ্রেণিতে ভাগ করা যায় যেমন রাজপরিবার পুরোহিত অভিজাত লিপিকার ব্যবসায়ী শিল্পী এবং কৃষক ও ভূমিদাস শ্রেণি
# মিশরের অর্থনীতি মূলত ছিল কৃষিনির্ভর
# ব্যবসাবাণিজ্যেও মিশর ছিল অগ্রগামী
# মিশরে উৎপাদিত গম লিনেন কাপড় ও মাটির পাত্র ক্রিট দ্বীপ ফিনিশিয়া ফিলিস্তিন ও সিরিয়ায় রপ্তানি হতো
# বিভিন্ন দেশ থেকে মিশরীয়রা স্বর্ণ রৌপ্য হাতির দাঁত কাঠ ইত্যাদি আমদানি করত
# মিশরের নীল নদের উৎপত্তি আফ্রিকার লেক ভিক্টোরিয়া থেকে
# প্রাচীন সভ্যতায় মিশরীয়দের অবদান অস্বীকার করার উপায় নেই
# মিশরীয়দের অন্যতম বৈশিষ্ট্য হচ্ছে যে তাদের জীবন ধর্মীয় চিন্তা ও বিশ্বাস দ্বারা প্রভাবিত ছিল
# সম্ভবত প্রাচীন মিশরীয়দের মতো অন্য কোনো জাতি জীবনের সকল ক্ষেত্রে এতটা ধর্মীয় নিয়মকানুন অনুশাসন দ্বারা প্রভাবিত ছিল না
# মিশরীয়দের ধারণা ছিল সূর্যদেবতা রে বা আমন রে এবং প্রাকৃতিক শক্তি শস্য ও নীল নদের দেবতা ওসিরিস মিলিতভাবে সমগ্র পৃথিবী পরিচালিত করেন
# মিশরীয়রা মনে করত মৃত ব্যক্তি আবার একদিন বেঁচে উঠবে
# মমিকে রক্ষার জন্য তারা পিরামিড তৈরি করেছিল
# ফারাওরা স্রষ্টার প্রতিনিধি হিসেবে দেশ শাসন করত
# স্ফিংক্স হচ্ছে এমন একটি মূর্তি যার দেহ সিংহের মতো কিন্তু মুখ মানুষের মতো
# মিশরের সবচেয়ে বড় পিরামিড হচ্ছে ফারাও খুফুর পিরামিড
# মিশরীয় সভ্যতার অন্যতম প্রধান বৈশিষ্ট্য ছিল লিপি বা অক্ষর আবিষ্কার
# ধর্মের কারণে মিশরীয়রা বিজ্ঞানচর্চায় আগ্রহী ছিল
# তারা পরলোকে বিশ্বাস করত এবং ফারাওরা পরবর্তী জন্মেও রাজা হবেন এই বিশ্বাস তাদের ছিল
# মিশরীয় বিজ্ঞানীরা রাসায়নিক প্রক্রিয়ায় মৃতদেহ পচন থেকে রক্ষা করতে সক্ষম হন
# মিশরীয়রা দর্শন ও সাহিত্যচর্চা করত
# সিন্ধু নদের অববাহিকায় গড়ে উঠেছিল বলে এই সভ্যতার নাম রাখা হয় সিন্ধুসভ্যতা
# সিন্ধু সভ্যতার সংস্কৃতিকে অনেক সময়ে হরপ্পা সংস্কৃতি বা হরপ্পা সভ্যতা বলা হয়ে থাকে
# উপমহাদেশের প্রাচীনতম সিন্ধুসভ্যতার বিস্তৃতি বিশাল এলাকা জুড়ে
# সিন্ধুসভ্যতার জনগণের রাজনৈতিক জীবন ও শাসনপ্রণালি সম্পর্কে কিছুই জানা যায় না
# পোশাকপরিচ্ছদের জন্য তারা মূলত সুতা ও পশম ব্যবহার করত
# কৃষি ও পশুপালনের পাশাপাশি মৃৎপাত্র নির্মাণ ধাতুশিল্প বয়নশিল্প অলঙ্কার নির্মাণ পাথরের কাজ ইত্যাদিতেও তারা যথেষ্ট উন্নতি লাভ করেছিল
# সিন্ধুসভ্যতায় কোনো মন্দির বা মঠের চিহ্ন পাওয়া যায়নি যে কারণে তাদের ধর্মবিশ্বাস সম্পর্কে সুস্পষ্ট ধারণা করা সম্ভব নয়
# পৃথিবীর প্রাচীনতম সভ্যতাগুলোর মধ্যে অন্যতম হচ্ছে সিন্ধুসভ্যতা
# সিন্ধুসভ্যতার এলাকায় যেসব শহর আবিষ্কৃত হয়েছে তার মধ্যে হরপ্পা ও মহেঞ্জোদারো সবচেয়ে বড় শহর
# সিন্ধুসভ্যতা যুগের অধিবাসীরা দ্রব্যের ওজন পরিমাপ করতে শিখেছিল
# সিন্ধুসভ্যতা যুগের অধিবাসীদের শিল্পবোধ সম্পর্কে আলোচনা করতে গেলে প্রথমেই মৃৎশিল্পের কথা বলতে হয়
# অলঙ্কারের মধ্যে আংটি বালা নাকফুল গলার হার কানের দুল বাজুবন্ধ ইত্যাদি ছিল উল্লেখযোগ্য
# সিন্ধুসভ্যতা যুগের অধিবাসীরা লোহার ব্যবহার জানত না
# সিন্ধুসভ্যতা যুগের অধিবাসীরা গুরুত্বপূর্ণ এবং চমৎকার স্থাপত্যশৈলীর নিদর্শন রেখে গেছে
# মহেঞ্জোদারোর স্থাপত্যের উল্লেখযোগ্য উদাহরণ হলো বৃহৎ মিলনায়তন যা  ফুট জায়গা জুড়ে তৈরি হয়েছিল
# গ্রিসের মহাকবি হোমারের ইলিয়াড ও ওডিসি মহাকাব্য দুটিতে বর্ণিত চমকপ্রদ কাহিনির মধ্যে লুকিয়ে থাকা সত্যকে খুঁজে বের করার অদম্য ইচ্ছা উৎসাহিত করে তোলে প্রত্নতত্ত্ববিদদের
# ইজিয়ান সাগরের দ্বীপপুঞ্জে এবং এশিয়া মাইনরের পশ্চিম উপকূলে আবিষ্কৃত হয় উন্নত এক প্রাচীন নগর সভ্যতা
# মিনিয়ন সভ্যতা  ক্রিট দ্বীপে যে সভ্যতার উদ্ভব এর স্থায়িত্ব ধরা হয়েছে  থেকে  খ্রিষ্টপূর্বাব্দ পর্যন্ত
# মাইসিনিয় বা ইজিয়ান সভ্যতা  গ্রিসের মূল ভূখণ্ডে দক্ষিণ অঞ্চলে অবস্থিত মাইসিনি নগরের নাম অনুসারে এর নামকরণ হয়
# ইতিহাস শব্দটির উৎপত্তি ইতিহ শব্দ থেকে যার অর্থ ঐতিহ্য
# ঐতিহ্য হচ্ছে অতীতের অভ্যাস শিক্ষা ভাষা শিল্প সাহিত্যসংস্কৃতি যা ভবিষ্যতের জন্য সংরক্ষিত থাকে
# ঐতিহ্যকে এক প্রজন্ম থেকে আরেক প্রজন্মের কাছে পৌঁছে দেয় ইতিহাস
# ইতিহাস হলো বর্তমান ও অতীতের মধ্যে এক অন্তহীন সংলাপ
# বর্তমানের সকল বিষয়ই অতীতের ক্রমবিবর্তন ও অতীত ঐতিহ্যের ওপর ভিত্তি করে গড়ে উঠেছে
# অতীতের ক্রমবিবর্তন ও ঐতিহ্যের বস্তুনিষ্ঠ বিবরণই হলো ইতিহাস
# যেসব তথ্যপ্রমাণের ওপর ভিত্তি করে ঐতিহাসিক সত্যকে প্রতিষ্ঠিত করা সম্ভব তাকেই ইতিহাসের উপাদান বলা হয়
# ইতিহাসের উপাদানকে আবার দুই ভাগে ভাগ করা যায় যথা  লিখিত উপাদান ও অলিখিত উপাদান
# ইতিহাস রচনার লিখিত উপাদানের মধ্যে রয়েছে সাহিত্য বৈদেশিক বিবরণ দলিলপত্র ইত্যাদি
# যেসব বস্তু বা উপাদান থেকে আমরা বিশেষ সময় স্থান বা ব্যক্তি সম্পর্কে বিভিন্ন ধরনের ঐতিহাসিক তথ্য পাই সেই বস্তু বা উপাদানই প্রত্নতত্ত্ব নিদর্শন
# মানব সমাজ সভ্যতার অগ্রগতির সঙ্গে সঙ্গে নতুন নতুন বিষয়ের ইতিহাস লেখা হচ্ছে
# পঠনপাঠন আলোচনা ও গবেষণাকর্মের সুবিধার্থে ইতিহাসকে প্রধানত দুই ভাগে ভাগ করা যায়  যথা ভৌগোলিক অবস্থানগত ও বিষয়বস্তুগত ইতিহাস
# কোনো বিশেষ বিষয়ের ওপর ভিত্তি করে যে ইতিহাস রচিত হয় তাকে বিষয়বস্তুগত ইতিহাস বলা হয়
# মানবসমাজ ও সভ্যতার ধারাবাহিক পরিবর্তনের প্রমাণ ও লিখিত দলিল হলো ইতিহাস
# সত্যনিষ্ঠ তথ্যের সাহায্যে অতীতের পুনর্গঠন করাই ইতিহাসের বৈশিষ্ট্য
# ইতিহাসের আলোচনার বিষয় হচ্ছে মানবসমাজ ও সভ্যতার অগ্রগতির ধারাবাহিক তথ্যনির্ভর বিবরণ
# ইতিহাস থেমে থাকে না এটি গতিশীল এবং বহমান
# ঘটে যাওয়া ঘটনার সঠিক বিবরণ পরবর্তী প্রজন্মের কাছে তুলে ধরাও ইতিহাসের বৈশিষ্ট্য
# মানুষের চিন্তাভাবনা পরিকল্পনা কার্যক্রম যত শাখাপ্রশাখায় বিস্তৃত ইতিহাসের সীমাও ততদূর পর্যন্ত বিস্তৃত
# আদিম যুগের মানুষ কৃষিকাজ জানত না
# মানুষ পাথর ভেঙে ঘষে ঘষে ধারালো অস্ত্র তৈরি করতে শেখে
# পাথর যুগের প্রথম পর্যায়কে বলা হতো পুরনো পাথরের যুগ বা পুরোপলীয় যুগ
# মানুষ পাথরের অস্ত্র দিয়ে দলবদ্ধভাবে পশু শিকার করত
# পুরনো পাথরের যুগ শেষ হয় মানুষের যাযাবর জীবনের অবসান ঘটিয়ে কৃষিভিত্তিক সমাজ প্রতিষ্ঠার মাধ্যমে এ যুগকে বলা হয় নতুন পাথরের যুগ বা নবোপলীয় যুগ
# কৃষির প্রয়োজনে এ যুগে মানুষ নদীর তীরে বসবাস শুরু করে
# আফ্রিকা মহাদেশের উত্তরপূর্ব অংশে বর্তমানে যে দেশটির নাম ইজিপ্ট সেই দেশেরই প্রাচীন নাম মিশর
# মিশরীয় সভ্যতার গোড়াপত্তন হয় মেনেসের নেতৃত্বে যা প্রায় তিন হাজার বছর ধরে স্বমহিমায় উজ্জ্বল ছিল
# প্রাকরাজবংশীয় যুগে মিশর কতকগুলো ছোট নগর রাষ্ট্রে বিভক্ত ছিল
# মিশরের প্রথম রাজা বা ফারাও মেনেস বা নারমার সমগ্র মিশরকে খ্রিষ্টপূর্ব  অব্দে ঐক্যবদ্ধ করে একটি রাজ্য গড়ে তোলেন যার রাজধানী ছিল দক্ষিণ মিশরের মেম্ফিসে
# পেশার ওপর ভিত্তি করে মিশরীয়দের কয়েকটি শ্রেণিতে ভাগ করা যায় যেমন রাজপরিবার পুরোহিত অভিজাত লিপিকার ব্যবসায়ী শিল্পী এবং কৃষক ও ভূমিদাস শ্রেণি
# মিশরের অর্থনীতি মূলত ছিল কৃষিনির্ভর
# ব্যবসাবাণিজ্যেও মিশর ছিল অগ্রগামী
# মিশরে উৎপাদিত গম লিনেন কাপড় ও মাটির পাত্র ক্রিট দ্বীপ ফিনিশিয়া ফিলিস্তিন ও সিরিয়ায় রপ্তানি হতো
# বিভিন্ন দেশ থেকে মিশরীয়রা স্বর্ণ রৌপ্য হাতির দাঁত কাঠ ইত্যাদি আমদানি করত
# মিশরের নীল নদের উৎপত্তি আফ্রিকার লেক ভিক্টোরিয়া থেকে
# প্রাচীন সভ্যতায় মিশরীয়দের অবদান অস্বীকার করার উপায় নেই
# মিশরীয়দের অন্যতম বৈশিষ্ট্য হচ্ছে যে তাদের জীবন ধর্মীয় চিন্তা ও বিশ্বাস দ্বারা প্রভাবিত ছিল
# সম্ভবত প্রাচীন মিশরীয়দের মতো অন্য কোনো জাতি জীবনের সকল ক্ষেত্রে এতটা ধর্মীয় নিয়মকানুন অনুশাসন দ্বারা প্রভাবিত ছিল না
# মিশরীয়দের ধারণা ছিল সূর্যদেবতা রে বা আমন রে এবং প্রাকৃতিক শক্তি শস্য ও নীল নদের দেবতা ওসিরিস মিলিতভাবে সমগ্র পৃথিবী পরিচালিত করেন
# মিশরীয়রা মনে করত মৃত ব্যক্তি আবার একদিন বেঁচে উঠবে
# মমিকে রক্ষার জন্য তারা পিরামিড তৈরি করেছিল
# ফারাওরা স্রষ্টার প্রতিনিধি হিসেবে দেশ শাসন করত
# স্ফিংক্স হচ্ছে এমন একটি মূর্তি যার দেহ সিংহের মতো কিন্তু মুখ মানুষের মতো
# মিশরের সবচেয়ে বড় পিরামিড হচ্ছে ফারাও খুফুর পিরামিড
# মিশরীয় সভ্যতার অন্যতম প্রধান বৈশিষ্ট্য ছিল লিপি বা অক্ষর আবিষ্কার
# ধর্মের কারণে মিশরীয়রা বিজ্ঞানচর্চায় আগ্রহী ছিল
# তারা পরলোকে বিশ্বাস করত এবং ফারাওরা পরবর্তী জন্মেও রাজা হবেন এই বিশ্বাস তাদের ছিল
# মিশরীয় বিজ্ঞানীরা রাসায়নিক প্রক্রিয়ায় মৃতদেহ পচন থেকে রক্ষা করতে সক্ষম হন
# মিশরীয়রা দর্শন ও সাহিত্যচর্চা করত
# সিন্ধু নদের অববাহিকায় গড়ে উঠেছিল বলে এই সভ্যতার নাম রাখা হয় সিন্ধুসভ্যতা
# সিন্ধু সভ্যতার সংস্কৃতিকে অনেক সময়ে হরপ্পা সংস্কৃতি বা হরপ্পা সভ্যতা বলা হয়ে থাকে
# ...
# তখন প্রাকৃতিক শক্তির প্রতীক হিসেবে মুখে মুখে প্রচলিত গল্পকাহিনির বিষয় হয়ে ওঠে দেবদেবী পুরোহিত গোষ্ঠীপতি ও রাজাদের কীর্তিকাণ্ড
# দৈনন্দিন জীবনযাপনের ভাষায় তথা গদ্যে কাহিনি লেখার উদ্ভব ঘটে ইতিহাসের এক বিশেষ পর্বে
# মুখে মুখে রচিত কাহিনি যেমন রূপকথা উপকথা পুরাণ জাতকের গল্প ইত্যাদি পরে গদ্যে লিপিবদ্ধ হলেও মানুষ এবং মানুষের জীবন ওইসব কাহিনির প্রধান বিষয় হতে পারেনি
# রেনেসাঁসের মধ্য দিয়ে রাষ্ট্র থেকে ধর্মকে বিচ্ছিন্ন করে সেক্যুলারিজম প্রতিষ্ঠিত হলে বিজ্ঞান ও দর্শনের অগ্রগতি বাধাহীন হয়ে ওঠে
# উপন্যাস রচনার ক্ষেত্রে উনিশ শতক খুবই তাৎপর্যবহ
# উপন্যাসশিল্পকে বিকাশের শীর্ষ স্তরে পৌঁছে দেয়া এসব মহৎ উপন্যাস পাঠকের মনকে যুক্ত করে বৃহত্তর জগৎ ও জীবনের সঙ্গে
# উপন্যাস বিভিন্ন প্রকারের হতে পারে কখনও তা কাহিনিনির্ভর কখনও চরিত্রনির্ভর কখনও মনস্তাত্ত্বিক কখনও বক্তব্যধর্মী
# বিষয় চরিত্র প্রবণতা এবং গঠনগত সৌকর্যের ভিত্তিতে উপন্যাসকে নানা শ্রেণিতে ভাগ করা যেতে পারে
# যে উপন্যাসে সামাজিক বিষয় রীতিনীতি ব্যক্তি মানুষের দ্বন্দ্ব আশাআকাঙ্ক্ষার প্রাধান্য থাকে তাকে সামাজিক উপন্যাস বলা হয়
# জাতীয় জীবনের গুরুত্বপূর্ণ কোনো ঐতিহাসিক ঘটনা বা চরিত্রের আশ্রয়ে যখন কোনো উপন্যাস রচিত হয় তখন তাকে ঐতিহাসিক উপন্যাস বলে
# ঐতিহাসিক উপন্যাসে লেখক নতুন নতুন ঘটনা বা চরিত্র সৃজন করে কাহিনিতে গতিময়তা ও প্রাণসঞ্চার করতে পারেন কিন্তু ঐতিহাসিক সত্য থেকে বিচ্যুত হতে পারেন না
# মনস্তাত্ত্বিক উপন্যাসের প্রধান আশ্রয় পাত্রপাত্রীর মনোজগতের ঘাতসংঘাত ও ক্রিয়াপ্রতিক্রিয়া
# চরিত্রের অন্তর্জগতের জটিল রহস্য উদ্ঘাটনই ঔপন্যাসিকের প্রধান লক্ষ্য
# সামাজিক উপন্যাস ও মনস্তাত্ত্বিক উপন্যাসে নৈকট্যও লক্ষ করা যায়
# সামাজিক উপন্যাসে যেমন মনস্তাত্ত্বিক ঘাতপ্রতিঘাত থাকতে পারে তেমনি মনস্তাত্ত্বিক উপন্যাসেও সামাজিক ঘাতপ্রতিঘাত থাকতে পারে
# মনস্তাত্ত্বিক উপন্যাসে কাহিনি অবলম্বন মাত্র প্রকৃত উদ্দেশ্য থাকে মানবমনের জটিল দিকগুলো সার্থক বিশ্লেষণের মাধ্যমে উপস্থাপন করা
# সমাজবিকাশের অন্যতম চালিকাশক্তি যে রাজনীতি সেই রাজনৈতিক ঘটনাবলি রাজনৈতিক মতাদর্শ এবং রাজনীতিসংশ্লিষ্ট চরিত্রের কর্মকাণ্ড যে উপন্যাসে প্রাধান্য লাভ করে তাকে রাজনৈতিক উপন্যাস বলে
# রাজনৈতিক উপন্যাসে রাজনৈতিক ক্ষোভবিক্ষোভ আন্দোলনসংগ্রাম স্বাধীনতা ও মুক্তির আকাঙ্ক্ষা সমাজ ও রাষ্ট্রের বিপুল পরিবর্তনের ইঙ্গিত স্পষ্ট হয়ে ওঠে
# অঞ্চল বিশেষের মানুষ ও তাদের যাপিত জীবন এবং স্থানিক রং ও স্থানিক পরিবেশবিধৌত জীবনাচরণ নিয়ে যে উপন্যাস লেখা হয় তাকে আঞ্চলিক উপন্যাস বলা হয়
# রহস্যোপন্যাসে ঔপন্যাসিকের প্রধান লক্ষ্য রহস্যময়তা সৃষ্টি এবং উপন্যাসের উপান্ত পর্যন্ত তা ধরে রাখা
# মানুষের মনোলোকে বর্তমানের অভিজ্ঞতা অতীতের স্মৃতি এবং ভবিষ্যতের কল্পনা এক সঙ্গে প্রবাহিত হয় এই প্রবাহের ভাষিক বর্ণনা দিয়ে চেতনাপ্রবাহ রীতির উপন্যাস লিখিত হয়
# ঔপন্যাসিক তাঁর ব্যক্তিগত জীবনের নানা ঘাতপ্রতিঘাতকে যখন আন্তরিক শিল্পকুশলতায় উপন্যাসে রূপদান করেন তখন তাকে আত্মজৈবনিক উপন্যাস বলে
# আত্মজৈবনিক উপন্যাসে লেখকের ঔপন্যাসিক কল্পনার উপর প্রভাব বিস্তার করে থাকে তাঁর ব্যক্তি জীবনের নানা অন্তর্ময় বৈশিষ্ট্যমণ্ডিত ঘটনাসূত্র
# সাহিত্যের রূপকাশ্রয় কোনো ব্যতিক্রমী ঘটনা নয়
# কখনো কখনো ঔপন্যাসিক তাঁর রচনায় উপস্থাপিত কাহিনি কাঠামোর অন্তরালে কোনো বিশেষ ব্যতিক্রমধর্মী রূপকাশ্রয়ী বক্তব্যের সাহায্যে উপন্যাসের শিল্পরূপ প্রদান করেন এ ধরনের উপন্যাসকে রূপক উপন্যাস বলা হয়
# প্রখ্যাত ইংরেজ লেখক জর্জ অরওয়েলের রূপক উপন্যাস অ্যানিমেল ফার্ম যেখানে পাত্রপাত্রী মানুষ নয় জন্তুজানোয়ার
# বাংলা ভাষায় উপন্যাস লেখার সূচনা ঘটে উনিশ শতকে
# বাংলা সাহিত্যে প্রথম সার্থক উপন্যাস লেখেন বঙ্কিমচন্দ্র চট্টোপাধ্যায়
# বঙ্কিমচন্দ্রের অধিকাংশ উপন্যাসেই অতীতচারী কল্পনার প্রাধান্য এবং সমকালীন জীবনের স্বল্প উপস্থিতি লক্ষ করা যায়
# বঙ্কিমপরবর্তী বাংলা উপন্যাসের ধারায় প্রধান শিল্পী রবীন্দ্রনাথ ঠাকুর
# আধুনিক চিন্তাচেতনার প্রকাশ ঘটিয়ে রবীন্দ্রনাথ সামাজিক পারিবারিক মনস্তাত্ত্বিক ও ব্যক্তিজীবনের সংকটমুখ্য কাহিনি রচনা করেছেন
# বিশ শতকের দ্বিতীয় দশকের শেষে বাংলা উপন্যাস তুমুলভাবে জনপ্রিয় হয়ে ওঠে আর জনপ্রিয়তম ঔপন্যাসিক হয়ে ওঠেন শরৎচন্দ্র চট্টোপাধ্যায়
# শরৎচন্দ্রের উপন্যাসের বিষয় বাঙালি মধ্যবিত্ত ও নিম্নবিত্ত হিন্দু সমাজের গ্রামীণ ও গার্হস্থ্য জীবনের সুখদুঃখের কাহিনি
# রবীন্দ্রনাথ ও শরৎচন্দ্রের সময়ে প্রতিষ্ঠিত সামাজিক বাস্তবতা দ্রুত বদলে যায়
# মানুষের পারিবারিক জীবনে নতুন মাত্রা যোগ করে শিক্ষার প্রসার ও অর্থনৈতিক সংকট
# একদিকে প্রথম বিশ্বযুদ্ধের নেতিবাচক প্রভাব এবং অন্যদিকে ব্রিটিশবিরোধী আন্দোলনের প্রেরণা সাধারণ মানুষকে যেমন করে তোলে অস্থির তেমনি তাকে করে তোলে অধিকারসচেতন
# এক ঐতিহাসিক পটভূমিতেই বাংলা সাহিত্যে মীর মশাররফ হোসেন মোজাম্মেল হক কাজী ইমদাদুল হক নজিবর রহমান প্রমুখ লেখকের আবির্ভাব ঘটে
# সৈয়দ ওয়ালীউল্লাহর প্রথম উপন্যাস লালসালু
# লালসালু রচনাটিকে একজন প্রতিভাবান লেখকের দুঃসাহসী প্রচেষ্টার সার্থক ফসল বলে বিবেচনা করা হয়
# লালসালু উপন্যাসের শৈল্পিক সার্থকতার প্রশ্নে সুসংহত কাহিনিবিন্যাসের চাইতে চরিত্র নির্মাণের কুশলতার দিকটি ভূমিকা রেখেছে অনেক বেশি
# মজিদ একটি প্রতীকী চরিত্র কুসংস্কার শঠতা প্রতারণা এবং অন্ধবিশ্বাসের প্রতীক সে
# খালেক ব্যাপারী লালসালু উপন্যাসের অন্যতম প্রতিনিধিত্বশীল চরিত্র
# লালসালু উপন্যাসের প্রথম থেকে শেষ পর্যন্ত খালেক ব্যাপারীর উপস্থিতি থাকলেও সে কখনোই আত্মমর্যাদাশীল ও ব্যক্তিত্বসম্পন্ন হয়ে উঠতে পারেনি
# ধর্মব্যবসায়ীরা আধ্যাত্মিক শক্তির অধিকারী হিসেবে জাহির করে সাধারণ মানুষের ওপর প্রভুত্ব করে
# লালসালু উপন্যাসে মজিদ ও খালেক ব্যাপারীর পরিবার ছাড়া আরেকটি পরিবারের কাহিনি গুরুত্ব লাভ করেছে
# লালসালু উপন্যাসের কাহিনি অত্যন্ত সুসংহত ও সুবিন্যস্ত
# কাহিনিগ্রন্থনায় লেখক অসামান্য পরিমিতিবোধের পরিচয় দিয়েছেন
# উপন্যাসের শুরু থেকে শেষ পর্যন্ত কাহিনির বিভিন্ন পর্যায়ে নাট্যিক সংবেদনা সৃষ্টিতে লেখক প্রদর্শন করেছেন অপূর্ব শিল্পনৈপুণ্য
# বাংলাদেশের গ্রামীণ জীবনের বাস্তবতা ধর্মতন্ত্র ও ধর্মবোধের দ্বন্দ্ব ধর্মতন্ত্রআশ্রয়ী ব্যবসাবৃত্তি ও ব্যক্তির মূলীভূত হওয়ার প্রতারণাপূর্ণ প্রয়াস অর্থনৈতিক ক্ষমতাকাঠামোর সঙ্গে ধর্মতন্ত্রের অবিচ্ছেদ্য নাড়ির যোগ প্রভৃতি বিষয়কে লেখক এক স্বাতন্ত্র্যমণ্ডিত ভাষায় রূপায়ণ করেছেন
# লালসালু উপন্যাসের কেন্দ্রীয় চরিত্র শেকড়হীন বৃক্ষপ্রতিম মজিদ ধর্মকে আশ্রয় করে মহব্বনগরে প্রতিষ্ঠাঅর্জনে প্রয়াসী হলেও তার মধ্যে সর্বদাই কার্যকর থাকে অস্তিত্বের এক সূক্ষ্মতর সংকট
# বাগযন্ত্রের দ্বারা উচ্চারিত অর্থবোধক ধ্বনির মাধ্যমে মানুষের মনোভাব প্রকাশ করাকে ভাষা বলে
# প্রতিটি সচল ও শুদ্ধ ভাষার মতো বাংলা ভাষারও দুটো রূপ ক মৌখিক ও খ লৈখিক
# মৌখিক ভাষার আবার দুটো রূপ  ক মান মৌখিক ভাষা ও খ আঞ্চলিক মৌখিক ভাষা
# লৈখিক ভাষারও দুটো রূপ  ক সাধু ভাষা ও খ চলিত ভাষা
# পরিমার্জিত ও সার্বজনীন মৌখিক ভাষাকে মান মৌখিক ভাষা বলে
# বিভিন্ন অঞ্চলের কথ্যরীতির ভাষা আঞ্চলিক মৌখিক ভাষার অন্তর্ভুক্ত
# যে ভাষা প্রধানত তৎসম শব্দবহুল সর্বনাম ও ক্রিয়াপদসমূহ অপেক্ষাকৃত দীর্ঘ অনেকটা গুরুগম্ভীর ও কৃত্রিম তাকেই সাধু ভাষা বলে
# অতৎসম শব্দবহুলতা সর্বনাম ও ক্রিয়াপদের অপেক্ষাকৃত সংক্ষিপ্ত রূপ তাকেই চলিত ভাষা বলে
# ব্যাকরণ শব্দটির ব্যুৎপত্তিগত অর্থ হলো বিশেষভাবে বিশ্লেষণ
# যে শাস্ত্রে কোনো ভাষার বিভিন্ন উপাদানের মৌল প্রকৃতি ও স্বরূপের বিচারবিশ্লেষণ করা হয় এবং বিভিন্ন উপাদানের পারস্পরিক সম্পর্ক নির্ণয় ও তার প্রয়োগবিধি বিশদভাবে আলোচিত হয় তাকে ব্যাকরণ বলে
# যে বিদ্যার দ্বারা কোনো ভাষাকে বিশ্লেষণ করিয়া তাহার স্বরূপটি আলোচিত হয় এবং সেই ভাষার পঠনে ও লিখনে এবং তাহাতে কথোপকথনে শুদ্ধরূপে তাহার প্রয়োগ করা যায় সেই বিদ্যাকে সেই ভাষার ব্যাকরণ বলে
# ব্যাকরণকে বলা হয় ভাষার সংবিধান সুতরাং ভাষার মৌলিক স্বরূপ ও বৈশিষ্ট্য নির্ণয়ে ব্যাকরণ পাঠ অত্যাবশ্যক
# ব্যাকরণ ভাষাকে চলতে নির্দেশ দেয় না কিংবা শাসন করে না বরং ভাষাই ব্যাকরণকে শাসন করে বা চলতে নির্দেশ দেয় কিংবা ব্যাকরণ ভাষার বর্ণনা করে মাত্র
# ভাষা ব্যাকরণ অনুসরণ করে না ব্যাকরণই ভাষাকে অনুসরণ করে
# ব্যাকরণ ভাষাকে নিয়ন্ত্রণ করে না নির্মাণও করে না তবু ব্যাকরণ পাঠের প্রয়োজনকে অস্বীকার করা যায় না
# শব্দের যথাযথ উচ্চারণের জন্য নিয়ম বা সূত্রের সমষ্টিকে উচ্চারণরীতি বলে
# স্বাধীনতা উত্তর বাংলা একাডেমি বাংলা বানান সংস্কারে অসামান্য সাহসী ভূমিকা রেখেছিল
# যে শব্দ দ্বারা সুনির্দিষ্টভাবে কোনো ব্যক্তি স্থান দেশ দিন মাস বই গল্প নাটক উপন্যাস কবিতা পত্রিকা চিত্রকর্ম শিল্পকর্ম ইত্যাদির নাম বোঝায় তাকে সংজ্ঞা বা নামবাচক বিশেষ্য বলে
# যে শব্দ দ্বারা কোনো প্রাণী উদ্ভিদ পদার্থ বা অন্য কোনো বা শ্রেণির নাম বোঝায় তাকে সাধারণ বিশেষ্য বলে
# যে বিশেষ্য দ্বারা কোনো ক্রিয়া বা কাজের নাম বোঝায় তাকে ক্রিয়াবিশেষ্য বলে
# বিশেষণের সাথে বিশেষ্যকারী অন্ত্যপ্রত্যয় যোগ করে যে বিশেষ্য গঠিত হয় তাকে বিশেষণজাত বিশেষ্য বলে
# প্রয়োগজনিত কারণে যে বিশেষণ কখনো বিশেষ্যের ভূমিকা গ্রহণ করে তাকে প্রয়োগনির্ধারিত বিশেষ্য বা প্রয়োগ বিশেষ্য বলে
# যেসব সংখ্যাবাচক শব্দ বা বিভক্তিযুক্ত বিশেষণ কখনো কখনো বিশেষ্য হিসেবে ব্যবহৃত হয় তাদের অন্বয়গত বিশেষ্য বলে
# ব্যাকরণগত অবস্থানের ভিত্তিতে বাংলা ভাষার শব্দসমূহকে যে কয় ভাগে বিভক্ত করা হয়েছে তাদের ব্যাকরণিক শব্দশ্রেণি বলে
# যে শব্দশ্রেণি দ্বারা কোনো ব্যক্তি জাতি সমষ্টি বস্তু স্থান কাল ভাব কর্ম বা গুণের নাম বোঝায় তাকে বিশেষ্য বলে
# বিশেষ্যের পরিবর্তে যে শব্দ ব্যবহৃত হয় তাকে সর্বনাম বলে
# সর্বনাম সাধারণত ইতঃপূর্বে ব্যবহৃত বিশেষ্যের প্রতিনিধি স্থানীয় শব্দ হিসেবে কাজ করে
# যে শব্দশ্রেণি দ্বারা বিশেষ্য সর্বনাম ও ক্রিয়ার দোষ গুণ অবস্থা সংখ্যা পরিমাণ ইত্যাদি প্রকাশ পায় তাকে বিশেষণ বলে
# যে শব্দশ্রেণি দ্বারা কোনো কিছু করা থাকা হওয়া ঘটা ইত্যাদি বোঝায় তাকে ক্রিয়া বলে
# যে শব্দ বাক্যের ক্রিয়াকে বিশেষিত করে তাকে ক্রিয়াবিশেষণ বলে
# যে শব্দ একটি বাক্যাংশের সাথে অন্য একটি বাক্যাংশ অথবা বাক্যস্থিত একটি শব্দের সঙ্গে অন্য একটি শব্দের সংযোজন বিয়োজন বা সংকোচন ঘটায় তাকে যোজক বলে
# যে শব্দ মনের বিশেষ ভাব বা আবেগ প্রকাশে সহায়তা করে তাকে আবেগ শব্দ বলে
# বিশেষ্যের পরিবর্তে যে শব্দ বা পদ ব্যবহৃত হয় তাকে সর্বনাম পদ বলে
# যে সর্বনাম কোনো ব্যক্তিকে বোঝায় তাকে ব্যক্তিবাচক সর্বনাম বলে
# কর্তা নিজেই কোনো কাজ করেছেএ ভাবটি জোর দিয়ে বোঝানোর জন্য যে সর্বনাম ব্যবহৃত হয় তাকে আত্মবাচক সর্বনাম বলে
# নির্দেশক সর্বনাম বক্তার কাছে থেকে কোনো কিছুর নৈকট্য দূরত্ব নির্দেশ করে
# অনির্দিষ্ট কাউকে বা কোনো বস্তু বোঝাতে অনির্দিষ্ট সর্বনাম ব্যবহৃত হয়
# প্রত্যক্ষ বা পরোক্ষ প্রশ্ন বোঝানোর জন্য যে সর্বনাম ব্যবহৃত হয় তাকে প্রশ্নবাচক সর্বনাম বলে
# সংযোগবাচক সর্বনাম দুটি বাক্যের মধ্যে সংযোগ ঘটায়
# পরস্পর নির্ভরশীল যে যুগল সর্বনাম দুটি বাক্যাংশের সংযোগ ঘটায় তাকে সাপেক্ষ সর্বনাম বলে
# যে সর্বনাম দুপক্ষের সহযোগ বা পারস্পরিক নির্ভরতা বোঝায় তাকে ব্যতিহার সর্বনাম বলে
# সকলবাচক সর্বনাম ব্যক্তি বস্তু বা ভাবের সমষ্টি বোঝায়
# অন্যবাচক সর্বনাম  নিজ ভিন্ন অন্য কোনো অনির্দিষ্ট ব্যক্তিকে বোঝাতে ব্যবহৃত হয়
# যে শব্দ বাক্যের অন্য শব্দের সাথে সম্পর্ক না রেখে স্বাধীনভাবে ভাব প্রকাশে সহায়তা করে তাকে আবেগ শব্দ বলে
# যেসব শব্দ দ্বারা অনুমোদন সম্মতি সমর্থন ইত্যাদি ভাব প্রকাশ করা হয় সেসব শব্দকে সিদ্ধান্তবাচক আবেগশব্দ বলে
# যেসব শব্দ প্রশংসা বা তারিফের মনোভাব প্রকাশ করে সেসব শব্দকে প্রশংসাবাচক আবেগ শব্দ বলে
# অবজ্ঞা ঘৃণা বিরক্তি ইত্যাদি মনোভাব যেসব শব্দ দ্বারা প্রকাশ করা হয় সেসব শব্দকে বিরক্তিবাচক আবেগশব্দ বলে
# যেসব শব্দ দ্বারা আতঙ্ক যন্ত্রণা কাতরতা ইত্যাদি প্রকাশ পায় সেসব শব্দকে বলা হয় ভয় ও যন্ত্রণাবাচক আবেগ শব্দ
# বিস্ময়বাচক আবেগ শব্দ বিস্মিত বা আশ্চর্য হওয়ার মনোভাব প্রকাশ করে
# যেসব শব্দ দ্বারা করুণা বা সহানুভূতিমূলক মনোভাব প্রকাশ পায় সেসব শব্দকে বলা হয় করুণাবাচক আবেগ শব্দ
# সম্বোধনবাচক আবেগ শব্দ সম্বোধন বা আহ্বান করার ক্ষেত্রে ব্যবহৃত হয়
# যেসব আবেগ শব্দ বাক্যের অর্থের কোনো রকম পরিবর্তন না ঘটিয়ে কোমলতা মাধুর্য ইত্যাদি বৈশিষ্ট্য এবং সংশয় অনুরোধ মিনতি ইত্যাদি মনোভাব প্রকাশের জন্য অলংকার হিসেবে ব্যবহৃত হয় সেসব শব্দকে বলা হয় আলংকারিক আবেগ শব্দ
# যে শব্দ একটি বাক্য বা বাক্যাংশের সঙ্গে অন্য একটি বাক্য বা বাক্যাংশের কিংবা বাক্যস্থিত একটি শব্দের সঙ্গে অন্য শব্দের সংযোজন বিয়োজন বা সংকোচন ঘটায় তাকে যোজক বলে
# যে যোজক দ্বারা একাধিক শব্দ বাক্য বা বাক্যাংশকে সংযুক্ত করা যায় তাকে সাধারণ যোজক বলে
# যে যোজক দ্বারা একাধিক শব্দ বাক্য বা বাক্যাংশের মধ্যে বিকল্প বোঝায় তাকে বৈকল্পিক যোজক বলে
# বিরোধমূলক যোজক দুটি বাক্যের সংযোগ ঘটিয়ে দ্বিতীয়টি দ্বারা প্রথমটির বিরোধ নির্দেশ করে
# কারণবাচক যোজক এমন দুটি বাক্যের মধ্যে সংযোগ ঘটায় যার একটি অন্যটির কারণ
# পরস্পর নির্ভরশীল যে যোজকগুলো একে অন্যের পরিপূরক হিসেবে বাক্যে ব্যবহৃত হয় তাকে সাপেক্ষ যোজক বলে
# যে ক্রিয়া দ্বারা বাক্যের ভাবের পরিসমাপ্তি ঘটে তাকে সমাপিকা ক্রিয়া বলে
# যে ক্রিয়া দ্বারা বাক্যের ভাবের পরিসমাপ্তি ঘটে না তাকে অসমাপিকা ক্রিয়া বলে
# যে ক্রিয়া কর্মপদযুক্ত তাকে সকর্মক ক্রিয়া বলে
# বাক্যের অন্তর্গত যে ক্রিয়া কোনো কর্ম গ্রহণ করে না তাকে অকর্মক ক্রিয়া বলে
# বাক্যস্থিত যে ক্রিয়া দুটি কর্ম গ্রহণ করে তাকে দ্বিকর্মক ক্রিয়া বলে
# কর্তার যে ক্রিয়া অন্যকে দিয়ে করানো তাকে প্রযোজক ক্রিয়া বলে
# যৌগিক ক্রিয়া একটি সমাপিকা ও একটি অসমাপিকা ক্রিয়া যোগে গঠিত হয় এবং সম্প্রসারিত অর্থ প্রকাশ করে
# বিশেষ্য বিশেষণ বা ধ্বনাত্মক শব্দের সাথে সমাপিকা ক্রিয়া যোগ করে যে ক্রিয়া গঠিত হয় তাকে সংযোগমূলক বা মিশ্র ক্রিয়া বলে
# যে ক্রিয়া দ্বারা অস্তিবাচক বা হ্যাঁবোধক অর্থ প্রকাশ পায় তাকে অস্তিবাচক ক্রিয়া বলে
# যে ক্রিয়া দ্বারা নেতিবাচক বা নাবোধক অর্থ প্রকাশ পায় তাকে নেতিবাচক ক্রিয়া বলে
# ক্রিয়ামূল বা ধাতুর সাথে কৃৎ প্রত্যয় যোগ করে যে বিশেষণ গঠিত হয় তাকে ক্রিয়াজাত বিশেষণ বলে
# বিশেষ্যের সাথে তদ্ধিত না শব্দ প্রত্যয় যোগ করে যে বিশেষণ গঠিত হয় তাকে বিশেষ্যজাত বিশেষণ বলে
# যে সর্বনাম কখনো এককভাবে আবার কখনোবা প্রত্যয়যুক্ত বিশেষণ হিসেবে ব্যবহৃত হয় তাকে সর্বনামজাত বিশেষণ বলে
# যে ধ্বন্যাত্মক শব্দ কখনো এককভাবে আবার কখনো বা প্রত্যয়যুক্ত হয়ে বিশেষণ হিসেবে ব্যবহৃত হয় তাকে ধ্বন্যাত্মক শব্দজাত বিশেষণ বলে
# যে সমাসবদ্ধ শব্দ বিশেষণ হিসেবে ব্যবহৃত হয় তাকে সমাসবদ্ধ বিশেষণ বলে
# আদ্যপ্রত্যয় বা উপসর্গযোগে যে বিশেষণ গঠিত হয় তাকে আদ্যপ্রত্যয় বা উপসর্গযুক্ত বিশেষণ বলে
# যে শব্দ বাক্যের ক্রিয়াকে বিশেষিত করে তাকে ক্রিয়াবিশেষণ বলে
# যে উপায়ে ক্রিয়া সম্পন্ন হয় তাকে ধরনবাচক ক্রিয়া বলে
# যে সময়টিতে ক্রিয়া সম্পন্ন হয় তাকে কালবাচক ক্রিয়াবিশেষণ বলে
# ক্রিয়া সংঘটনের স্থানকে স্থানবাচক ক্রিয়াবিশেষণ বলে
# যে ক্রিয়াবিশেষণ একাধিক বাক্যাংশকে সংযুক্ত করে তাকে সংযোজক ক্রিয়াবিশেষণ বলে
# যে ক্রিয়াবিশেষণ তাকে নাবাচক বৈশিষ্ট্য দেয় তাকে নাবাচক ক্রিয়াবিশেষণ বলে
# একটি মাত্র পদ দিয়ে যে ক্রিয়াবিশেষণ গঠিত হয় তাকে একপদী ক্রিয়াবিশেষণ বলে
# একের অধিক পদ দিয়ে যে ক্রিয়াবিশেষণ গঠিত হয় তাকে বহুপদী ক্রিয়াবিশেষণ বলে
# বাক্যে বিশেষ ইঙ্গিত প্রকাশের জন্যে যে পদাণু ব্যবহার করা হয় তাকে ক্রিয়াবিশেষণ পদাণু বলে
# প্রকাশ অনুসারে আবেগ শব্দকে বিভিন্ন ভাগে ভাগ করা যায়
# যে শব্দগুলো কখনো স্বাধীনরূপে আবার কখনো বা শব্দবিভক্তির মতো বাক্যে ব্যবহৃত হয়ে তার অর্থ প্রকাশে সাহায্য করে তাকে অনুসর্গ বলে
# ক্রিয়া ছাড়া অন্যান্য শব্দ থেকে যে অনুসর্গগুলো এসেছে তাদের বিশেষ্য বা নামজাত অনুসর্গ বলে
# ক্রিয়া থেকে যেসব অনুসর্গ উৎপন্ন হয় তাদের ক্রিয়া বা ক্রিয়াজাত অনুসর্গ বলে
# যে বিশেষ্য অনুসর্গগুলো সংস্কৃত থেকে বাংলা ভাষায় এসেছে তাদের সংস্কৃত অনুসর্গ বলে
# যে বিশেষ্য অনুসর্গগুলো সংস্কৃত থেকে কিছুটা পরিবর্তিত হয়ে বাংলা ভাষায় এসেছে তাদের বিবর্তিত অনুসর্গ বলে
# যে বিশেষ্য অনুসর্গগুলো ফারসি থেকে বাংলা ভাষায় এসেছে তাদের ফারসি অনুসর্গ বলে
# ক্রিয়া থেকে যেসব অনুসর্গ উৎপন্ন হয় তাদের ক্রিয়া বা ক্রিয়াজাত অনুসর্গ বলে
# মানুষ স্বাভাবিকভাবেই সৌন্দর্যপ্রিয় রূপপিয়াসী ও কল্পনাবিলাসী
# নৃতাত্ত্বিক বিচারে আর্যবসতিপূর্ব জাতিগোষ্ঠীর ব্যবহৃত ভাষা থেকে এসে বাংলা ভাষায় ব্যবহৃত হচ্ছে এমন উপসর্গকে খাঁটি বাংলা বা দেশি উপসর্গ বলে
# সংস্কৃত ভাষা থেকে আগত এবং বর্তমানে বাংলা ভাষায় ব্যবহৃত উপসর্গকে সংস্কৃত বা তৎসম উপসর্গ বলে
# বিদেশি ভাষা থেকে এসে বা ভাষায় ব্যবহৃত উপসর্গকে বিদেশি উপসর্গ বলে
# বাংলা ভাষায় এমন কতকগুলো অব্যয়সূচক শব্দাংশ রয়েছে যা স্বাধীন পদ হিসেবে বাক্যে ব্যবহৃত হতে পারে না এগুলো অন্য শব্দের পূর্বে বসে
# উপসর্গের প্রধান বৈশিষ্ট্য হলো উপসর্গের অর্থবাচকতা নেই কিন্তু অর্থদ্যোতকতা আছে
# বাংলা ভাষায় ব্যবহৃত উপসর্গগুলোর নিজস্ব কোনো অর্থ নেই বা আলাদাভাবে ব্যবহৃত হয় না
# কেবল ধাতু বা শব্দের পূর্বে যুক্ত হয়ে নতুন শব্দ গঠন করে এবং অর্থের বৈচিত্র্য তৈরি করে
# উপসর্গের নিজস্ব কোনো অর্থবাচকতা নেই কেবল অন্য শব্দের পূর্বে বসে এদের অর্থদ্যোতকতা বা নতুন শব্দ সৃষ্টির ক্ষমতা থাকে
# কোনো মৌলিক শব্দের যে অংশকে আর বিশ্লেষণ করা যায় না তাকে প্রকৃতি বলে
# প্রকৃতি দুই প্রকার যথা   নাম প্রকৃতি এবং  ধাতু প্রকৃতি
# ধাতুর সাথে যা যুক্ত করে শব্দ কিংবা কালরূপ এবং শব্দে যা যুক্ত করে অন্য শব্দ বা ধাতু হয় তাকে প্রত্যয় বলে
# প্রত্যয় দুই প্রকার যথা   ধাতু প্রত্যয় বা কৃৎ প্রত্যয় এবং  শব্দ প্রত্যয় বা তদ্ধিত প্রত্যয়
# ধাতু বা কৃৎ প্রত্যয় আবার দুই প্রকার যথা  বাংলা কৃৎ প্রত্যয় এবং  সংস্কৃত কৃৎ প্রত্যয়
# শব্দ বা তদ্ধিত প্রত্যয় তিন প্রকার যথা  বাংলা তদ্ধিত প্রত্যয়  বিদেশি তদ্ধিত প্রত্যয় এবং ত তৎস তদ্ধিত প্রত্যয়
# সমাসের প্রক্রিয়ায় সমাসবদ্ধ বা সমাস নিষ্পন্ন পদটিকে সমস্তপদ বলে
# সমস্তপদ বা সমাসবদ্ধ পদটির অন্তর্গত পদগুলোকে সমস্যমান পদ বলে
# সমাসযুক্ত পদের প্রথম অংশ শব্দকে পূর্বপদ বলে এবং পরবর্তী অংশ শব্দকে পরপদ বা উত্তরপদ বলে
# সমস্তপদকে ভেঙে যে বাক্যাংশ করা হয় তাকে সমাসবাক্য ব্যাসবাক্য বা বিগ্রহবাক্য বলে
# পরস্পর অর্থসঙ্গতিপূর্ণ অন্বয়যুক্ত দুই বা বহুপদের একপদে পরিণত হওয়াকে সমাস বলে
# বাংলা ভাষায় সমাস প্রধানত ছয় প্রকার যথা   দ্বন্দ্ব সমাস  কর্মধারয় সমাস  তৎপুরুষ সমাস  বহুব্রীহি সমাস  অব্যয়ীভাব সমাস   দ্বিগু সমাস
# যে সমাসে প্রত্যেকটি সমস্যমান পদের অর্থের প্রাধান্য থাকে তাকে দ্বন্দ্ব সমাস বলে
# যে সমাসে পূবৃপদটি সংখ্যাবাচক বিশেষণ পরপদটি বিশেষ্য এবং সমাসে পরপদেরই অর্থ প্রাধান্য থাকে তাকে দ্বিগু সমাস বলে
# যে সমাসে পূর্বপদে বিভিক্তি লোপ হয় এবং পরপদ অর্থপ্রাধান্য লাভ করে তাকে তৎপুরুষ সমাস বলে
# পরস্পর সম্বন্ধযুক্ত বিশেষ্য ও বিশেষণ পদে কিংবা বিমেষ্য ও বিশেষ্য পদে কিংবা বিশেষণ ও বিশেষণ পদের যে সমাস হয় এবং উত্তরপদ অর্থ প্রাধান্য লাভ করে তাকে কর্মধারয় সমাস বলে

# %%
stop =["অতএব","অথচ","অথবা","অনুযায়ী","অনেক","অনেকে","অনেকেই","অন্তত","অন্য","অবধি","অবশ্য","অর্থাত","আই","আগামী","আগে","আগেই","আছে","আজ","আদ্যভাগে","আপনার","আপনি","আবার","আমরা","আমাকে","আমাদের","আমার","আমি","আর","আরও","ই","ইত্যাদি","ইহা","উচিত","উত্তর","উনি","উপর","উপরে","এ","এঁদের","এঁরা","এই","একই","একটি","একবার","একে","এক্","এখন","এখনও","এখানে","এখানেই","এটা","এটাই","এটি","এত","এতটাই","এতে","এদের","এব","এবং","এবার","এমন","এমনকী","এমনি","এর","এরা","এল","এস","এসে","ঐ","ও","ওঁদের","ওঁর","ওঁরা","ওই","ওকে","ওখানে","ওদের","ওর","ওরা","কখনও","কত","কবে","কমনে","কয়েক","কয়েকটি","করছে","করছেন","করতে","করবে","করবেন","করলে","করলেন","করা","করাই","করায়","করার","করি","করিতে","করিয়া","করিয়ে","করে","করেই","করেছিলেন","করেছে","করেছেন","করেন","কাউকে","কাছ","কাছে","কাজ","কাজে","কারও","কারণ","কি","কিংবা","কিছু","কিছুই","কিন্তু","কী","কে","কেউ","কেউই","কেখা","কেন","কোটি","কোন","কোনও","কোনো","ক্ষেত্রে","কয়েক","খুব","গিয়ে","গিয়েছে","গিয়ে","গুলি","গেছে","গেল","গেলে","গোটা","চলে","চান","চায়","চার","চালু","চেয়ে","চেষ্টা","ছাড়া","ছাড়াও","ছিল","ছিলেন","জন","জনকে","জনের","জন্য","জন্যওজে","জানতে","জানা","জানানো","জানায়","জানিয়ে","জানিয়েছে","জে","জ্নজন","টি","ঠিক","তখন","তত","তথা","তবু","তবে","তা","তাঁকে","তাঁদের","তাঁর","তাঁরা","তাঁাহারা","তাই","তাও","তাকে","তাতে","তাদের","তার","তারপর","তারা","তারৈ","তাহলে","তাহা","তাহাতে","তাহার","তিনঐ","তিনি","তিনিও","তুমি","তুলে","তেমন","তো","তোমার","থাকবে","থাকবেন","থাকা","থাকায়","থাকে","থাকেন","থেকে","থেকেই","থেকেও","দিকে","দিতে","দিন","দিয়ে","দিয়েছে","দিয়েছেন","দিলেন","দু","দুই","দুটি","দুটো","দেওয়া","দেওয়ার","দেওয়া","দেখতে","দেখা","দেখে","দেন","দেয়","দ্বারা","ধরা","ধরে","ধামার","নতুন","নয়","না","নাই","নাকি","নাগাদ","নানা","নিজে","নিজেই","নিজেদের","নিজের","নিতে","নিয়ে","নিয়ে","নেই","নেওয়া","নেওয়ার","নেওয়া","নয়","পক্ষে","পর","পরে","পরেই","পরেও","পর্যন্ত","পাওয়া","পাচ","পারি","পারে","পারেন","পি","পেয়ে","পেয়্র্","প্রতি","প্রথম","প্রভৃতি","প্রযন্ত","প্রাথমিক","প্রায়","প্রায়","ফলে","ফিরে","ফের","বক্তব্য","বদলে","বন","বরং","বলতে","বলল","বললেন","বলা","বলে","বলেছেন","বলেন","বসে","বহু","বা","বাদে","বার","বি","বিনা","বিভিন্ন","বিশেষ","বিষয়টি","বেশ","বেশি","ব্যবহার","ব্যাপারে","ভাবে","ভাবেই","মতো","মতোই","মধ্যভাগে","মধ্যে","মধ্যেই","মধ্যেও","মনে","মাত্র","মাধ্যমে","মোট","মোটেই","যখন","যত","যতটা","যথেষ্ট","যদি","যদিও","যা","যাঁর","যাঁরা","যাওয়া","যাওয়ার","যাওয়া","যাকে","যাচ্ছে","যাতে","যাদের","যান","যাবে","যায়","যার","যারা","যিনি","যে","যেখানে","যেতে","যেন","যেমন","র","রকম","রয়েছে","রাখা","রেখে","লক্ষ","শুধু","শুরু","সঙ্গে","সঙ্গেও","সব","সবার","সমস্ত","সম্প্রতি","সহ","সহিত","সাথে","সাধারণ","সামনে","সি","সুতরাং","সে","সেই","সেখান","সেখানে","সেটা","সেটাই","সেটাও","সেটি","স্পষ্ট","স্বয়ং","হইতে","হইবে","হইয়া","হওয়া","হওয়ায়","হওয়ার","হচ্ছে","হত","হতে","হতেই","হন","হবে","হবেন","হয়","হয়তো","হয়নি","হয়ে","হয়েই","হয়েছিল","হয়েছে","হয়েছেন","হল","হলে","হলেই","হলেও","হলো","হাজার","হিসাবে","হৈলে","হোক","হয়"]
display(stop)
# Out:
# ['অতএব',
#  'অথচ',
#  'অথবা',
#  'অনুযায়ী',
#  'অনেক',
#  'অনেকে',
#  'অনেকেই',
#  'অন্তত',
#  'অন্য',
#  'অবধি',
#  'অবশ্য',
#  'অর্থাত',
#  'আই',
#  'আগামী',
#  'আগে',
#  'আগেই',
#  'আছে',
#  'আজ',
#  'আদ্যভাগে',
#  'আপনার',
#  'আপনি',
#  'আবার',
#  'আমরা',
#  'আমাকে',
#  'আমাদের',
#  'আমার',
#  'আমি',
#  'আর',
#  'আরও',
#  'ই',
#  'ইত্যাদি',
#  'ইহা',
#  'উচিত',
#  'উত্তর',
#  'উনি',
#  'উপর',
#  'উপরে',
#  'এ',
#  'এঁদের',
#  'এঁরা',
#  'এই',
#  'একই',
#  'একটি',
#  'একবার',
#  'একে',
#  'এক্',
#  'এখন',
#  'এখনও',
#  'এখানে',
#  'এখানেই',
#  'এটা',
#  'এটাই',
#  'এটি',
#  'এত',
#  'এতটাই',
#  'এতে',
#  'এদের',
#  'এব',
#  'এবং',
#  'এবার',
#  'এমন',
#  'এমনকী',
#  'এমনি',
#  'এর',
#  'এরা',
#  'এল',
#  'এস',
#  'এসে',
#  'ঐ',
#  'ও',
#  'ওঁদের',
#  'ওঁর',
#  'ওঁরা',
#  'ওই',
#  'ওকে',
#  'ওখানে',
#  'ওদের',
#  'ওর',
#  'ওরা',
#  'কখনও',
#  'কত',
#  'কবে',
#  'কমনে',
#  'কয়েক',
#  'কয়েকটি',
#  'করছে',
#  'করছেন',
#  'করতে',
#  'করবে',
#  'করবেন',
#  'করলে',
#  'করলেন',
#  'করা',
#  'করাই',
#  'করায়',
#  'করার',
#  'করি',
#  'করিতে',
#  'করিয়া',
#  'করিয়ে',
#  'করে',
#  'করেই',
#  'করেছিলেন',
#  'করেছে',
#  'করেছেন',
#  'করেন',
#  'কাউকে',
#  'কাছ',
#  'কাছে',
#  'কাজ',
#  'কাজে',
#  'কারও',
#  'কারণ',
#  'কি',
#  'কিংবা',
#  'কিছু',
#  'কিছুই',
#  'কিন্তু',
#  'কী',
#  'কে',
#  'কেউ',
#  'কেউই',
#  'কেখা',
#  'কেন',
#  'কোটি',
#  'কোন',
#  'কোনও',
#  'কোনো',
#  'ক্ষেত্রে',
#  'কয়েক',
#  'খুব',
#  'গিয়ে',
#  'গিয়েছে',
#  'গিয়ে',
#  'গুলি',
#  'গেছে',
#  'গেল',
#  'গেলে',
#  'গোটা',
#  'চলে',
#  'চান',
#  'চায়',
#  'চার',
#  'চালু',
#  'চেয়ে',
#  'চেষ্টা',
#  'ছাড়া',
#  'ছাড়াও',
#  'ছিল',
#  'ছিলেন',
#  'জন',
#  'জনকে',
#  'জনের',
#  'জন্য',
#  'জন্যওজে',
#  'জানতে',
#  'জানা',
#  'জানানো',
#  'জানায়',
#  'জানিয়ে',
#  'জানিয়েছে',
#  'জে',
#  'জ্নজন',
#  'টি',
#  'ঠিক',
#  'তখন',
#  'তত',
#  'তথা',
#  'তবু',
#  'তবে',
#  'তা',
#  'তাঁকে',
#  'তাঁদের',
#  'তাঁর',
#  'তাঁরা',
#  'তাঁাহারা',
#  'তাই',
#  'তাও',
#  'তাকে',
#  'তাতে',
#  'তাদের',
#  'তার',
#  'তারপর',
#  'তারা',
#  'তারৈ',
#  'তাহলে',
#  'তাহা',
#  'তাহাতে',
#  'তাহার',
#  'তিনঐ',
#  'তিনি',
#  'তিনিও',
#  'তুমি',
#  'তুলে',
#  'তেমন',
#  'তো',
#  'তোমার',
#  'থাকবে',
#  'থাকবেন',
#  'থাকা',
#  'থাকায়',
#  'থাকে',
#  'থাকেন',
#  'থেকে',
#  'থেকেই',
#  'থেকেও',
#  'দিকে',
#  'দিতে',
#  'দিন',
#  'দিয়ে',
#  'দিয়েছে',
#  'দিয়েছেন',
#  'দিলেন',
#  'দু',
#  'দুই',
#  'দুটি',
#  'দুটো',
#  'দেওয়া',
#  'দেওয়ার',
#  'দেওয়া',
#  'দেখতে',
#  'দেখা',
#  'দেখে',
#  'দেন',
#  'দেয়',
#  'দ্বারা',
#  'ধরা',
#  'ধরে',
#  'ধামার',
#  'নতুন',
#  'নয়',
#  'না',
#  'নাই',
#  'নাকি',
#  'নাগাদ',
#  'নানা',
#  'নিজে',
#  'নিজেই',
#  'নিজেদের',
#  'নিজের',
#  'নিতে',
#  'নিয়ে',
#  'নিয়ে',
#  'নেই',
#  'নেওয়া',
#  'নেওয়ার',
#  'নেওয়া',
#  'নয়',
#  'পক্ষে',
#  'পর',
#  'পরে',
#  'পরেই',
#  'পরেও',
#  'পর্যন্ত',
#  'পাওয়া',
#  'পাচ',
#  'পারি',
#  'পারে',
#  'পারেন',
#  'পি',
#  'পেয়ে',
#  'পেয়্র্',
#  'প্রতি',
#  'প্রথম',
#  'প্রভৃতি',
#  'প্রযন্ত',
#  'প্রাথমিক',
#  'প্রায়',
#  'প্রায়',
#  'ফলে',
#  'ফিরে',
#  'ফের',
#  'বক্তব্য',
#  'বদলে',
#  'বন',
#  'বরং',
#  'বলতে',
#  'বলল',
#  'বললেন',
#  'বলা',
#  'বলে',
#  'বলেছেন',
#  'বলেন',
#  'বসে',
#  'বহু',
#  'বা',
#  'বাদে',
#  'বার',
#  'বি',
#  'বিনা',
#  'বিভিন্ন',
#  'বিশেষ',
#  'বিষয়টি',
#  'বেশ',
#  'বেশি',
#  'ব্যবহার',
#  'ব্যাপারে',
#  'ভাবে',
#  'ভাবেই',
#  'মতো',
#  'মতোই',
#  'মধ্যভাগে',
#  'মধ্যে',
#  'মধ্যেই',
#  'মধ্যেও',
#  'মনে',
#  'মাত্র',
#  'মাধ্যমে',
#  'মোট',
#  'মোটেই',
#  'যখন',
#  'যত',
#  'যতটা',
#  'যথেষ্ট',
#  'যদি',
#  'যদিও',
#  'যা',
#  'যাঁর',
#  'যাঁরা',
#  'যাওয়া',
#  'যাওয়ার',
#  'যাওয়া',
#  'যাকে',
#  'যাচ্ছে',
#  'যাতে',
#  'যাদের',
#  'যান',
#  'যাবে',
#  'যায়',
#  'যার',
#  'যারা',
#  'যিনি',
#  'যে',
#  'যেখানে',
#  'যেতে',
#  'যেন',
#  'যেমন',
#  'র',
#  'রকম',
#  'রয়েছে',
#  'রাখা',
#  'রেখে',
#  'লক্ষ',
#  'শুধু',
#  'শুরু',
#  'সঙ্গে',
#  'সঙ্গেও',
#  'সব',
#  'সবার',
#  'সমস্ত',
#  'সম্প্রতি',
#  'সহ',
#  'সহিত',
#  'সাথে',
#  'সাধারণ',
#  'সামনে',
#  'সি',
#  'সুতরাং',
#  'সে',
#  'সেই',
#  'সেখান',
#  'সেখানে',
#  'সেটা',
#  'সেটাই',
#  'সেটাও',
#  'সেটি',
#  'স্পষ্ট',
#  'স্বয়ং',
#  'হইতে',
#  'হইবে',
#  'হইয়া',
#  'হওয়া',
#  'হওয়ায়',
#  'হওয়ার',
#  'হচ্ছে',
#  'হত',
#  'হতে',
#  'হতেই',
#  'হন',
#  'হবে',
#  'হবেন',
#  'হয়',
#  'হয়তো',
#  'হয়নি',
#  'হয়ে',
#  'হয়েই',
#  'হয়েছিল',
#  'হয়েছে',
#  'হয়েছেন',
#  'হল',
#  'হলে',
#  'হলেই',
#  'হলেও',
#  'হলো',
#  'হাজার',
#  'হিসাবে',
#  'হৈলে',
#  'হোক',
#  'হয়']

# %%
def stopwordRemoval(text):
    x=str(text)
    l=x.split()

    stm=[elem for elem in l if elem not in stop]

    out=' '.join(stm)

    return str(out)

# %%
data['cleantext'] = data.cleantext.apply(lambda x: stopwordRemoval(str(x)))
#display(data.cleantext)
sample_data = range(0,1000)
for i in sample_data:
  print(data.cleantext[i])
# Out:
# ভৌত জগৎ মূলত চারটি উপাদানের সমন্বয়ে তৈরি স্থান কাল সময় ভর শক্তি
# বলবিদ্যা বস্তুর বলের ক্রিয়া সংক্রান্ত বিষয় আলোচনা
# পদার্থের ধর্ম বস্তুর গুণ আলোচনা
# স্থিতিবিদ্যা স্থিতিশীল বস্তুর বলের ক্রিয়া আলোচনা
# গতিবিদ্যা গতিশীল বস্তুর বলের ক্রিয়া আলোচনা
# ধর্ম সকল পদার্থেরই কমবেশি পদার্থের ধর্ম ওজন বিস্তৃতি রোধ স্থিতিস্থাপকতা
# ধর্ম সকল পদার্থের পদার্থের ধর্ম তারতা পাততা দৃঢ়তা ভঙ্গুরতা ধর্ম কেবলমাত্র কঠিন পদার্থের বেলায়
# সান্দ্রতা তরল বায়বীয় পদার্থের ধর্ম
# পৃষ্ঠটান তলটান তরল পদার্থের ধর্ম
# তাপ একপ্রকার শক্তি বস্তুতে প্রয়োগ বস্তুটিকে গরম বস্তুটির তাপমাত্রা বৃদ্ধি পায় বর্জন তাপমাত্রা হ্রাস পায়
# তত্ত্ব পরীক্ষানিরীক্ষার সাহায্যে প্রমাণিত মূল কথাগুলি উক্তির প্রকাশ বৈজ্ঞানিক সূত্র
# সূত্র সময় আবিষ্কর্তার নামানুসারে ওমের সূত্র বয়েলের সূত্র কখনওবা বিষয়ের নামে শক্তির নিত্যতা সূত্র তাপগতিবিদ্যার সূত্র আবিষ্কারক বিষয় উভয়ের নামে নিউটনের গতিসূত্র গ্যালিলিওর পড়ন্ত বস্তুর সূত্র
# সকল প্রাকৃতিক সত্য সরাসরি স্পষ্টভাবে প্রমাণ সত্যের সাহায্যে প্রাকৃতিক ঘটনাকে প্রমাণ নীতি
# গাণিতিক মডেল সূত্র প্রতিষ্ঠা লক্ষ্যে পূর্বশর্ত স্বীকার পূর্বশর্তসমূহকে স্বীকার্য
# পরীক্ষানিরীক্ষার প্রমাণিত অনুকল্পকে তত্ত্ব
# তত্ত্বকে ধারণা উক্তি সমীকরণের ব্যাখ্যা তত্ত্বকে সূত্র
# সকল সূত্রই তত্ত্ব সকল তত্ত্ব সূত্র
# সকল তত্ত্বই অনুকল্প সকল অনুকল্প তত্ত্ব
# বিজ্ঞানীরা পর্যবেক্ষিত ঘটনার সম্বন্ধে ব্যাখ্যা প্রদানের সময় পূর্বে আবিষ্কৃত প্রাকৃতিক নিয়মের সামঞ্জস্য অনুমান অনুমানগুলোকে অনুকল্প
# চিরায়িত বলবিদ্যা নিউটনীয় বলবিদ্যা নামে পরিচিত
# বিজ্ঞানী নিউটনের মতে স্থান পরম জিনিস অবস্থান বাইরের কিছুর সম্পর্কীয় পরিবেশ প্রভাবিত
# নিউটনের মতে সময় কাল প্রকৃতিগতভাবে পরম রাশি বাইরের কিছুর নির্ভর সমভাবে এগিয়ে
# নিউটনীয় বলবিদ্যায় বস্তুর ভর মৌলিক রাশি গতির নির্ভরশীল ভরের নিত্যতা সূত্র অনুসারে স্বতন্ত্র প্রক্রিয়াধীন বস্তুসমূহের ভর প্রক্রিয়াধীন ততোধিক বস্তুর ক্রিয়া প্রতিক্রিয়ার দরুন
# বস্তুর গতিশীল অবস্থার দৈর্ঘ্য বস্তুর স্থির অবস্থার দৈর্ঘ্যের ছোট হওয়াকে দৈর্ঘ্য সংকোচন
# জড় স্থির কাঠামোতে সংঘটিত ঘটনা উক্ত কাঠামো সাপেক্ষে গতিশীল কাঠামো ঘটনার সময় ব্যবধান বৃদ্ধি পেয়েছে
# বস্তু গতিশীল ভর বৃদ্ধি পায় ঘটনাকে ভরের আপেক্ষিকতা গতিজনিত ভর বৃদ্ধি
# একক এককের নির্ভর একেবারে সম্পর্কশূন্য স্বাধীন মৌলিক একক
# মৌলিক একক একক লব্ধ যৌগিক একক
# রাশি মৌলিক এককের সম্পর্ক স্থাপনের সংকেত উক্ত রাশির মাত্রা
# প্রাকৃতিক রাশির মাত্রা উক্ত রাশি মৌলিক এককের সম্পর্ক স্থাপন
# লব্ধ একক গঠন মৌলিক এককগুলোকে ঘাতে উন্নীত ঘাতকে লব্ধ এককের মাত্রা
# পদার্থবিজ্ঞানের তিনটি মৌলিক রাশি দৈর্ঘ্য ভর সময়
# সমীকরণ মৌলিক একক লব্ধ এককের সম্পর্ক স্থাপন মাত্রা সমীকরণ
# রাশি সম্মন্ধে দুভাবে জ্ঞান লাভ পারিএকটি গুণগত অন্যটি পরিমাণগত
# প্রাকৃতিক রাশি পরিমাপ নির্দিষ্ট সুবিধাজনক অংশ খণ্ডকে আদর্শ হিসেবে রাশির পরিমাপ সর্বত্র নির্দিষ্ট অংশেরই প্রচলন
# পিথাগোরাস জ্যোতির্বিদ্যা গণিত শব্দবিজ্ঞান বিষয়ে অবদানের বিখ্যাত
# খ্রি পূ চতুর্থ শতকে ইউক্লিড জ্যামিতি আলোকবিজ্ঞানের মূল্যবান গবেষণা লব্ধ তথ্য প্রদান
# খ্রি পূ তৃতীয় শতকে আর্কিমিডিস লিভারের নীতি উদস্থিতিবিদ্যার সূত্র আবিষ্কার
# খ্রিস্টাব্দে বিজ্ঞানী গ্যালিলিও মুক্তভাবে পড়ন্ত বস্তুর তথ্যউপাত্ত সংগ্রহ তিনটি সূত্র আবিষ্কার
# খ্রিস্টাব্দে বিজ্ঞানী গ্যালিলিও যৌগিক অণুবীক্ষণ যন্ত্র আবিষ্কার
# সালে ক্যামব্রিজে পড়ার সময় নিউটন মহাকর্ষ বলের তত্ত্ব ক্যালকুলাস আলোর বর্ণালী তিনটি সূত্র আবিষ্কার
# স্যার আইজাক নিউটনের সমসাময়িক ডাচ বিজ্ঞানী হাইগেন্স খ্রিস্টাব্দে আলোর তরঙ্গ তত্ত্ব প্রদান
# ফ্যারাডে তড়িৎচুম্বকীয় আবেশ আপেক্ষিক আবেশিক ধারকত্ব আবিষ্কারের অমর আছেন
# সালে রাদারফোর্ড বিখ্যাত আলফা বিক্ষেপণ পরীক্ষার ফলাফল সিদ্ধান্তে উপনীত পরমাণুর ধন আধান ভর কেন্দ্রে অতি অল্প পরিসর স্থানে কেন্দ্রীভূত
# আইনস্টাইন বৈচিত্র্যময় বৈজ্ঞানিক আবিষ্কারের সবচেয়ে পরিচিত আপেক্ষিক তত্ত্বের
# প্ল্যাঙ্কের অভিমত অনুসারে বস্তু শক্তির বিকিরণ ধাতুর শক্তির বিনিময় নিরবচ্ছিন্নভাবে ঘটে
# পরিমাপে যন্ত্র সেগুলো সঠিক সুবেদী ভৌত রাশির পরিমাপে ত্রুটি যান্ত্রিক ত্রুটি
# সাধারণত ভার্নিয়ার স্কেল স্ক্রুগজ স্লাইড ক্যালিপার্স স্ফেরোমিটার ইত্যাদির প্রধান স্কেলের দাগ ভার্নিয়ার বৃত্তাকার স্কেলের দাগের মিলে পিছনে শূন্য ত্রুটি
# পিছট ত্রুটি নাটস্ক্রু নীতির ভিত্তি সকল যন্ত্র তৈরি সেসব যন্ত্রে ত্রুটি পরিলক্ষিত
# পর্যবেক্ষণমূলক ব্যক্তিগত ত্রুটি পর্যবেক্ষকের পর্যবেক্ষণে ভুল সঠিক মূল্যায়নের অভাবে ত্রুটি পরিলক্ষিত
# পরীক্ষাকালে ত্রুটির পরীক্ষাধীন রাশির পরীক্ষালব্ধ মান সর্বদাই নিয়মিতভাবে রাশিটির প্রকৃত মান অপেক্ষা কম ধরনের ত্রুটিকে নিয়মিত পুনরাবৃত্তিক ত্রুটি
# রাশির প্রকৃত মান পরিমাপকৃত মানের পার্থক্যকে পরম ত্রুটি
# পদার্থবিজ্ঞানের অন্তর্গত রাশিকে ভৌত রাশি
# ভৌত রাশির মান দিক তাদেরকে স্কেলার রাশি অদিক রাশি
# ভৌত রাশির মান দিক দুইই তাদেরকে ভেক্টর রাশি দিক রাশি
# ততোধিক সমজাতীয় ভেক্টরকে যোগ ভিন্ন প্রকৃতির ভেক্টরকে যোগ
# ততোধিক ভেক্টর যোগ ভেক্টর প্রথমোক্ত ভেক্টর দুটির সম্মিলিত ক্রিয়ার ফলাফলের সমান
# ভেক্টরের ভেক্টর গুণফল ভেক্টর রাশি
# ভেক্টরের স্কেলার গুণফল স্কেলার রাশি
# ভেক্টর রাশি মানের অনুপাত ভেক্টরটির দিক নির্দেশিত
# ভেক্টর রাশি যোগ সংযোজন বণ্টন সূত্র মেনে
# অক্ষরের তীর চিহ্ন রাশিটির ভেক্টর রূপ পাশের খাড়া রেখা মান নির্দেশ
# বাহ্যিক বস্তুর গতি স্থিতি অবস্থার পরিবর্তন ঘটায় ঘটাতে বল
# অক্ষের সাপেক্ষে ঘূর্ণনরত বস্তুর বিন্দুতে বল ক্রিয়াশীল বিন্দুর অবস্থান ভেক্টর প্রযুক্ত বলের গুণফলকে ঘূর্ণন বল টর্ক
# সময় ব্যবধান শূন্যের কাছাকাছি কৌণিক সরণের পরিবর্তনের হারকে তাৎক্ষণিক কৌণিক বেগ কৌণিক বেগ
# ঘূর্ণনরত বস্তুকণার ব্যাসার্ধ ভেক্টর রৈখিক ভরবেগের ভেক্টর গুণফলকে কৌণিক ভরবেগ
# পৃষ্ঠের সমতলের অভিলম্ব অঙ্কন দিক নির্দেশিত তলের ভেক্টর
# ভেক্টর রাশির মান এক একক একক ভেক্টর
# ভেক্টরের মানকে ভেক্টরের একক ভেক্টর গুণ ভেক্টরটি
# ভেক্টর রাশির মান শূন্য নাল শূন্য ভেক্টর
# ভেক্টরের বিপরীত ভেক্টর যোগ সমান ভেক্টর বিয়োগ নাল ভেক্টর
# দুইটি সমান বিপরীত ভেক্টর বিন্দুতে ক্রিয়া লব্ধি নাল ভেক্টর
# প্রসঙ্গ কাঠামোর মূল বিন্দুর সাপেক্ষে বিন্দুর অবস্থান ভেক্টরের সাহায্যে নির্ণয় নির্দেশ অবস্থান ভেক্টর
# মূল বিন্দু বিন্দুর অবস্থানের দূরত্বকে ব্যাসার্ধ ভেক্টর
# রৈখিক সরল পথে বিন্দুর অতিক্রান্ত দূরত্বকে সরণ ভেক্টর
# সমজাতীয় অসম মানের ভেক্টর ক্রিয়া তাদেরকে সদৃশ ভেক্টর
# সমান্তরাল ভেক্টরের একটির মান অপরটির বিপ্রতীপ তাদেরকে বিপ্রতীপ ভেক্টর
# ততোধিক ভেক্টর রেখায় সমান্তরালে ক্রিয়া তাদেরকে সমরেখ ভেক্টর
# ততোধিক ভেক্টর রাশি যোগে ভেক্টর রাশি লব্ধি
# সমজাতীয় ভেক্টরের প্রথমটির শীর্ষ শেষবিন্দু দ্বিতীয়টির আদি বিন্দু বিন্দুতে স্থাপন ভেক্টরের আদি বিন্দু দ্বিতীয় ভেক্টরের শীর্ষবিন্দুর সংযোগকারী সরলরেখার লব্ধি ভেক্টরের দিক সরলরেখার দৈর্ঘ্য ভেক্টর দুটির লব্ধির মান নির্দেশ
# ভেক্টর ত্রিভুজের সন্নিহিত বাহু ক্রমে মানে সূচিত ত্রিভুজের তৃতীয় বাহুটি বিপরীতক্রমে ভেক্টর দুটির লব্ধি নির্দেশ
# বিন্দুতে সময়ে ক্রিয়ারত তিনটি সমজাতীয় সমতলীয় ভেক্টর রাশিকে ত্রিভুজের তিনটি বাহু ক্রমে নির্দেশ লব্ধি শূন্য
# দুইএর অধিক ভেক্টর রাশির ভেক্টর রাশিগুলোকে ক্রমে সাজিয়ে ভেক্টর রাশির পাদবিন্দু শেষ ভেক্টর রাশির শীর্ষবিন্দু যোগ বহুভুজ শেষ বাহুটি বিপরীতক্রমে ভেক্টর রাশিগুলোর লব্ধির মান দিক নির্দেশ
# সামান্তরিকের বিন্দু অঙ্কিত সন্নিহিত বাহু কণার সময়ে ক্রিয়ারত ভেক্টর রাশির মান দিক নির্দেশ বিন্দু অঙ্কিত সামান্তরিকের কর্ণই লব্ধির মান দিক নির্দেশ
# ভেক্টর সরলরেখা বরাবর পরস্পর ক্রিয়া লব্ধির মান সর্বোচ্চ সর্বোচ্চ মান ভেক্টর রাশি দুটির যোগফলের সমান
# ভেক্টর রাশির লব্ধির মান যোগফল অপেক্ষা বড়
# ভেক্টর রাশি সরলরেখা বরাবর পরস্পর বিপরীত ক্রিয়া লব্ধির মান সর্বনিম্ন লব্ধির সর্বনিম্ন মান ভেক্টর রাশি দুটির বিয়োগফলের সমান
# ভেক্টর রাশির স্কেলার গুণফল স্কেলার রাশি মান রাশি দুটির মান মধ্যবর্তী কোণের কোসাইনের গুণফলের সমান
# ভেক্টর রাশির গুণনের স্কেলার রাশি ভেক্টরদ্বয়ের স্কেলার গুণফল
# ভেক্টরের মানের গুণফলের মধ্যবর্তী কোণের কোসাইনের গুণফলকে স্কেলার গুণফল ডট গুণফল
# ভেক্টর রাশির গুণফল ভেক্টর রাশি গুণনকে ভেক্টর গুণন ক্রস গুণন
# ভেক্টর গুণফলের মান ভেক্টর রাশি দুটির মান মধ্যবর্তী কোণের সাইন গুর্ণফলের সমান
# নিউট্রন তারকা নির্দিষ্ট সময় অন্তর অন্তর বেতার স্পন্দন পালসার
# গাণিতিক চিহ্নের রাশিকে রাশিতে রূপান্তর পরিবর্তনশীল রাশির ব্যাখ্যা দেয়া অপারেটর
# সময়ের ভেক্টর রাশির পরিবর্তন রাশির ব্যবকলন করাকে ভেক্টরের সময় সাপেক্ষে ব্যবকলন বুঝায়
# ক্ষেত্রের সংশ্লিষ্ট ভৌত গুণ স্কেলার ক্ষেত্রকে স্কেলার ক্ষেত্র
# ক্ষেত্রের সংশ্লিষ্ট ভৌতগুণ ভেক্টর ক্ষেত্রকে ভেক্টর ক্ষেত্র
# ভেক্টর ফাংশন ক্ষেত্রের ডাইভারজেন্সগুলো স্কেলার ফাংশন ক্ষেত্র যাদ্বারা ভেক্টর ক্ষেত্রের বিন্দুতে ফ্লাক্সের প্রকৃতি বহিঅন্ত
# বস্তুর গতির বর্ণনার ত্রিমাত্রিক স্থানে সুনির্দিষ্ট স্থানাঙ্ক ব্যবস্থা বিবেচনা সাপেক্ষে বস্তুটির গতি বর্ণনা প্রসঙ্গ কাঠামো
# বস্তুর সকল বিন্দুর স্থানাঙ্ক সময় প্রসঙ্গ কাঠামোর সাপেক্ষে স্থির বস্তুর অবস্থাকে স্থিতি
# বস্তুটির যেকোনো বিন্দুর স্থানাঙ্ক সময় প্রসঙ্গ কাঠামোর সাপেক্ষে পরিবর্তিত বস্তুর অবস্থাকে গতি
# বস্তুর গতির বর্ণনার ত্রিমাত্রিক স্থানে সুনির্দিষ্ট স্থানাঙ্ক ব্যবস্থা বিবেচনা সাপেক্ষে বস্তুটির গতি বর্ণনা প্রসঙ্গ কাঠামো
# বস্তুর সকল বিন্দুর স্থানাঙ্ক সময় প্রসঙ্গ কাঠামোর সাপেক্ষে স্থির বস্তুর অবস্থাকে স্থিতি
# বস্তুটির যেকোনো বিন্দুর স্থানাঙ্ক সময় প্রসঙ্গ কাঠামোর সাপেক্ষে পরিবর্তিত বস্তুর অবস্থাকে গতি
# বস্তুর কণার অবস্থান একটিমাত্র স্থানাঙ্ক নির্দেশ একমাত্রিক প্রসঙ্গ কাঠামো
# মুক্তভাবে পড়ন্ত বস্তুর গতি আলোচনা সময়ে বস্তুর অবস্থান
# বিন্দু বস্তুটি পড়তে প্রসঙ্গ বিন্দু গতিপথ অক্ষ
# বস্তুর কণার অবস্থান দুইটি স্থানাঙ্ক থাকলে উক্ত বস্তুটিকে দ্বিমাত্রিক বস্তু
# বস্তুর কণা কাঠামোয় অবস্থান বস্তুটিকে ত্রিমাত্রিক বস্তু
# প্রসঙ্গ বস্তুটি পরম স্থিতিতে তাহলেই বস্তু সাপেক্ষে স্থির থাকলে বস্তুকে পরম স্থিতিশীল বলি
# প্রসঙ্গ বস্তুটি পরম স্থিতিতে সাপেক্ষে বস্তু গতিশীল থাকলে পরম গতি বলি
# মহাবিশ্বের সকল স্থিতিই আপেক্ষিক সকল গতিই আপেক্ষিক
# গতিই পরম পরম স্থিতি
# বস্তুর স্থিতি গতি সবসময়ই আপেক্ষিক
# বস্তু সরলরেখা বরাবর চললে বস্তু সাপেক্ষে বস্তুর আপেক্ষিক বেগের মান বস্তুদ্বয়ের বেগের মানের বিয়োগফলের সমান
# বিক্রিয়ক উৎপাদে পরিণত বিক্রিয়ককে অবশ্যই শক্তির বাধা অতিক্রম শক্তির বাধাকে শক্তিপর্বত
# গতিশীল বস্তু চললে বস্তু দুটির বেগ বিয়োগ আপেক্ষিক বেগ
# গতিশীল বস্তু বিপরীত চললে আপেক্ষিক বেগ বের বেগ যোগ
# গতিশীল বস্তুর বেগ নির্ণয় কালে সরণকে সময় ভাগ বেগ নির্ণয় থাকি
# বস্তুর অবস্থানের পরিবর্তন অবস্থানসময় বেগের পরিবর্তন বেগসময় লেখচিত্রের সাহায্যে প্রকাশ
# সময় ব্যবধানে বস্তুর সরণকে সময় ব্যবধান ভাগ রাশি তাকেই বস্তুটির গড় বেগ
# সময়ের ব্যবধান শূন্যের কাছাকাছি বস্তুর সরণের হারকে তাৎক্ষণিক বেগ বেগ
# তাৎক্ষণিক বেগ বস্তুর মুহূর্তের বেগ বুঝায়
# সময় ব্যবধান শূন্যের কাছাকাছি গড় বেগের সীমান্তিক মানকেই তাৎক্ষণিক বেগ বেগ
# গতিশীল বস্তুর শেষ বেগএর অভিমুখ যোগফলের অর্ধেককে মধ্য বেগ
# বস্তুর ক্রিয়াশীল বলের মান দিক ধ্রুব থাকলে বস্তুর বেগও ধ্রুব
# বস্তুর ধ্রুব বেগকে সমবেগ
# ভিন্ন ভিন্ন সময়ে বস্তুর বেগ ভিন্ন ভিন্ন অসম বেগ
# সময়ের সরণের হারের মান দিক উভয়েই পরিবর্তিত সরণের হারই অসম বেগ
# গতিশীল বস্তুর সময় ব্যবধান শূন্যের কাছাকাছি বেগ পরিবর্তনের হারকে তাৎক্ষণিক ত্বরণ সংক্ষেপে ত্বরণ
# সময় ব্যবধান শূন্যের কাছাকাছি গড় ত্বরণের সীমান্তিক মান ত্বরণের সমান
# বিন্দুতে তাৎক্ষণিক ত্বরণ বিন্দুতে বস্তুটির বেগের লম্ব বরাবর
# ত্বরণ প্রকার যথা ক সমত্বরণ খ অসমত্বরণ
# তুরণ সময় ধ্রুব সমত্বরণ
# অভিকর্ষের টানে মুক্তভাবে পড়া বস্তুর ত্বরণ সমত্বরণ
# সময়ের ত্বরণ ভিন্ন ভিন্ন অসম ত্বরণ
# ত্বরণের মান দিক মান দিক পরিবর্তনের অসম ত্বরণ সৃষ্টি
# বস্তু নির্দিষ্ট বিন্দু নির্দিষ্ট দূরত্বে অবস্থিত বিন্দু বস্তুর দূরত্বকে অবস্থান
# প্রাস প্রক্ষেপণ বিন্দু অনুভূমিক সর্বাধিক দূরত্ব অতিক্রম প্রাসের পাল্লা
# উচ্চতায় স্থির অবস্থান মুক্তভাবে সকল পড়ন্ত বস্তু সমান সময়ে সমান দূরত্ব অতিক্রম
# স্থির অবস্থান বাধায় পড়ন্ত বস্তুর নির্দিষ্ট সময়এ প্রাপ্ত বেগ সময়ের সমানুপাতিক
# স্থির অবস্থান বাধায় পড়ন্ত বস্তু নির্দিষ্ট সময়ে দূরত্ব অতিক্রম সময়ের বর্গের সমানুপাতিক
# বৃত্তাকার পথে সমদ্রুতিতে ঘূর্ণায়মান বস্তুকণার গতিকে সুষম বৃত্তীয় গতি
# সুষম বৃত্তীয় গতিতে সময়ের বস্তুর বেগের মান অপরিবর্তিত থাকলেও বেগের অভিমুখ পরিবর্তিত
# বৃত্তকার পথে সমদ্রুতিতে চলমান বস্তুর ত্বরণ
# বস্তুকণা বৃত্তাকার পথে ঘুরতে বৃত্তের ব্যাসার্ধ বরাবর কেন্দ্রের অভিমুখে বস্তুকণার ত্বরণ ক্রিয়া কেন্দ্রমুখী অভিকেন্দ্র ত্বরণ
# সকল বল প্রয়োগের বল প্রয়োগকারীর বস্তুর প্রত্যক্ষ সংস্পর্শ প্রয়োজন ধরনের বলকে স্পর্শ বল
# বাহ্যিক স্থির বস্তুকে গতিশীল গতিশীল বস্তুর অবস্থার পরিবর্তন ঘটায় ঘটাবার বল
# সকল বল মূল অকৃত্রিম অর্থাৎ বল উৎপন্ন অন্যান্য সকল বলের প্রকাশ মৌলিক বল
# মৌলিক বলগুলো মহাকর্ষ বল তড়িৎচুম্বকীয় বল সবল নিউক্লীয় বল দুর্বল নিউক্লীয় বল
# মহাবিশ্বের বস্তুর এক ধরনের আকর্ষণ বল ক্রিয়াশীল আকর্ষণ বলকে মহাকর্ষ বল
# আহিত চার্জিত বস্তুর চুম্বক পদার্থের এক ধরনের বল ক্রিয়াশীল এদেরকে যথাক্রমে কুলম্বের তড়িৎ চৌম্বক বল
# তড়িৎ চৌম্বক বল আকর্ষণ বিকর্ষণ উভয় ধরনের
# চারটি মৌলিক বলের পরিমাপের আপেক্ষিক সবলতা তুলনা সবচেয়ে শক্তিশালী বল সবল নিউক্লীয় বল সবচেয়ে দুর্বল মহাকর্ষ বল
# সবল দুর্বল উভয় ধরনের নিউক্লীয় বলের ক্রিয়ার পাল্লা খুবই স্বল্প পাল্লাবিশিষ্ট
# বস্তুর ভর বেগের সমন্বয়ে বস্তুতে ধর্মের উদ্ভব বস্তুর ভরবেগ
# ভরবেগের পরিবর্তনের হার বস্তুর প্রযুক্ত বলের সমানুপাতিক
# একক ভরের বস্তুর একক ত্বরণ সৃষ্টি বল প্রযুক্ত একক বল
# নিউটনের দ্বিতীয় সূত্রানুসারে সময়ের বস্তুর ভরবেগের পরিবর্তন বলের ক্রিয়া অভিমুখে সংঘটিত
# বস্তুর ত্বরণ প্রযুক্ত বলের সমানুপাতিক
# বলের ক্রিয়া বন্ধ বস্তুটির ত্বরণ মন্দন
# বলের অভিমুখই ত্বরণের অভিমুখ
# বস্তুর বল ক্রিয়া বস্তুটি ত্বরণ চলতে
# অল্প সময়ের বড় মানের বল বস্তুর প্রযুক্ত ঘাত বল
# বল বলের ক্রিয়াকালের গুণফলকে বলের ঘাত
# বাইরে প্রযুক্ত বল অবস্থার পরিবর্তন বাধ্য স্থির বস্তু চিরকাল স্থির গতিশীল বস্তু চিরকাল সমবেগে সরলরেখায় চলতে
# বস্তুর ভরবেগের পরিবর্তনের হার বস্তুটির প্রযুক্ত বলের সমানুপাতিক বল প্রযুক্ত ভরবেগের পরিবর্তন সেইদিকে ঘটে
# প্রত্যেক ক্রিয়ার সমান বিপরীত প্রতিক্রিয়া
# জড়তার বিরুদ্ধে অর্থাৎ স্থির বস্তুকে গতিশীল গতিশীল বস্তুর গতির পরিবর্তন ঘটাতে বল প্রয়োগ
# বস্তুর ভর ভরবেগও
# বস্তু বস্তুর বল প্রয়োগ দ্বিতীয় বস্তুটিও বস্তুটির সমান বিপরীতমুখী বল প্রয়োগ
# নিউটনের গতি সূত্রের ভিত্তি বলবিদ্যার উদ্ভব উন্নয়ন সাধিত নিউটনের বলবিদ্যা
# নিউটনিয়ান বলবিদ্যায় বস্তুর ভর দৈর্ঘ্য দ্রুতির নির্ভর
# পদার্থবিজ্ঞানের সূত্রসমূহ সম্পর্ক কাঠামো সাপেক্ষে প্রকাশ বিন্যাস প্রণালী অপরিবর্তনীয় এটিই বিজ্ঞানী আইনস্টাইনএর আপেক্ষিক তত্ত্ব মূল ধারণা
# নিউটনের গতি সূত্র বৃহৎ আকৃতির বস্তুর প্রযোজ্য
# ক্ষুদ্র ভর বিশিষ্ট সকল কণার বেগ অর্থাৎ আলোর বেগের কাছাকাছি গতিশীল অবস্থায় তরঙ্গ রূপ আচরণ
# বস্তুর ত্বরণ কম নিউটনের গতিসূত্র প্রয়োগে ভালো ফল
# বস্তু স্থির কাঠামোতে সমবেগে চলমান নিউটনের গতিসূত্র প্রযোজ্য
# বিস্তৃত বস্তুর মধ্যবর্তী দূরত্ব আকারের তুলনায় কেবলমাত্র তখনই বস্তু দুটির আকার উপেক্ষা কণা
# মহাবিশ্বের বস্তুকণা পরস্পরকে আকর্ষণ আকর্ষণ বল বস্তু দুটির ভরের গুণফলের সমানুপাতিক দূরত্বের বর্গের ব্যস্তানুপাতিক বস্তু দুটির সংযোগকারী সরলরেখা বরাবর ক্রিয়াশীল
# বিশ্বজনীন ধ্রুবক মান বস্তুকণা দুটির মধ্যবর্তী মাধ্যমের প্রকৃতির ওপর যেমনপ্রবেশ্যতা প্রবণতা দিকদর্শিতা বস্তুকণা দুটির ভৌত অবস্থার নির্ভর
# মহাকর্ষ বল বস্তুর মধ্যকার পারস্পরিক আকর্ষণ বল
# চার্জিত বস্তু চুম্বক পরস্পরকে আকর্ষণ চার্জ বিপরীতধর্মী অর্থাৎ ধনাত্মক অপরটি ঋণাত্মক বিকর্ষণ চার্জ সমধর্মী
# চুম্বকের আকর্ষণ চুম্বকদ্বয়ের বিপরীত মেরু কাছাকাছি আসে বিকর্ষণ মেরুদ্বয় সমধর্মী
# যেকোনো অঞ্চলে ভর রাখলে মহাকর্ষীয় বল ক্রিয়া অঞ্চলকে মহাকর্ষীয় ক্ষেত্র
# বস্তুর দূরত্ব অসীম আকর্ষণ বল শূন্য
# মহাকর্ষীয় ক্ষেত্রের যেকোনো বিন্দুতে একক ভর রাখলে ভরের বল কিয়া বিন্দুতে মহাকর্ষীয় ক্ষেত্রের প্রাবল্য তীব্রতা
# একাধিক বস্তুর বাহ্যিক বল ক্রিয়া প্রযুক্ত নিট বাহ্যিক বল শূন্য সকল বস্তুর রৈখিক ভরবেগ ধ্রুব ভরবেগের পরিবর্তন
# বস্তুর ক্রিয়া প্রতিক্রিয়াজনিত বলের ভরবেগের পরিবর্তন বস্তু পরিমাণ ভরবেগ হারায় অপরটি সমপরিমাণ ভরবেগ লাভ অর্থাৎ ধাক্কার ভরবেগ
# বস্তু দ্বিতীয় বস্তুর বল প্রয়োগ ক্রিয়া দ্বিতীয় বস্তু কর্তৃক বস্তুটির প্রযুক্ত বলকে প্রতিক্রিয়া
# ক্রিয়া প্রতিক্রিয়া সম্পর্ক কার্যকারণ সম্পর্ক
# প্রকৃতিতে বল সকল সময় জোড়ায় জোড়ায় ক্রিয়া
# প্রত্যেক ক্রিয়ার সমান বিপরীত প্রতিক্রিয়া
# প্রত্যেক ক্রিয়ামূলক বলের সমান বিপরীত প্রতিক্রিয়ামূলক বল
# ব্যবস্থার প্রযুক্ত বাহ্যিক বল শূন্য ব্যবস্থাটির ভরবেগ সংরক্ষিত
# দৃঢ় বস্তু নির্দিষ্ট অক্ষে আবদ্ধ বস্তুর বল প্রয়োগ আবদ্ধ থাকার কারণে বস্তুটি সরলরেখায় চলতে
# দৃঢ় বস্তুর নির্দিষ্ট বিন্দু বস্তুটির ভর কেন্দ্রীভূত ঘূর্ণন অক্ষ সাপেক্ষে বিন্দুতে জড়তার ভ্রামক সমগ্র বস্তুটির জড়তার ভ্রামকের সমান অক্ষ বিন্দুর দূরত্বকে চক্রগতির ব্যাসার্ধ
# ঘূর্ণনরত বস্তুকণার ব্যাসার্ধ ভেক্টর রৈখিক ভরবেগের ভেক্টর গুণফলকে কৌণিক ভরবেগ
# ঘূর্ণন অক্ষ সাপেক্ষে বস্তুর জড়তার ভ্রামক কৌণিক বেগের গুণফলকে কৌণিক ভরবেগ
# বৃত্তীয় গতিতে সচল কণার ব্যাসার্ধ ভেক্টর নির্দিষ্ট সময়ের অবকাশে কোণে সরে সময়ের অবকাশে কণাটির কৌণিক সরণ
# কৌণিক গতি অসম কৌণিক সরণ অতিক্রান্ত সময়ের অনুপাতকে কণার গড় কৌণিক বেগ
# নির্দিষ্ট মুহূর্তে কৌণিক বেগ সময়ের অবকাশকে ক্ষুদ্র ক্ষুদ্রতর
# সময়ের অবকাশের সীমাস্থ মান শূন্য অবকাশে গড় কৌণিক বেগ তাৎক্ষণিক কৌণিক বেগের সমান
# অতি ক্ষুদ্র সময়ে কৌণিক সরণের পরিবর্তনের তাৎক্ষণিক হারকে তাৎক্ষণিক কৌণিক বেগ
# কৌণিক বেগের মান স্থির থাকলে বৃত্তীয় গতিকে সমবৃত্তীয় গতি
# আবর্তনরত কণার কৌণিক বেগ বাড়ে কমে
# কৌণিক বেগ পরিবর্তিত বোঝা কণাটি কৌণিক ত্বরণ চলছে
# নির্দিষ্ট অক্ষের চারদিকে ঘূর্ণায়মান বস্তুতে ত্বরণ সৃষ্টির প্রযুক্ত দ্বন্দ্বের ভ্রামককে টর্ক বলের ভ্রামক
# অক্ষের সাপেক্ষে ঘূর্ণনরত বস্তুর বিন্দুতে বল ক্রিয়াশীল বিন্দুর অবস্থান ভেক্টর প্রযুক্ত বলের ভেক্টর গুণফলকে টর্ক
# কৌণিক ত্বরণের আবর্তনরত বস্তুকণার ক্রিয়ারত দ্বন্দ্বের টর্ক ঘূর্ণাক্ষের সাপেক্ষে জড়তার ভ্রামক কৌণিক ত্বরণের গুণফলের সমান
# অক্ষের চারদিকে ঘূর্ণায়মান দৃঢ় বস্তুর টর্ক ক্রিয়া একক কৌণিক ত্বরণের সৃষ্টি অক্ষের সাপেক্ষে জড়তার ভ্রামক
# বস্তুর টর্কের লব্ধি শূন্য বস্তুটির কৌণিক ভরবেগ সংরক্ষিত
# বস্তুর ক্রিয়ারত বহিস্থ টর্কের লব্ধি শূন্য ঘূর্ণায়মান বস্তুর কৌণিক ভরবেগের পরিবর্তন এটিই কৌণিক ভরবেগের সংরক্ষণ সূত্র
# অভিকেন্দ্র বল সময় গতিপথের লম্বদিকে ক্রিয়া বলের অভিমুখে বস্তুর সরণ
# বৃত্তপথে আবর্তনরত বস্তুর ক্রিয়াশীল অভিকেন্দ্র বল বাইরে প্রযুক্ত
# সংঘর্ষের বস্তুর আপেক্ষিক বেগ অপরিবর্তিত সংঘর্ষকে পূর্ণ স্থিতিস্থাপক সংঘর্ষ
# সংঘর্ষের বস্তু যুক্ত পরস্পর বিচ্ছিন্ন সংঘর্ষের আপেক্ষিক বেগ সংঘর্ষের আগের আপেক্ষিক বেগের কম আংশিক স্থিতিস্থাপক সংঘর্ষ
# হালকা বস্তু ভারী স্থির বস্তুর সংঘর্ষে লিপ্ত ভারী বস্তুটি স্থির হালকা বস্তুটি দ্বিগুণ বেগে বিপরীত ছুটে
# সংঘর্ষের বস্তু পরস্পরের যুক্ত বস্তুরূপে চলতে অর্থাৎ সংঘর্ষের বস্তু দুটির আপেক্ষিক বেগ শূন্য অস্থিতিস্থাপক সংঘর্ষ
# সংঘাতাধীন বস্তু দুটির আপেক্ষিক গতিবেগ সংঘর্ষের সরলরেখা বরাবর সংঘাতকে একমাত্রিক সংঘর্ষ
# বলের ক্রিয়ায় বস্তু সমদ্রুতিতে বৃত্তপথে চলতে বল সবসময় বস্তুর গতিপথের লম্বভাবে ভেতরের অর্থাৎ বৃত্তের কেন্দ্রাভিমুখে ক্রিয়া কেন্দ্রমুখী অভিকেন্দ্র বল
# সমদ্রুতিতে বৃত্তপথে আবর্তনরত বস্তুর অভিকেন্দ্র বলের সমান বিপরীতমুখী অর্থাৎ কেন্দ্র বাইরেরর অলীক বল ক্রিয়া কেন্দ্রবিমুখী অপকেন্দ্র বল
# অতি অল্পসময়ের বৃহৎ বল ক্রিয়া বস্তুর গতির হঠাৎ ব্যাপক পরিবর্তন করাকে সংঘাত সংঘর্ষ
# বস্তুর বল প্রয়োগে বস্তুর সরণ ঘটলে প্রযুক্ত বল বলের অভিমুখে সরণের উপাংশের গুণফলকে
# সামর্থ্যকে শক্তি
# ধনাত্মক বলের বুঝায়
# ঋণাত্মক বলের বিরুদ্ধে বুঝায়
# বলের মানের দিকের একটির পরিবর্তন পরিবর্তনশীল বল
# স্থিতিস্থাপক সীমার বাইরে বল প্রয়োগে বস্তুর আকারআকৃতির পরিবর্তন ঘটানোর বল অপসারণ বলের কারণে পূর্বের আকারআকৃতি পায় স্থিতিস্থাপক বল
# ভূপৃষ্ঠের নিকটে অবস্থিত প্রতিটি বস্তুর পৃথিবীর আকর্ষণ বলকে অভিকর্ষ বল
# স্থিতিস্থাপক বল সরণের বর্গের সমানুপাতিক
# অভিকর্ষ বল উচ্চতার সরণের সমানুপাতিক
# অভিকর্ষজ ত্বরণের মান বৃদ্ধি পেলে বল কাজও বৃদ্ধি পায়
# গতিশীল বস্তু গতির সামর্থ্য শক্তি লাভ বস্তুটির গতিশক্তি
# গতিশীল বস্তু স্থিতিতে আসার পূর্ব মুহূর্ত পরিমাণ সম্পন্ন গতিশক্তির পরিমাপ
# মুহূর্তে গতিশক্তি মুহূর্তে বস্তুর বেগের বর্গ ভরের গুণফলের অর্ধেক
# বস্তুর গতিশক্তির বৃদ্ধি বস্তুর প্রযুক্ত বল কৃত কাজের সমান কাজশক্তি উপপাদ্য
# বস্তু অবস্থানের শক্তি অর্জন বস্তুস্থিত কণাসমূহের পারস্পরিক অবস্থান পরিবর্তনের বস্তু শক্তি অর্জন বস্তুর স্থিতিশক্তি বিভব শক্তি
# বস্তু বর্তমান অবস্থা স্বাভাবিক প্রমাণ অবস্থানে আসতে পরিমাণ সম্পন্ন স্থিতিশক্তির পরিমাপ
# স্থিতিস্থাপক সীমার বস্তুর বল প্রয়োগ বস্তুর বিকৃতি ঘটে
# শক্তি অবিনশ্বর শক্তি সৃষ্টি ধ্বংস এক রূপ রূপে রূপান্তরিত
# বিশ্বের শক্তির পরিমাণ ধ্রুবক
# শক্তি এক রূপ রূপে পরিবর্তিত ঘাটতি বাড়তি ঘটে
# উৎসের হারকে ক্ষমতা একক সময়ের কৃত ক্ষমতা পরিমাপ
# এক সেকেন্ডে এক জুল ক্ষমতাকে এক জুলসে এক ওয়ার্ট
# সেকেন্ডে জুল ক্ষমতাকে এক অশ্বক্ষমতা
# বল বস্তুর ক্রিয়া পথে ঘুরিয়ে পুনরায় অবস্থানে আনলে বল কর্তৃক শূন্য সংরক্ষণশীল বল
# অভিকর্ষীয় বল সংরক্ষণশীল বল বল কর্তৃক পুনরুদ্ধার সম্ভব
# বলের ক্রিয়ায় বস্তুকে এক বিন্দু অপর বিন্দুতে বল কর্তৃক বিন্দুদ্বয়ের অবস্থানের নির্ভর পথের নির্ভর সংরক্ষণশীল বল
# বল বস্তুর ক্রিয়া পথে ঘুরিয়ে পুনরায় অবস্থানে বল কর্তৃক শূন্য অসংরক্ষণশীল বল
# ঘর্ষণ বল কর্তৃক পুনরুদ্ধার সম্ভব ঘর্ষণ বল অসংরক্ষণশীল বল
# যন্ত্রে সরবরাহকৃত শক্তি পরিণত শক্তির অনুপাতকে কর্মদক্ষতা
# বায়ুশূন্য স্থানে বাধাহীন পথে সকল বস্তুই নিশ্চল অবস্থা যাত্রা সমান দ্রুততায় নিচে নামে অর্থাৎ সমান সময়ে সমান দূরত্ব অতিক্রম
# বাধাহীন পথে পড়ন্ত বস্তুর নির্দিষ্ট সময়ে প্রাপ্ত বেগ সময়ের সমানুপাতিক
# বাধাহীন পথে পড়ন্ত বস্তুর নির্দিষ্ট সময়ে অতিক্রান্ত দূরত্ব সময়ের বর্গের সমানুপাতিক
# প্রতিটি গ্রহ সূর্যকে উপবৃত্তের ফোকাসে উপবৃত্তাকার পথে প্রদক্ষিণ
# গ্রহ সূর্যের সংযোগকারী ব্যাসার্ধ রেখা সমান সময়ে সমান ক্ষেত্রফল অতিক্রম
# প্রতিটি গ্রহের পর্যায়কালের বর্গ সূর্য গড় দূরত্বের ঘনফলের সমানুপাতিক
# প্রতিটি গ্রহের পর্যায়কালের বর্গ গ্রহের কক্ষপথের পরাক্ষের অর্ধেকের ঘনএর সমানুপাতিক
# গ্রহের আবর্তন কাল সূর্য গড় দূরত্ব থাকলে যেকোনো গ্রহের আবর্তন কাল পর্যবেক্ষণ সূর্য দ্বিতীয় গ্রহের গড় দূরত্ব নির্ণয়
# গ্রহের আবর্তন কাল ভরের নির্ভর
# সূর্য গ্রহের গড় দূরত্ব কম অর্থাৎ গ্রহ সূর্যের নিকটে আবর্তনকাল কম
# গ্রহের পর্যায়কালের বর্গ কক্ষপথের গ্রহ সূর্যের মধ্যবর্তী দূরত্বের ঘনএর সমানুপাতিক
# একক ভরবিশিষ্ট বস্তুকণা একক দূরত্বে পরিমাণ বল পরস্পরকে আকর্ষণ সংখ্যাগত মানকে মহাকর্ষীয় ধ্রুবক
# বস্তুতে অভিকর্ষ বল কর্তৃক ত্বরণ উৎপন্ন অভিকর্ষজ ত্বরণ
# স্থানে অভিকর্ষের টানে মুক্তভাবে পড়ন্ত বস্তুর বেগ হারে বৃদ্ধি পায় স্থানের অভিকর্ষজ অভিকর্ষীয় ত্বরণ
# জায়গায় বস্তুর ভর অপরিবর্তিত থাকলেও অভিকর্ষজ ত্বরণের মান পরিবর্তিত
# সুষম নিরেট গোলক সুষম গোল খোলকের ভর নিজ নিজ কেন্দ্রে কেন্দ্রীভূত গোলক গোলকে অবস্থিত কণার মহাকর্ষ সূত্র আকর্ষণ বল নির্ণয়
# পৃথিবী বস্তু বস্তুকণার মধ্যকার আকর্ষণ বলকে অভিকর্ষ মাধ্যাকর্ষণ
# মহাবিশ্বের যেকোনো বস্তুকণা পরস্পরকে আকর্ষণ আকর্ষণ বল বস্তু দুটির ভরের গুণফলের সমানুপাতিক মধ্যকার দূরত্বের বর্গের ব্যস্তানুপাতিক
# বস্তু পরিমাণ বল পৃথিবীর কেন্দ্রের আকৃষ্ট ওজন ভার
# বস্তুর চারপাশে অঞ্চলব্যাপী মহাকর্ষীয় প্রভাব বজায় অর্থাৎ বস্তু আকর্ষণ বল লাভ বস্তুর মহাকর্ষীয় ক্ষেত্র
# মহাকর্ষীয় ক্ষেত্রের যেকোনো বিন্দুতে একক ভরের বস্তু স্থাপন ভরের বল ক্রিয়া বিন্দুতে মহাকর্ষীয় ক্ষেত্রের তীব্রতা
# সুষম গোলাকার খোলকের গোলকের ভেতরে অবস্থিত সকল বিন্দুতে প্রাবল্য শূন্য
# সুষম নিরেট গোলক সুষম গোলাকার গোলকের ভর নিজ নিজ কেন্দ্রে কেন্দ্রীভূত গোলক গোলকের বাইরে অবস্থিত বিন্দুতে প্রাবল্য নির্ণয়
# অসীম দূর একক ভরের বস্তুকে মহাকর্ষীয় ক্ষেত্রের বিন্দুতে আনতে পরিমাণ সাধিত বিন্দুর মহাকর্ষীয় বিভব
# একক ভরের বস্তুকে মহাকর্ষীয় ক্ষেত্রের এক বিন্দু বিন্দুতে আনতে পরিমাণ সাধিত বিন্দুর মহাকর্ষীয় বিভব পার্থক্য
# আকর্ষণ বলের অভিমুখে সরণ বিভব পার্থক্য ঋণাত্মক আকর্ষণ বলের বিরুদ্ধে সরণ বিভব পার্থক্য ধনাত্মক
# সুষম নিরেট গোলক সুষম গোলকের ভর নিজ নিজ কেন্দ্রে কেন্দ্রীভূত গোলক গোলকের বাইরে অবস্থিত বিন্দুতে বিভব নির্ণয়
# সুষম গোলকের ভেতরে অবস্থিত সকল বিন্দুতে বিভব স্থির বিভব গোলকের পৃষ্ঠের বিভবের সমান
# দূরত্ব সাপেক্ষে বিভবের পরিবর্তনের হারকে প্রাবল্য
# ভূপৃষ্ঠের মান কমে পৃথিবীর অভ্যন্তরে মান কমে
# পৃথিবীর কেন্দ্রে মান শূন্য ভূপৃষ্ঠেই মান সর্বাপেক্ষা
# বস্তুকে যেভাবেই ওজন বিন্দুর বস্তুর সর্বদা ক্রিয়া বিন্দুকে বস্তুর অভিকর্ষ কেন্দ্র ভারকেন্দ্র
# বস্তুর কণাগুলোর ভরকে বিন্দুতে কেন্দ্রীভূত বিন্দুর মধ্য দিয়েই কণার ভরের সমানুপাতিক ক্রিয়ারত সমান্তরাল বলসমূহের লব্ধি ক্রিয়া বিবেচিত বিন্দুকে বস্তুর ভরকেন্দ্র
# সর্বাপেক্ষা কম বেগে বস্তুকে ওপরের নিক্ষেপ পৃথিবীতে আসে বেগকে মুক্তিবেগ
# উপগ্রহের প্রদক্ষিণ বেগ মুক্তিবেগ অপেক্ষা কম উপগ্রহটি মহাশূন্যে বিলীন যেত
# মুক্তি বেগ বস্তুর ভরের নির্ভর
# নিউটনের মহাকর্ষ সূত্র স্থানে অভিকর্ষজ ত্বরণ নির্ণয়
# উপগ্রহ প্রাকৃতিক কারণে সৃষ্ট তাদেরকে স্বাভাবিক উপগ্রহ
# মানুষ মহাশূন্যে পাড়ি দেয়ার জন্যে উপগ্রহ তৈরি নাম কৃত্রিম উপগ্রহ
# কৃত্রিম উপগ্রহের আবর্তনকাল নিজ অক্ষের চারদিকে ঘূর্ণায়মান পৃথিবীর আবর্তনকালের সমান পৃথিবীর সাপেক্ষে স্থির ধরনের উপগ্রহকে ভূস্থির উপগ্রহ
# কৃত্রিম উপগ্রহ ভূপৃষ্ঠের নিকটে অর্থাৎ তুলনায় ছোট যেসব উপগ্রহ পৃথিবীকে বৃহত্তর ব্যাসার্ধের কক্ষপথে প্রদক্ষিণ আবর্তনকাল প্রদক্ষিণ বেগ কম
# সর্বাপেক্ষা কম বেগে বস্তুকে উপরের নিক্ষেপ পৃথিবীতে আসে বেগকে মুক্তিবেগ
# পদার্থের অণুগুলো পরস্পর বল যুক্ত ভৌত কাঠামো গঠন আন্তঃআণবিক আকর্ষণ বল
# কঠিন পদার্থের আন্তঃআণবিক আকর্ষণ সবচেয়ে আন্তঃআণবিক দূরত্ব সবচেয়ে কম
# কঠিন পদার্থের ক্ষুদ্রতম কণাগুলো পরম শূন্য তাপমাত্রার ঊর্ধ্বে যেকোনো তাপমাত্রায় নড়াচড়া চলাফেরা গতিশক্তি লাভ
# আন্তঃআণবিক আকর্ষণ বলের মান গতিশক্তির পদার্থ কঠিন অবস্থায়
# তরল অবস্থায় পদার্থের গঠনকারী কণাসমূহের আন্তঃকণা আকর্ষণ বল তুলনামূলকভাবে কম
# আন্তঃকণা ফাঁকা স্থান সামান্য চাপ প্রয়োগে তরল পদার্থের উল্লেখযোগ্য সংকোচন ঘটে
# গ্যাসীয় পদার্থের বেলায় আন্তঃআণবিক দূরত্ব সবচেয়ে আন্তঃআণবিক আকর্ষণ বল সবচেয়ে কম
# গ্যাসের পরমাণুসমূহের মধ্যকার দূরত্ব হ্রাস পেলে পজিটিভ চার্জযুক্ত নিউক্লিয়াসসমূহও পরস্পরকে বিকর্ষণ তখনই বিকর্ষণ বল উদ্ভূত
# আন্তঃআণবিক বল আন্তঃআণবিক দূরত্বের নির্ভরশীল
# অণু কাছাকাছি বিকর্ষণ বল
# অণুদ্বয়ের মধ্যবর্তী দূরত্ব একটু আকর্ষণ বল
# আন্তঃআণবিক দূরত্বের নির্দিষ্ট মান আকর্ষণ বিকর্ষণ বলের মান সমান অর্থাৎ দূরত্বে অণুদ্বয়ের লব্ধিবল শূন্য
# প্রযুক্ত বল বস্তুটিকে টেনে প্রসারিত চাইলে অণুসমূহের পারস্পরিক দূরত্ব বেড়ে প্রত্যায়ন বল আকর্ষিক
# প্রযুক্ত বল বস্তুটিকে সঙ্কুচিত চাইলে প্রত্যায়ন বল বিকর্ষিক
# বস্তুর সাম্যাবস্থানের প্রযুক্ত বল প্রত্যায়ন বল পরস্পর বিরোধী পরিমাণে সমান
# সমপরিমাণ সরণের বস্তুর স্থিতিস্থাপক বল সমান
# বস্তুর প্রযুক্ত বলের ক্রিয়ায় আকার আয়তন উভয়েরই পরিবর্তনের প্রচেষ্টাকে পদার্থের ধর্ম বাধা প্রযুক্ত বল অপসারিত পূর্বের আকার আয়তন পায় স্থিতিস্থাপকতা
# বিকৃতিকারী বল অপসারণের বস্তুর অবস্থার পুনঃ প্রাপ্তি ঘটে নমনীয় বস্তু বস্তুর ধর্মকে নমনীয়তা
# বস্তুর বল প্রয়োগ বল অপসারণ বস্তুটি পুরাপুরি পূর্বের অবস্থা পায় পূর্ণস্থিতিস্থাপক
# বস্তুর পরিমাণ বল প্রয়োগ বিকৃতি কায়িক পরিবর্তন ঘটানো বস্তুকে পূর্ণ দৃঢ় বস্তু
# প্রযুক্ত বাহ্যিক বলের সর্বোচ্চ ঊর্ধ্বসীমা বস্তু পূর্ণ স্থিতিস্থাপক বস্তুর স্থিতিস্থাপক সীমা
# ইস্পাত হীরার স্থিতিস্থাপক সীমা দস্তার স্থিতিস্থাপক সীমা কম
# ন্যূনতম নির্দিষ্ট ভারের ক্রিয়ায় বস্তু ভেঙ্গে ছিঁড়ে অসহ ভার অসহ ওজন
# বস্তুর একক ক্ষেত্রফলের প্রযুক্ত অসহ ভারকে অসহ পীড়ন
# বস্তু তারের ক্রমাগত পীড়নের হ্রাসবৃদ্ধি পীড়নের বিকৃতি বিকৃতি ধীর গতিতে সংঘটিত বস্তুর স্থিতিস্থাপক ধর্মের অবনতি ঘটে
# বস্তুর একক মাত্রায় পরিবর্তন ঘটে বিকৃতি পরিমাপ যায়
# বল প্রয়োগের বস্তুর দৈর্ঘ্যের পরিবর্তন ঘটে দৈর্ঘ্য বিকৃতি
# প্রযুক্ত বাহ্যিক বলের ক্রিয়ায় বস্তুর আয়তন অপরিবর্তিত কেবলমাত্র আকৃতির পরিবর্তন বস্তুটি মোচড় খায় ধরনের বিকৃতিকে কৃন্তন মোচড় বিকৃতি বস্তুর অভ্যন্তরে পীড়ন সৃষ্টি কৃন্তন পীড়ন
# আকার পরিবর্তনে সৃষ্ট কৌণিক বিকৃতি কৃন্তন মোচড় বিকৃতি পরিমাপ
# বল প্রয়োগের বস্তুর আয়তনের পরিবর্তন ঘটে আয়তন বিকৃতি একক আয়তনের আয়তন পরিবর্তন আয়তন বিকৃতি পরিমাপ
# দৈর্ঘ্য বিকৃতি ঘটাবার একক ক্ষেত্রফলের দৈর্ঘ্য বরাবর প্রযুক্ত বলকে দৈর্ঘ্য পীড়ন
# আকার বিকৃতি ঘটাবার পীড়ন প্রয়োগ কৃন্তন মোচড় পীড়ন
# আয়তন বিকৃতি ঘটাবার পীড়ন প্রয়োগ আয়তন পীড়ন
# স্থিতিস্থাপক সীমার বস্তুর প্রযুক্ত পীড়ন বিকৃতির সমানুপাতিক
# একক প্রস্থচ্ছেদের ক্ষেত্রফলে ন্যূনতম বলের ক্রিয়ায় তারটি ছিঁড়ে তারের অসহ পীড়ন
# স্থিতিস্থাপক সীমার বস্তুর পীড়ন বিকৃতির অনুপাত ধ্রুব সংখ্যা ধ্রুব সংখ্যাকে বস্তুর উপাদানের স্থিতিস্থাপক গুণাঙ্ক
# স্থিতিস্থাপক সীমার বস্তুর অনুদৈর্ঘ্য পীড়ন অনুদৈর্ঘ্য বিকৃতির অনুপাত ধ্রুব রাশি ধ্রুব রাশিকে বস্তুর উপাদানের ইয়ংএর গুণাঙ্ক
# স্থিতিস্থাপক সীমার বস্তুর আয়তন পীড়ন আয়তন বিকৃতির অনুপাত ধ্রুব সংখ্যা ধ্রুব সংখ্যাকে বস্তুর উপাদানের আয়তন গুণাঙ্ক
# বস্তুর চারদিক সমান চাপ প্রয়োগ বস্তুটির আয়তন কমে বস্তুর ধর্মকে সংনম্যতা
# তারের এক প্রান্ত দৃঢ় অবলম্বনের আটকিয়ে প্রান্তে বল প্রয়োগ টানলে দৈর্ঘ্য বিকৃতির পার্শ্ব বিকৃতি ঘটে অর্থাৎ তারের ব্যাস ব্যাসার্ধ কমে
# স্থিতিস্থাপক সীমার বস্তুর পার্শ্ব বিকৃতি দৈর্ঘ্য বিকৃতির অনুপাত ধ্রুব রাশি
# প্রবাহীর এক স্থান স্থানে গমন করাকে প্রবাহীর প্রবাহ
# প্রবাহ অসংনম্য অভ্যন্তরীণ সান্দ্রতা আদর্শ প্রবাহী
# যেকোনো বিন্দুতে প্রবাহীর বেগ সময়ের অপরিবর্তিত প্রবাহীর গতিকে স্থিতিশীল অবিচল গতি
# প্রবাহীর বেগ সময়ের অপেক্ষক অর্থাৎ সময় সময়ে বিন্দু বিন্দুতে পরিবর্তিত অস্থিতিশীল প্রবাহ
# সর্বক্ষণ প্রবাহীর বেগ ধ্রুব সমপ্রবাহ
# সর্বক্ষণ প্রবাহীর বেগ অসম প্রবাহ
# সর্বত্র প্রবাহীর বেগ সমান স্থির প্রবাহ
# সর্বত্র প্রবাহীর বেগ সমান অস্থির প্রবাহ
# প্রবাহীর স্তর পরস্পরের সমান্তরালে সমরেখ প্রবাহ
# প্ৰবাহীর স্তর পরস্পরের সমান্তরালে গতিতে আবর্ত ঘূর্ণীর সৃষ্টি বিক্ষিপ্ত প্রবাহ
# সর্বাধিক বেগ তরলের প্রবাহ ধারারেখ প্রবাহ বজায় রাখে বেগকে সংকট বেগ
# প্রবাহীর স্তর পরস্পরের সমান্তরালে গতিতে আবর্ত ঘূর্ণীর সৃষ্টি বিক্ষিপ্ত প্রবাহ বিশৃঙ্খল প্রবাহ
# ধর্মের দরুন প্রবাহী অভ্যন্তরস্থ স্তরের আপেক্ষিক বেগ রোধ প্রবাহীর সান্দ্রতা
# একক বেগ অবক্রমে প্রবাহীর একক ক্ষেত্রফলের পরিমাণ সান্দ্রতা বল ক্রিয়া প্রবাহীর সান্দ্রতা গুণাঙ্ক
# তরল পদার্থের পরীক্ষালব্ধ ফলাফলে তাপমাত্রা বাড়ালে সান্দ্রতা হ্রাস পায়
# তরলের সান্দ্রতার চাপের প্রভাব চাপ বৃদ্ধি পেলে সান্দ্রতা বাড়ে
# তরলের পৃষ্ঠে সরলরেখা কল্পনা উক্ত রেখার একক দৈর্ঘ্যে রেখার পার্শ্বে তরলের পৃষ্ঠ তলে এক অংশ অংশের স্পর্শক বল প্রয়োগ তাকেই পৃষ্ঠ টান
# পদার্থের অণুর পারস্পরিক আকর্ষণ বলকে সংসক্তি সংযুক্তি বল
# পদার্থের অণুগুলোর পারস্পরিক আকর্ষণ বলকে আসঞ্জন বল
# অণুর ক্রিয়ারত সংসক্তি বল সর্বাধিক যতটুকু দূরত্ব অনুভূত আন্তঃআণবিক পাল্লা
# অণুকে কেন্দ্র আণবিক পাল্লার সমান ব্যাসার্ধ গোলক কল্পনা অণুর প্রভাব গোলক
# তরুণ তলের ক্ষেত্রফল এক একক বৃদ্ধি পরিমাণ সাধিত তলের পৃষ্ঠ শক্তি
# তরলের পৃষ্ঠ শক্তি সংখ্যাগতভাবে তরলের পৃষ্ঠ টানের সমান
# কঠিন তরলের স্পর্শ বিন্দু বক্র তরল তলে অঙ্কিত স্পর্শক কঠিন বস্তুর তরলের কোণ উৎপন্ন উক্ত কঠিন তরলের মধ্যকার স্পর্শ কোণ
# স্পর্শ কোণ অপেক্ষা কম সূক্ষ্ম স্পর্শ কোণ
# স্পর্শ কোণ অপেক্ষা বড় স্থূল স্পর্শ কোণ
# বস্তু নির্দিষ্ট সময় স্থানে আসে স্থান নির্দিষ্ট সময় অন্তর অতিক্রম পর্যাবৃত্ত
# সরল দোলক এক বিন্দু যাত্রা পুনরায় বিন্দুতে আসতে সময় লাগে দোলকের পর্যায়কাল
# কিছুর পুনরাবৃত্তি স্থানের সাপেক্ষে স্থানিক পর্যায়ক্রম
# পর্যাবৃত্তির পর্যায়কাল নির্দিষ্ট সময় সাপেক্ষ কালিক পর্যায়ক্রম
# গতিশীল বস্তু কণার গতি গতিপথে নির্দিষ্ট বিন্দুকে নির্দিষ্ট সময় দিক অতিক্রম গতিকে পর্যাবৃত্ত গতি
# পর্যাবৃত্ত গতিসম্পন্ন কণা নির্দিষ্ট সময় নির্দিষ্ট বিন্দুকে নির্দিষ্ট দিক অতিক্রম সময়কে পর্যায়কাল
# পর্যাবৃত্ত গতির গতিপথ বৃত্তাকার উপবৃত্তাকার সরলরৈখিক আরো জটিল
# পর্যাবৃত্ত গতিসম্পন্ন কণা পর্যায়কালের অর্ধেক সময় নির্দিষ্ট বাকি অর্ধেক সময় পথে বিপরীত গতিকে স্পন্দন গতি
# সরল ছন্দিত গতি বল প্রত্যায়নী বল সরণের সমানুপাতিক বিপরীতমুখী
# দোলনরত কণার ত্বরণ সাম্যাবস্থান দূরত্বের সমানুপাতিক সময় সাম্যাবস্থানের অভিমুখী কণার গতিকে সরল ছন্দিত গতি
# সময় সাপেক্ষে সরণের পরিবর্তনের হারকে বেগ
# সময় সাপেক্ষে বেগের পরিবর্তনের হারকে ত্বরণ
# সরল ছন্দিত স্পন্দনসম্পন্ন কণার পূর্ণ স্পন্দন সম্পন্ন সময় ব্যয় পর্যায়কাল
# কম্পমান বস্তু স্পন্দক একক সময়ে যতগুলো পূর্ণ দোলন কম্পাঙ্ক
# সরল ছন্দিত স্পন্দন সম্পন্ন কণা একক সময়ে কৌণিক দূরত্ব অতিক্রম কৌণিক কম্পাঙ্ক
# সরল ছন্দিত স্পন্দনরত বস্তু কণার দশা মুহূর্তের দোলনের অবস্থা বুঝায় অর্থাৎ বস্তু কণাটির সরণ বেগ ত্বরণ গতির অভিমুখ বুঝায়
# পর্যায় গতিসম্পন্ন বস্তুর কার্যরত ত্বরণ গতিপথের নির্দিষ্ট বিন্দু অভিমুখে এমনভাবে ক্রিয়া মান বিন্দু বস্তুর সরণের মানের সমানুপাতিক বস্তুর উক্ত গতিকে সরল দোলন গতি
# এক স্থানে নির্দিষ্ট দৈর্ঘ্যবিশিষ্ট সরল দোলকের বিস্তার থাকলে প্রতিটি দোলনের সমান সময় লাগবে
# বিস্তার থাকলে নির্দিষ্ট স্থানে সরল দোলকের দোলন কাল কার্যকর দৈর্ঘ্যের বর্গমূলের সমানুপাতিক
# কার্যকর দৈর্ঘ্য গুণ বাড়লে দোলন কাল গুণ বাড়বে কার্যকর দৈর্ঘ্য গুণ কমলে দোলন কাল গুণ কমবে
# বিস্তার থাকলে নির্দিষ্ট দৈর্ঘ্যবিশিষ্ট সরল দোলকের দোলন কাল স্থানের অভিকর্ষীয় অভিকর্ষজ ত্বরণের বর্গমূলের ব্যস্তানুপাতিক
# বিস্তার কার্যকর দৈর্ঘ্য স্থির থাকলে স্থানে সরল দোলকের দোলন কাল দোলক পিণ্ডের ভর আকৃতি উপাদানের নির্ভর
# দোলকপিণ্ড বড় ছোট তামা সীসার ফাঁপা নিরেট কার্যকর দৈর্ঘ্য স্থির থাকলে স্থানে দোলকের দোলন কালের পরিবর্তন ঘটে
# সরল দোলকের গতির যান্ত্রিক শক্তির নিত্যতা সংরক্ষণ নীতি প্রযোজ্য
# শক্তি সরণের নির্ভর গতিপথের সর্বত্র মান স্থির
# বৃত্তাকার গতি এক ধরনের সরল দোলন গতি
# দৃঢ় অবলম্বন ওজনহীন নমনীয় অসম্প্রসারণীয় সুতা আয়তনহীন বস্তুকে ঝুলিয়ে বস্তুটিকে সরল ছন্দিত গতিতে দুলতে দিলে সরল দোলক তৈরি
# ত্বরণ সরণের সমানুপাতিক বিপরীতমুখী সরল দোলন গতির বৈশিষ্ট্যকে প্রকাশ
# সরল দোলকের দোলনকাল দোলককে সেকেন্ড দোলক থাকি
# অল্প বিস্তারে কম দোলায়মান সরল দোলকের গতি সরল দোলন গতি
# পর্যায়বৃত্ত আন্দোলন স্থিতিস্থাপক মাধ্যমের কণাগুলোর স্থানান্তর এক স্থান স্থানে শক্তি সঞ্চালিত তরঙ্গ
# শব্দ উৎপত্তির মূল উৎসই বস্তুর কম্পন
# আন্দোলনের মাধ্যমের কণাসমূহে যান্ত্রিক শক্তির সৃষ্টি কম্পনের এক স্থান স্থানে সঞ্চালিত
# তরঙ্গের বিস্তার
# তরঙ্গের কম্পন
# তরঙ্গের তরঙ্গদৈর্ঘ্য
# তরঙ্গ অগ্রগামী স্থির
# তরঙ্গ আড় কিম্বা লম্বিক
# তরঙ্গের তরঙ্গমুখ
# তরঙ্গ প্রতিফলন প্রতিসরণ ব্যতিচার অপবর্তন ঘটায়
# তরঙ্গ এক স্থান স্থানে শক্তি সঞ্চালিত
# মাধ্যমের কণাগুলো সরল দোল গতিতে কম্পিত তরঙ্গের সৃষ্টি সরল দোল তরঙ্গ সাইন তরঙ্গ
# সরল দোল তরঙ্গ প্রকারের যথা আড় তরঙ্গ অনুপ্রস্থ তরঙ্গ লম্বিক তরঙ্গ অনুদৈর্ঘ্য তরঙ্গ
# মাধ্যমের কণাগুলো তরঙ্গ অভিমুখের সমকোণে কম্পিত থাকলে তরঙ্গকে আড় তরঙ্গ অনুপ্রস্থ তরঙ্গ
# মাধ্যমের কণাগুলো তরঙ্গের গতির অভিমুখের সমান্তরালে কম্পিত থাকলে তরঙ্গকে লম্বিক অনুদৈর্ঘ্য তরঙ্গ
# সংকোচন প্রসারণের মধ্যবর্তী দূরত্বকে প্রসারণ সংকোচনের মিলিত দৈর্ঘ্যকে তরঙ্গ দৈর্ঘ্য
# তরঙ্গ উৎস উৎপন্ন সময়ের অগ্রসরমান চলমান অগ্রগামী তরঙ্গ
# অগ্রগামী তরঙ্গ আড় অনুদৈর্ঘ্য লম্বিক অনুপ্রস্থ উভয় ধরনের
# কম্পমান বস্তু বিন্দু যাত্রা দিক বিন্দুতে এলে পূর্ণ কম্পন
# তরঙ্গ সৃষ্টিকারী কম্পনশীল কণার পূর্ণ কম্পন সম্পন্ন সময় লাগে সময়ে তরঙ্গ দূরত্ব অতিক্রম তরঙ্গ দৈর্ঘ্য
# কম্পমান বস্তু কণা এক সেকেন্ডে যতগুলো পূর্ণ কম্পন সম্পন্ন কম্পাঙ্ক স্পন্দন সংখ্যা
# কম্পমান বস্তু পূর্ণ কম্পন সম্পন্ন সময় নেয় দোলনকাল পর্যায়কাল
# কম্পমান বস্তু সাম্যাবস্থান ডানে বামে নিচে সর্বাধিক দূরত্ব অতিক্রম বিস্তার
# দশা কম্পমান বস্তুর মুহূর্তের দোলনের অবস্থা প্রকাশ
# কম্পমান বস্তু দশা কম্পন আদি দশা
# তরঙ্গ এক সেকেন্ডে দূরত্ব অতিক্রম মাধ্যমের তরঙ্গ বেগ
# তরঙ্গের উপরিস্থিত সমদশাসম্পন্ন বিন্দুর মধ্য অঙ্কিত তলকে তরঙ্গ মুখ
# পরপর তরঙ্গ শীর্ষ তরঙ্গপাদ বরাবর অঙ্কিত তলের তরঙ্গ মুখের মধ্যবর্তী দূরত্ব এক তরঙ্গ দৈর্ঘ্য
# আড় তরঙ্গের ধনদিকে এক তরঙ্গ দৈর্ঘ্যে সর্বাধিক সরণের বিন্দুকে তরঙ্গ শীর্ষ
# আড় তরঙ্গের ঋণদিকে এক তরঙ্গ দৈর্ঘ্যে সর্বাধিক সরণের বিন্দুকে তরঙ্গ পাদ
# তরঙ্গের সমকোণে একক ক্ষেত্রফলের মধ্য এক সেকেণ্ডে পরিমাণ শক্তি প্রবাহিত তরঙ্গের তীব্রতা
# তীব্রতা বাড়ে অর্থাৎ শব্দ তরঙ্গ হারে শব্দ শক্তি কানে পৌঁছে শব্দের প্রাবল্য
# শব্দ বিস্তারের অভিমুখের লম্বভাবে একক ক্ষেত্রফলের মধ্য সেকেন্ডে পরিমাণ শব্দ শক্তি প্রবাহিত শব্দের তীব্রতা
# শব্দের তীব্রতা উৎসের কম্পনের বিস্তারের বর্গের সমানুপাতিক
# উৎসের আকার বড় উৎপন্ন শব্দের তীব্রতা বাড়ে
# উৎস শ্রোতার দূরত্ব শব্দের তীব্রতা কমে
# শব্দ মাধ্যমের মধ্য ঘনত্ব শব্দের তীব্রতাও
# মাধ্যমের গতির অভিমুখে শব্দের তীব্রতা বাড়ে বিপরীত শব্দের তীব্রতা কমে
# শব্দের কম্পমান উৎসের নিকটে বস্তু থাকলে উৎসের কম্পনের প্রভাবে বস্তুটিও কম্পাঙ্কে কম্পিত
# তরঙ্গ মাধ্যমের ভেতর এগোতে অপরটি সাপেক্ষে স্বাধীনভাবে সঞ্চালিত
# মাধ্যমের সীমিত অংশে পরস্পর বিপরীতমুখী সমান বিস্তার তরঙ্গ দৈর্ঘ্যের অগ্রগামী তরঙ্গ অপরের আপতিত তরঙ্গ সৃষ্টি স্থির তরঙ্গ
# স্থির তরঙ্গের উপরোস্থ বিন্দুতে বস্তুকণার বিস্তার শূন্য বিন্দুতে বিস্তার সর্বাধিক
# বিন্দুগুলোতে বিস্তার সর্বাধিক তাদেরকে সুস্পন্দ বিন্দু
# স্থির তরঙ্গের উপরোস্থ সকল বিন্দুতে বিস্তার শূন্য তাদেরকে নিস্পন্দ বিন্দু
# বস্তুর আরোপিত পর্যাবৃত্ত স্পন্দনের কম্পাঙ্ক বস্তুটির স্বাভাবিক কম্পাঙ্কের সমান বস্তুটি সর্বোচ্চ বিস্তারে কম্পিত ধরনের কম্পনকে অনুনাদ
# সকল অনুনাদই পরবশ কম্পন সকল পরবশ্ কম্পন অনুনাদ
# বৈশিষ্ট্য শব্দ শব্দ জোরালো বুঝা শব্দোচ্চতা
# শব্দোচ্চতা শব্দের তীব্রতার সমানুপাতিক হারে বাড়ে
# শব্দ সঞ্চালনের অভিমুখের লম্বভাবে স্থাপিত একক ক্ষেত্রফলের মধ্য পরিমাণ শক্তি সেকেন্ডে প্রবাহিত তীব্রতা
# শব্দের তীব্রতা আদর্শ প্রমাণ তীব্রতার শব্দের শব্দোচ্চতার পার্থক্যকে তীব্রতা লেভেল
# সমান সমান তীব্রতা সমান কম্পাঙ্কবিশিষ্ট অগ্রগামী শব্দ তরঙ্গের উপরিপাতনের শব্দের লব্ধি প্রাবল্যের হ্রাসবৃদ্ধির ঘটনাকে বীট স্বরকম্প
# শব্দের তীব্রতা গুণ বৃদ্ধি পায় শব্দোচ্চতা পরিমাণ বাড়ে বেল
# সকল গ্যাস গ্যাসের গতিতত্ত্বের মৌলিক স্বীকার্যসমূহ মেনে সকল তাপমাত্রায় চাপে বয়েল চার্লসের সূত্র যুগ্মভাবে মেনে আদর্শ গ্যাস
# আদর্শ গ্যাস সকল তাপমাত্রায় চাপে সমীকরণ মেনে
# স্থির তাপমাত্রায় আদর্শ গ্যাসের অভ্যন্তরীণ শক্তি আয়তনের নির্ভরশীল
# আদর্শ গ্যাসের অণুসমূহের আকর্ষণবিকর্ষণ
# আদর্শ গ্যাসের অণুসমূহের আয়তন গ্যাস দখলকৃত আয়তনের তুলনায় নগণ্য
# গ্যাসের আয়তন তাপমাত্রা চাপ তিনটিকে গ্যাসের চল রাশি
# তাপমাত্রা চাপে পদার্থ বায়বীয় অবস্থায় তাদেরকে গ্যাস
# তাপমাত্রা স্থির থাকলে নির্দিষ্ট ভরের গ্যাসের আয়তন চাপের ব্যস্তানুপাতিক
# চাপের আয়তনের মানের স্থির উষ্ণতায় নির্দিষ্ট ভরের গ্যাসের আয়তন চাপ লেখচিত্র সমপরাবৃত্ত
# বয়েলের সূত্র উচ্চ তাপমাত্রায় কম চাপে বিশেষভাবে প্রযোজ্য নিম্ন তাপমাত্রায় উচ্চ চাপে সূত্র বিচ্যুতি
# নির্দিষ্ট চাপে নির্দিষ্ট ভরের গ্যাসের আয়তন পরম তাপমাত্রার সমানুপাতিক এটিই পরম স্কেলে চার্লসের সূত্র
# এক মোল আদর্শ গ্যাসের তাপমাত্রা এক ডিগ্রী বাড়ালে পরিমাণ সম্পন্ন সর্বজনীন গ্যাস ধ্রুবক
# গ্যাসের গতিতত্ত্ব গ্যাসের গতির প্রকৃতি উদ্ভূত তাপের সম্পর্ক
# গ্যাসের অণুগুলো বিন্দুভর আদর্শ স্থিতিস্থাপক গোলক
# ধাক্কা সংঘটিত সময় লাগে মুক্ত পথ অতিক্রম সময়ের তুলনায় অতি নগণ্য ধাক্কাগুলো তাৎক্ষণিক
# আদর্শ গ্যাসের আণবিক ঘনত্ব সর্বদা স্থির
# গ্যাসের পরম তাপমাত্রা অণুগুলোর গতিশক্তির সমানুপাতিক
# গ্যাস অণুর গড় গতিশক্তি পরম তাপমাত্রার সমানুপাতিক
# আদর্শ গ্যাসের অণুগুলির যেহেতু আকর্ষণ বিকর্ষণ সেহেতু স্থিতিশক্তি শূন্য
# গ্যাসের গতিশীলতার তাপ উৎপন্ন গ্যাসের গতিতত্ত্ব
# মূল গড় বর্ণ বেগ পরম তাপমাত্রার বর্গমূলের সমানুপাতিক
# নির্দিষ্ট ভরের গ্যাসের অণুর গতিশক্তি পরম তাপমাত্রার সমানুপাতিক
# পরম শূন্য তাপমাত্রায় অণুর গতিশক্তি শূন্য
# তাপমাত্রায় প্রমাণ চাপে বরফ গলে পানিতে পরিণত পানি জমে বরফে পরিণত তাপমাত্রাকে প্রমাণ তাপমাত্রা
# সেলসিয়াস স্কেলে প্রমাণ তাপমাত্রা কেলভিন স্কেলে
# অক্ষাংশে তাপমাত্রায় উল্লম্বভাবে অবস্থিত উচ্চতাবিশিষ্ট শুষ্ক বিশুদ্ধ পারদ স্তম্ভ চাপ প্রমাণ চাপ
# বস্তুর গতিশীল অবস্থা অবস্থান সম্পূর্ণরূপে প্রকাশ সংখ্যক স্বাধীন চলরাশির প্রয়োজন স্বাধীনতার মাত্রা
# গতীয় সংস্থার শক্তি তাপীয় সাম্যাবস্থায় প্রতিটি স্বাধীনতার মাত্রার সমভাবে বণ্টিত
# এক পারমাণবিক গ্যাসের অণুর স্বাধীনতার মাত্রা
# দ্বিপারমাণবিক গ্যাসের অণুর স্বাধীনতার মাত্রা
# স্থানে পানির উৎসের উপস্থিতি অক্ষাংশ সমুদ্র পৃষ্ঠ অবস্থান প্রভৃতির বায়ুমণ্ডলের জলীয় বাষ্পের পরিমাণ নির্ভর
# দ্রব্যের সুষ্ঠু উৎপাদন গুদামজাতকরণে বায়ুমণ্ডলের জলীয় বাষ্পের পরিমাণ তাপমাত্রা নির্দিষ্ট সীমার প্রয়োজন
# জলীয় বাষ্পের পরিমাণ চাপও
# বায়ুতে অণুসমূহ অবিরত ইতস্তত ছুটাছুটি পাত্রের একক ক্ষেত্রফলের বায়ুর অণুসমূহ বল প্রয়োগ বায়ুর চাপ
# তাপমাত্রায় অক্ষাংশে সমুদ্র সমতলে পরিমাণ বায়ুচাপ পারদস্তম্ভের চাপের সমান এক বায়ুমণ্ডলীয় চাপ এক বায়ুচাপ
# নির্দিষ্ট তাপমাত্রায় আবদ্ধ স্থানের বাষ্পধারণ ক্ষমতা নির্দিষ্ট অতিরিক্ত বাষ্প ধারণ অবস্থায় বাষ্প চাপ সম্পৃক্ত বাষ্প চাপ
# নির্দিষ্ট তাপমাত্রায় স্থানে বাষ্পের পরিমাণ অতিরিক্ত বাষ্প ধারণ বাষ্পকে অসম্পৃক্ত বাষ্প
# স্থির তাপমাত্রায় বায়ুর ঘনত্ব উহার চাপের সমানুপাতিক
# সম্পৃক্ত বাষ্প বয়েল চার্লসএর সূত্র মানে
# সম্পৃক্ত বাষ্পের সংস্পর্শে তরল পদার্থ থাকলে স্থির তাপমাত্রায় বাষ্পের আয়তন বৃদ্ধি তরল পদার্থ বাষ্পীভূত হবার স্থান বাষ্প অসম্পৃক্ত
# তাপমাত্রা বৃদ্ধি নির্দিষ্ট পরিমাণ সম্পৃক্ত বাষ্পকে অসম্পৃক্ত বাষ্পে পরিণত
# অসম্পৃক্ত বাষ্প বয়েল চার্লসএর সূত্র মেনে
# নির্দিষ্ট পরিমাণ অসম্পৃক্ত বাষ্পের তাপমাত্রা স্থির আয়তন ক্রমাগত কমাতে থাকলে এক সময় স্থান বাষ্প সম্পৃক্ত
# তাপমাত্রা কমিয়ে নির্দিষ্ট পরিমাণ অসম্পৃক্ত বাষ্পকে সম্পৃক্ত বাষ্পে পরিণত
# তাপমাত্রায় নির্দিষ্ট আয়তনের বায়ু ভেতরের জলীয় বাষ্প সম্পৃক্ত বায়ুর শিশিরাঙ্ক
# স্থানের বায়ুর শিশিরাঙ্ক বুঝা তাপমাত্রায় স্থানের বায়ু মধ্যস্থ জলীয় বাষ্প সম্পৃক্ত
# বায়ুর তাপমাত্রায় নির্দিষ্ট আয়তনের অসম্পৃক্ত জলীয় বাষ্পের চাপ শিশিরাঙ্কে সম্পৃক্ত জলীয় বাষ্পের চাপের সমান
# সময় স্থানের একক আয়তনের বায়ুতে পরিমাণ জলীয় বাষ্প বায়ুর পরম আর্দ্রতা
# নির্দিষ্ট তাপমাত্রায় নির্দিষ্ট আয়তনের বায়ুতে পরিমাণ জলীয় বাষ্প তাপমাত্রায় আয়তনের বায়ুকে সম্পৃক্ত পরিমাণ জলীয় বাষ্পের প্রয়োজন অনুপাতকে আপেক্ষিক আর্দ্রতা
# জলীয় বাষ্প শিশিরাঙ্কে স্থানের বায়ু সম্পৃক্ত
# বায়ুমণ্ডলে উপস্থিত জলীয় বাষ্পের পরিমাণের বায়ুমণ্ডলের সম্পৃক্ততার মাত্রা কতখানি আপেক্ষিক আর্দ্রতা পরিমাপ
# যন্ত্র বস্তুর তাপমাত্রা নির্ভুলভাবে পরিমাপ থার্মোমিটার
# তাপমাত্রা পরিমাপ উপযোগী পদার্থের সকল ধর্ম লাগানো পদার্থের ধর্মগুলিকে উষ্ণতামিতি ধৰ্ম সকল পদার্থের উষ্ণতামিতি ধর্ম থার্মোমিটার তৈরি তাদেরকে উষ্ণতামিতি পদার্থ
# একাধিক বস্তু তাপীয়ভাবে সংযুক্ত তাপের আদান প্রদান ঘটলে বস্তুগুলি তাপীয় সমতায়
# বস্তু তৃতীয় বস্তুর তাপীয় সাম্যাবস্থায় প্রথমোক্ত বস্তু পরস্পরের তাপীয় সাম্যাবস্থায়
# তাপমাত্রা বস্তুর উত্তপ্ততার পরিমাণ বুঝায়
# তাপমাত্রা বস্তুর তাপীয় অবস্থা বস্তু বস্তুতে তাপের প্রবাহ নিয়ন্ত্রণ তাপ প্রবাহের অভিমুখ নির্ধারণ
# তাপগতীয় ব্যবস্থা সিস্টেম তল বেষ্টনী সীমাবদ্ধ নির্দিষ্ট পরিমাণ বস্তুকে বুঝায় তাপগতীয় চলরাশি চাপ আয়তন তাপমাত্রা পরিমাপ
# নির্দিষ্ট ব্যবস্থার শক্তি বিনিময়ে সক্ষম ব্যবস্থাকে ব্যবস্থার পরিপার্শ্ব
# সকল রাশির মান ব্যবস্থার অবস্থা নির্ধারণ সেগুলিকে ব্যবস্থার তাপগতীয় স্থানাঙ্ক অবস্থা পরিবর্তী
# বিচ্ছিন্ন ব্যবস্থার চূড়ান্ত অবিচল অবস্থাকে তাপগতীয় সাম্যাবস্থা
# সাম্যাবস্থায় ব্যবস্থার সকল বিন্দুতে তাপগতীয় স্থানাঙ্ক অর্থাৎ চাপ আয়তন তাপমাত্রার মান সমান
# ব্যবস্থার তাপগতীয় স্থানাঙ্কসমূহের পরিবর্তনকে তাপগতীয় প্রক্রিয়া
# সিস্টেমের শক্তি অন্তর্নিহিত সুপ্ত অবস্থায় পরিবেশ পরিস্থিতিতে বহিঃপ্রকাশ ঘটায় অভ্যন্তরীণ শক্তি
# সম্পূর্ণভাবে তাপে তাপ সম্পূর্ণভাবে রূপান্তরিত তাপ পরস্পরের সমানুপাতিক
# ব্যবস্থায় তাপ সরবরাহ ব্যবস্থা কর্তৃক তাপ গৃহীত কিয়দংশ অভ্যন্তরীণ শক্তি বৃদ্ধি অর্থাৎ তাপমাত্রা বৃদ্ধি অবশিষ্ট অংশ বাহ্যিক সম্পাদনে ব্যয়
# ব্যবস্থায় সম্পন্ন অভ্যন্তরীণ শক্তির পরিবর্তনের সমষ্টি সর্বদা প্রযুক্ত তাপের সমান
# যন্ত্রের উদ্ভাবন জ্বালানি শক্তি ব্যতিরেকে সক্ষম অর্থাৎ অনন্ত গতিযুক্ত যন্ত্র উদ্ভাবন সম্ভব শক্তি ব্যয় সম্ভব
# প্রক্রিয়ায় সিস্টেমের তাপমাত্রা স্থির চাপ আয়তন পরিবর্তিত সমোষ্ণ প্রক্রিয়া
# প্রক্রিয়ায় সিস্টেমের তাপ ধ্রুব চাপ আয়তন পরিবর্তিত রুদ্ধতাপীয় প্রক্রিয়া
# প্রক্রিয়ায় সিস্টেমের আয়তন ধ্রুব ধ্রুব আয়তন প্রক্রিয়া
# আবেষ্টনী আবদ্ধ নির্দিষ্ট পরিমাণ বস্তুকে তাপীয় ব্যবস্থা সিস্টেম হিসেবে
# পরীক্ষানিরীক্ষার সময় জড় জগতের নির্দিষ্ট তাপীয় অংশ বিবেচনা তাপীয় সিস্টেম
# প্রত্যেক তাপীয় সিস্টেমের একটা নির্দিষ্ট আয়তন ভর অন্তস্থ শক্তি
# উন্মুক্ত সিস্টেম পরিবেশের ভর শক্তির উভয়ই বিনিময়
# বদ্ধ সিস্টেম পরিবেশের শক্তি বিনিময় ভর বিনিময়
# বিচ্ছিন্ন সিস্টেম পরিবেশ মোটেও প্রভাবিত অর্থাৎ এক্ষেত্রে ভর শক্তি বিনিময়
# পরিবর্তনে গ্যাসের চাপের আয়তনের পরিবর্তন তাপমাত্রা স্থির পরিবর্তনকে সমোষ্ণ পরিবর্তন পদ্ধতিতে পরিবর্তন সংঘটিত সমোষ্ণ প্রক্রিয়া
# প্রক্রিয়ায় সিস্টেম তাপ গ্রহণ তাপ বর্জন রুদ্ধতাপীয় প্রক্রিয়া
# পরিবর্তনে তাপ বাহির সরবরাহ গ্যাস অপসারণ গ্যাসের চাপ আয়তনের পরিবর্তন ঘটে রুদ্ধতাপীয় পরিবর্তন
# প্রত্যেক ব্যবস্থাএর নির্দিষ্ট পরিমাণ শক্তি সম্পাদন শক্তিতে রূপান্তরিত
# বস্তুর মধ্যস্থ অণুপরমাণুর গতিশক্তি মধ্যকার আন্তঃআণবিক বলের কারণে সৃষ্ট শক্তিকে অভ্যন্তরীণ শক্তি
# সিস্টেমের বস্তুর শক্তি লুক্কায়িত সুপ্ত অবস্থায় পরিবেশ পরিস্থিতিতে বহিঃপ্রকাশ ঘটায় অভ্যন্তরীণ শক্তি
# নির্দিষ্ট পরিমাণ গ্যাসের অভ্যন্তরীণ শক্তি শুধুমাত্র তাপমাত্রার নির্ভর চাপ আয়তনের নির্ভর মেয়ারের প্রকল্প
# কিছুর দক্ষতা এক
# বাইরের শক্তির সাহায্য ব্যতিরেকে স্বয়ংক্রিয় যন্ত্রের নিম্ন তাপমাত্রার বস্তু উচ্চ তাপমাত্রার বস্তুতে তাপের স্থানান্তর সম্ভব
# বস্তুকে পরিপার্শ্বের শীতলতম অংশ অধিকতর শীতল শক্তির অবিরাম সরবরাহ সম্ভব
# তাপ উৎস অনবরত তাপ শোষণ সম্পূর্ণরূপে রূপান্তরিত এরূপ তাপ ইঞ্জিন তৈরি সম্ভব
# নির্দিষ্ট পরিমাণ তাপ শক্তি সম্পূর্ণ পুরোপুরিভাবে যান্ত্রিক শক্তিতে রূপান্তর যন্ত্র তৈরি সম্ভব
# প্রক্রিয়া বিপরীতমুখী প্রত্যাবর্তন সম্মুখবর্তী বিপরীতমুখী প্রক্রিয়ার স্তরে তাপ কাজের ফলাফল সমান বিপরীত প্রক্রিয়াকে প্রত্যাগামী প্রত্যাবর্তী প্রক্রিয়া
# প্রক্রিয়া সম্মুখগামী বিপরীতমুখী প্রত্যাবর্তন অপ্রত্যাবর্তী প্রক্রিয়া
# চক্রে আদর্শ গ্যাস কার্যকরী পদার্থ হিসেবে নির্দিষ্ট আয়তন চাপ তাপমাত্রা আরম্ভ সমোষ্ণ প্রসারণ রুদ্ধতাপ প্রসারণ সমোষ্ণ সংকোচন রুদ্ধতাপ সংকোচনের পূর্বাবস্থায় আসে কার্নো চক্র
# যন্ত্র তাপশক্তিকে যান্ত্রিক শক্তিতে রূপান্তর তাপ ইঞ্জিন
# যন্ত্রের সাহায্যে পরিবেশ অপেক্ষা কম তাপমাত্রা সৃষ্টি তাপমাত্রা সর্বদা স্থির অবস্থায় রেফ্রিজারেটর
# তাপ ইঞ্জিন কাজের রূপান্তরিত তাপশক্তির পরিমাণ ইঞ্জিন শোষিত তাপশক্তির পরিমাণের অনুপাতকে ইঞ্জিনের দক্ষতা কর্মদক্ষতা
# রুদ্ধতাপ প্রক্রিয়ায় বস্তুর তাপীয় ধর্ম স্থির এনট্রপি
# সংস্থা চক্রের তাপমাত্রা সাপেক্ষে গৃহীত বর্জিত তাপের পরিবর্তনের হার এন্ট্রপি পরিমাপ
# প্রকৃতির সকল ভৌত রাসায়নিক ক্রিয়া এমনভাবে সংঘটিত সার্বিক ব্যবস্থার এন্ট্রপি বৃদ্ধি পায়
# ঘর্ষণের প্রত্যেক বস্তু বস্তুকে কমবেশি আকর্ষণ তড়িতাহিতকরণ ধর্ম নামে পরিচিত
# কুলম্বের সূত্র কেবলমাত্র বিন্দু চার্জের প্রযোজ্য
# আহিত চার্জিত বস্তুর আকার খুবই ক্ষুদ্র চার্জিত বস্তুর চার্জকে বিন্দু চার্জ
# নির্দিষ্ট বিন্দু চার্জের ক্রিয়াশীল আকর্ষণ বিকর্ষণ বলের মান চার্জ দুটির গুণফলের সমানুপাতিক চার্জ দুটির মধ্যবর্তী দূরত্বের বর্গের ব্যস্তানুপাতিক বল চার্জ দুটির সংযোজক সরলরেখা বরাবর ক্রিয়া
# চার্জ অবস্থিত মাধ্যমের ভেদনযোগ্যতা সংক্ষেপে ভেদ্যতা
# সমমানের চার্জ শূন্য মিটার দূরে অবস্থান পরস্পরের বল প্রয়োগ চার্জ দুটির প্রত্যেককে একক চার্জ একক চার্জকে এক কুলম্ব
# নির্ণীত মান ধন রাশি বল বিকর্ষণমূলক জাতীয় রাশির গুণফল ধন রাশি
# নির্ণীত মান ঋণ রাশি বল আকর্ষণমূলক বিপরীত রাশির গুণফল ঋণ রাশি
# চার্জিত বস্তুর মধ্যবর্তী দূরত্ব অসীম কেবল তখনই পারস্পরিক স্থির তড়িৎ বলের মান শূন্য
# তড়িৎক্ষেত্রের বিন্দুতে স্থাপিত আধানের ক্রিয়াশীল বল তড়িৎবল বিন্দুতে প্রাবল্য স্থাপিত আধানের গুণফলের সমান
# ধনাত্মক আধান প্রাবল্যের অভিমুখে বল লাভ ঋণাত্মক আধান প্রাবল্যের বিপরীত বল লাভ
# অত্যন্ত ক্ষুদ্র মানের কাল্পনিক চার্জ চার্জের বল প্রয়োগ অর্থাৎ আশেপাশের চার্জকে প্রভাবিত পরখ চার্জ
# চার্জিত বস্তু চারদিকে অঞ্চল ব্যাপী প্রভাব বিস্তার অঞ্চলকে চার্জিত বস্তুর তড়িৎ ক্ষেত্র
# তল পৃষ্ঠের ভেতর যতগুলো তড়িৎ বলরেখা অতিক্রম তড়িৎ ফ্লাক্স
# তড়িৎ ক্ষেত্র তলের অভিলম্ব সমান্তরাল অবস্থানে তড়িৎ ফ্লাক্স সর্বাধিক
# তড়িৎ ক্ষেত্র তলের অভিলম্ব সমকোণে তড়িৎ ফ্লাক্স শূন্য
# তড়িৎ ক্ষেত্রের মান দিক সর্বত্র সমান সুষম তড়িৎ ক্ষেত্র
# বিন্দুতে একক আধান চার্জের ক্রিয়াশীল বলকে তড়িৎ ক্ষেত্রের প্রাবল্য
# দিক ধনাত্মক পরখ চার্জের ক্রিয়াশীল বলের দিক
# তড়িৎ বলের মানকে চার্জের মান ভাগ ভাগফলই তড়িৎ ক্ষেত্রের প্রাবল্যের তড়িৎ ক্ষেত্রের মান
# চার্জিত আহিত বস্তু দুটির বিভব পার্থক্য থাকলেই শুধুমাত্র চার্জের প্রবাহ ঘটবে
# উচ্চ বিভববিশিষ্ট চার্জিত বস্তু নিম্ন বিভবের চার্জিত বস্তুতে চার্জের প্রবাহ সৃষ্টি
# চার্জিত বস্তুর চার্জের আদানপ্রদান তড়িৎ অবস্থার নির্ধারিত তড়িৎ বিভব
# তড়িৎ ক্ষেত্রের বিন্দুতে স্থাপিত চার্জ বিভব শক্তিকে চার্জ ভাগ মান বিন্দুর তড়িৎ বিভব
# অসীম দূর একক ধন চার্জকে তড়িৎ ক্ষেত্রের বিন্দুতে আনতে পরিমাণ সাধিত উক্ত ক্ষেত্রের দরুন বিন্দুর বিভব তড়িৎ বিভব
# যেহেতু একক ধন চার্জ স্থানান্তরে কৃত বিভব পরিমাপ কাজেই কাজের ন্যায় বিভবেরও অভিমুখ কেবল পরিমাণ
# অসীম দূরত্ব কুলম্ব ধন চার্জকে তড়িৎ ক্ষেত্রের বিন্দুতে আনতে জুল বিন্দুর বিভবকে ভোল্ট
# তড়িৎ ক্ষেত্রের বিন্দুর তড়িৎ বিভবের ব্যবধানকে বিভব পার্থক্য বিভব বৈষম্য
# তড়িৎ ক্ষেত্রের এক বিন্দু অপর বিন্দুতে একক ধন চার্জকে স্থানান্তর পরিমাণ সাধিত বিন্দুর মধ্যকার বিভব পার্থক্য
# তড়িৎ ক্ষেত্রের বিন্দুর বিভব পার্থক্য মুক্ত ইলেকট্রন এক বিন্দু অপর বিন্দুতে গতিশীল গতিশক্তি অর্জন ইলেকট্রন ভোল্ট সংক্ষেপে
# বৈদ্যুতিক ক্ষেত্রের বিন্দুর তড়িৎ প্রাবল্য বিন্দুতে দূরত্ব সাপেক্ষে বিভবের পরিবর্তনের হারের সমান
# তল আয়তন এরূপ বিভব সর্বত্র সমান তল আয়তনকে সমবিভব তল আয়তন
# যেহেতু সমবিভব তলের সকল বিন্দুতে বিভব সমান তলের বিন্দুর বিভব পার্থক্য শূন্য
# চার্জকে সম বিভব তলের এক বিন্দু বিন্দুতে কাজের প্রয়োজন
# সমবিভব তলের বিন্দুতে তড়িৎ ক্ষেত্রের প্রাবল্য তড়িৎ প্রাবল্য তলের লম্বভাবে ক্রিয়া
# দুইটি সমপরিমাণ বিপরীতধর্মী বিন্দু চার্জ পরস্পরের কাছাকাছি থাকলে তড়িৎ দ্বিমেরু গঠিত
# সকল পদার্থের মধ্য তড়িৎ প্রবাহ চলতে তাদেরকে অপরিবাহী অন্তরক পদার্থ
# বিন্দু চার্জের মধ্যবর্তী স্থান শূন্য বায়ু মাধ্যম ভিন্ন অপরিবাহী অন্তরক মাধ্যম বিন্দু চার্জ দুটিকে পরস্পর বিচ্ছিন্ন রাখে এরূপ মাধ্যমকে তড়িৎ বিভাজক ডাইইলেকট্রিক মাধ্যম
# সাধারণভাবে পরাবিদ্যুৎএর বিন্দুতে লব্ধি প্রাবল্য বহিস্থ প্রাবল্যের কম কখনই পরিবাহীর পরাবিদ্যুৎএর প্রাবল্য শূন্য
# নির্দিষ্ট বিন্দু চার্জ নির্দিষ্ট দূরত্বে থাকলে শূন্য বায়ু ক্রিয়াশীল বল দূরত্বে ক্রিয়াশীল বলের অনুপাতকে পরাবৈদ্যুতিক ধ্রুবক
# স্থির তড়িৎবিদ্যায় ধারক বস্তুর ধারকত্ব বৃদ্ধি কৃত্রিম ব্যবস্থা বুঝায়
# যান্ত্রিক প্রক্রিয়ার সাহায্যে তড়িৎ সংরক্ষণ ধারক
# ধারকের মধ্যবর্তী মাধ্যম বায়ু বায়ু মাধ্যম ধারক সংক্ষেপে বায়ু ধারক কাচ কাচ মাধ্যম ধারক সংক্ষেপে কাচ ধারক
# ধারকের অন্তরীত ভূসংযুক্ত পরিবাহীর একক বিভব বৈষম্য সৃষ্টি অন্তরীত পরিবাহীতে পরিমাণ চার্জ প্রদান উক্ত ধারকের ধারকত্ব
# ক্ষেত্রফল বৃদ্ধি পায় পরিবাহীর ধারকত্ব বেড়ে
# পরিবাহীর চতুর্দিকের মাধ্যমের পরাবৈদ্যুতিক ধ্রুবকের ধারকত্ব নির্ভর
# সমান্তরাল পাত ধারকের মধ্যবর্তী দূরত্ব বৃদ্ধি পেলে ধারকত্ব কমে দূরত্ব কমলে ধারকত্ব বৃদ্ধি পায়
# চার্জগ্রস্ত পরিবাহীর নিকটে চার্জশূন্য ভূসংযুক্ত পরিবাহী থাকলে বৈদ্যুতিক আবেশের দরুন পরীক্ষাধীন পরিবাহীর ধারকত্ব বৃদ্ধি পাবে
# পরিবাহীর বিভব ভোল্ট বৃদ্ধি কুলম্ব চার্জের প্রয়োজন ধারকত্বকে ফ্যারাড
# ধারকের সমবায়ের পরিবর্তে ধারক ধারকের পাতে চার্জ বিভব পার্থক্য সমবায়ের চার্জ বিভব পার্থক্যের সমান ধারকের ধারকত্বকে সমবায়ের তুল্য ধারকত্ব
# কতকগুলো ধারককে এমনভাবে যুক্ত ধারকের দ্বিতীয় পাত দ্বিতীয় ধারকের পাতের দ্বিতীয় ধারকের দ্বিতীয় পাত তৃতীয় ধারকের পাতের একের এক যুক্ত সর্বশেষ ধারকের শেষ পাত ভূসংযুক্ত শ্রেণিবিন্যাস
# কতগুলো ধারককে এমনভাবে যুক্ত প্রত্যেক ধারকের পাত এক বিন্দুতে দ্বিতীয় পাত অপর এক বিন্দুতে যুক্ত ধারকের সমান্তরাল সংযোজন
# চার্জের চারদিকে কল্পিত বন্ধ তলকে গাউসীয় তল
# চার্জিত কণাসমূহের বেগ আলোর বেগের কাছাকাছি কণাসমূহের বিদ্যমান পারস্পরিক তড়িৎ চুম্বকীয় মিথস্ক্রিয়া কুলম্বের সূত্র ব্যাখ্যা সম্ভব
# সদৃশ চার্জ বিন্যাসের কুলম্বের সূত্র প্রয়োগ দুরূহ
# ধর্মের পরিবাহী মধ্য বিদ্যুৎ চলাচলে বাধা প্রদান রোধ
# ডিগ্রী সেলসিয়াস তাপমাত্রা বৃদ্ধির একক রোধসম্পন্ন পরিবাহীর রোধের পরিবর্তন উক্ত পরিবাহীর রোধের তাপমাত্রা গুণাঙ্ক উষ্ণতা গুণাঙ্ক
# বিদ্যুৎবাহী পরিবাহীর রোধ বিদ্যুৎ প্রবাহ কাল অপরিবর্তিত থাকলে পরিবাহীতে বিদ্যুৎ প্রবাহের দরুন উদ্ভূত তাপ বিদ্যুৎ প্রবাহমাত্রার বর্গের সমানুপাতিক
# বিদ্যুৎ প্রবাহমাত্রা বিদ্যুৎ প্রবাহ কাল অপরিবর্তিত থাকলে পরিবাহীতে বিদ্যুৎ প্রবাহের দরুন উদ্ভূত তাপ পরিবাহীর রোধের সমানুপাতিক
# বিদ্যুৎবাহী পরিবাহীর রোধ বিদ্যুৎ প্রবাহমাত্রা অপরিবর্তিত থাকলে পরিবাহীতে বিদ্যুৎ প্রবাহের দরুন উদ্ভূত তাপ বিদ্যুৎ প্রবাহের কালের সমানুপাতিক
# বৈদ্যুতিক যন্ত্র উৎসের সামর্থ্যকে বিদ্যুৎ শক্তি
# উৎস যন্ত্রের হারকে ক্ষমতা একক সময়ের সম্পাদিত পরিমাপ
# ওয়াট ক্ষমতাসম্পন্ন যন্ত্র ঘণ্টা শক্তি ব্যয় ওয়াটঘণ্টা
# কিলোওয়াট ক্ষমতাসম্পন্ন যন্ত্র ঘণ্টা শক্তি ব্যয় কিলোওয়াটঘণ্টা
# বহিঃবর্তনীর সংযোগ বিচ্ছিন্ন অবস্থায় কোষের প্রান্তের সর্বোচ্চ বিভব পার্থক্যকে তড়িচ্চালক বল
# চালিকা শক্তি বর্তনীতে বিদ্যুৎ প্রবাহ বজায় রাখে তড়িচ্চালক বল
# তড়িৎ বর্তনীর এক বিন্দু কুলম্ব চার্জকে তড়িৎ কোষসহ সম্পূর্ণ বর্তনী ঘুরিয়ে পুনরায় বিন্দুতে আনতে জুল সম্পন্ন কোষের তড়িচ্চালক বল ভোল্ট
# বহিঃবর্তনীতে প্রবাহ অর্থাৎ বর্তনী খোলা অবস্থায় কোষের প্রান্তের বিভব পার্থক্য কোষের তড়িচ্চালক শক্তির সমান
# বর্তনীতে বিদ্যুৎ প্রবাহ মাত্রা বিভব বৈষম্য পরিবর্তনের কতকগুলো বৈদ্যুতিক কোষকে একত্রে যুক্ত
# কতকগুলো বিদ্যুৎ কোষকে এমনভাবে যুক্ত প্রথমটির ঋণ পাতের দ্বিতীয়টির ধন পাত দ্বিতীয়টির ঋণ পাতের তৃতীয়টির ধন পাত এভাবে যুক্ত বিদ্যুৎ কোষগুলোর সমবায়কে শ্রেণি সমবায়
# কতকগুলো বিদ্যুৎ কোষের ধন পাতগুলো এক বিন্দুতে ঋণ পাতগুলো অপর এক বিন্দুতে যুক্ত বিদ্যুৎ কোষগুলোর সমবায়কে সমান্তরাল সমবায়
# ওমের সূত্রের সাহায্যে সরল বর্তনীর বিদ্যুৎ প্রবাহমাত্রা রোধ নির্ণয়
# বিদ্যুৎ বর্তনীর সংযোগ বিন্দুতে মিলিত প্রবাহমাত্রাগুলোর বীজগাণিতিক যোগফল শূন্য
# বদ্ধ বর্তনীর অন্তর্গত বিদ্যুচ্চালক শক্তি বর্তনীর শাখাগুলোর রোধ মধ্য প্রবাহিত সংশ্লিষ্ট বিদ্যুৎ প্রবাহমাত্রার গুণফলসমূহের বীজগাণিতিক যোগফলের সমান
# পরিবাহী বর্তনীর বদ্ধ বর্তনীর অংশের রোধ মধ্য প্রবাহিত বিদ্যুৎ প্রবাহমাত্রার গুণফলের বীজগাণিতিক যোগফল বদ্ধ বর্তনীর বিদ্যুচ্চালক শক্তির সমান
# ...
# বস্তুর কিনারা ঘেষে আলোকের খানিকটা বেঁকে যাওয়াকে অপবর্তন
# উৎস পর্দা মধ্যবর্তী বাধা অল্প দূরত্বের অবস্থান বাধার দরুন পর্দায় আলোকের অপবর্তন পরিলক্ষিত ফ্রেনেল শ্রেণি অপবর্তন
# উৎস পর্দা মধ্যবর্তী বাধা অসীম দূরত্বে অবস্থান বাধার দরুন পর্দায় অপবর্তন পরিলক্ষিত ফ্রনহফার শ্রেণি অপবর্তন
# তরঙ্গমুখের অংশ নির্গত গৌণ তরঙ্গসমূহের ব্যতিচারের অপবর্তন সৃষ্টি
# অপবর্তন ঝালরে পট্টিগুলোর বেধ সমান
# অপবর্তনের উজ্জ্বল পট্টি অন্ধকার পট্টিগুলোর অন্তর্বর্তী দূরত্বগুলো ক্রমাগত কমতে
# অপবর্তনে অন্ধকার পট্টিগুলো সম্পূর্ণ অন্ধকার
# অপবর্তনে উজ্জ্বল পট্টিগুলোর প্রত্যেকটিতে আলোক প্রাবল্য কখনই সমান
# সমতল নিঃসরণ গ্রেটিং স্বচ্ছ সমতল কাচ অনুরূপ পদার্থের পাত সূঁচালো হীরক বিন্দু সমব্যবধানে সমান্তরালভাবে খুবই কাছাকাছি বহুসংখ্যক দাগ কাটা
# চিড়ের পরবর্তী চিড়ের দূরত্বকে গ্রেটিং ধ্রুবক
# চিড়ের শেষ প্রান্ত পরবর্তী চিড়ের শেষ প্রান্তের দূরত্বকে গ্রেটিং ধ্রুবক
# আলোক তরঙ্গ লম্বিক অনুদৈর্ঘ্য তরঙ্গ নহে আলোক তরঙ্গ আড় তরঙ্গ তির্যক তরঙ্গ
# প্রক্রিয়ায় তলে কম্পমান আলোক তরঙ্গকে নির্দিষ্ট তল বরাবর কম্পনক্ষম আলোকের সমবর্তন পোলারায়ন
# আলোক কম্পন গতিপথের লম্ব অভিমুখে চারদিকে সমান বিস্তারে কম্পিত অসমবর্তিত আলোক
# তলে সমান্তরাল তলে কম্পমান আড় তরঙ্গবিশিষ্ট আলোককে সমবর্তিত আলোক
# আলোক তরঙ্গের কণাগুলোর কম্পন কেবলমাত্র তলে সীমাবদ্ধ থাকলে রেখা সমবর্তিত আলোক
# আলোক তরঙ্গের কণাসমূহ সমতলে কম্পিত কম্পন তল
# প্রতিফলক আপতন কোণ ধীরে ধীরে পরিবর্তন কোণ সমবর্তন সর্বাধিক কোণটিকে সমবর্তন কোণ
# কম্পন তলের তলটি লম্বভাবে অবস্থান সমবর্তন তল
# কতকগুলো কেলাস মধ্য আলোক রশ্মি গমন প্রতিসৃত রশ্মিতে বিভক্ত
# দূর কাছের বিন্দুর সাপেক্ষে দ্বি ত্রিমাত্রিক স্থানে বিন্দুকে সুনির্দিষ্ট প্রসঙ্গ কাঠামো
# প্রসঙ্গ কাঠামোতে জড়তার সূত্র নিউটনের গতির সূত্র প্রযোজ্য জড় কাঠামো জড়তার কাঠামো
# কাঠামোতে জড়তার সূত্র নিউটনের গতির সূত্র প্রযোজ্য অজড় কাঠামো
# ঘূর্ণায়মান অসমবেগে চলমান প্রসঙ্গ কাঠামো অজড় কাঠামো
# আলোকের বেগ ধ্রুব রাশি উৎস পর্যবেক্ষণ মাধ্যমের গতির নির্ভর
# বিষয় কিছুর সাপেক্ষে বিবেচিত হবার নামই আপেক্ষিকতা
# আপেক্ষিকতার তত্ত্ব অনুসারে পরম গতি নিরর্থক গতিই আপেক্ষিক
# আপেক্ষিক তত্ত্ব মূলত দুভাগে বিভক্ত যথা আপেক্ষিকতার সার্বিক তত্ত্ব আপেক্ষিকতার তত্ত্ব
# আপেক্ষিকতার সার্বিক তত্ত্ব পরস্পরের তুলনায় ঊর্ধ্ব নিম্নগতিশীল ত্বরিত বস্তুসমূহ সিস্টেম আলোচনা
# জড় কাঠামোতে গ্যালিলিয় কাঠামোতে পদার্থবিজ্ঞানের সূত্রসমূহ অভিন্ন
# পরস্পরের সমবেগে ধাবমান সকল প্রসঙ্গ কাঠামোতে পদার্থবিজ্ঞানের সূত্রগুলো একইরূপ সমীকরণ প্রকাশ
# শূন্যস্থানে সকল পর্যবেক্ষকের নিকট আলোকের বেগ সর্বদা সমান
# রূপান্তরণ সূত্র প্রয়োগে বিদ্যুৎ চুম্বকীয় সমীকরণ এক জড় কাঠামো কাঠামোতে নিলে অভিন্নরূপে প্রকাশিত লরেন্জ রূপান্তরণ সূত্র নামে পরিচিত
# পদার্থবিদ্যার সূত্রগুলো সকল অভ্যন্তরীণ কাঠামোয় অভিন্ন কাঠামোগুলোকে পরস্পরের সাপেক্ষে সমবেগে গতিশীল থাকতে
# শূন্যস্থানে আলোর বেগ সর্বদা ধ্রুব অভ্যন্তরীণ কাঠামো অন্যটিতে রূপান্তরিত মান অপরিবর্তিত
# জড় স্থির কাঠামোতে সংঘটিত ঘটনা উক্ত কাঠামো সাপেক্ষে গতিশীল কাঠামো ঘটনার সময় ব্যবধান বৃদ্ধি পেয়েছে
# দৈর্ঘ্যের আপেক্ষিক বেগের সময়েরও পরিবর্তন ঘটে
# চিরায়ত বলবিদ্যা অনুসারে বস্তুর সাপেক্ষে পর্যবেক্ষকের বেগ পর্যবেক্ষকের সাপেক্ষে বস্তুর বেগ যাই সকল পর্যবেক্ষকের নিকট বস্তুর দৈর্ঘ্য
# আপেক্ষিক তত্ত্ব অনুসারে বস্তু পর্যবেক্ষকের আপেক্ষিক বেগ থাকলে বস্তুর দৈর্ঘ্য পর্যবেক্ষকের কম
# বস্তুর গতিশীল অবস্থার দৈর্ঘ্য বস্তুর স্থির অবস্থার দৈর্ঘ্যের ছোট হওয়াকে দৈর্ঘ্য সংকোচন
# আপেক্ষিক তত্ত্বানুসারে বস্তুর ভর বেগের বৃদ্ধি পায়
# তাপমাত্রা বৃদ্ধি পেলে কৃষ্ণ বস্তু বিকীর্ণ শক্তি বৃদ্ধি পায়
# তরঙ্গদৈর্ঘ্যে সর্বোচ্চ পরিমাণ শক্তি বিকীর্ণ তাপমাত্রা বৃদ্ধির হ্রাস পায়
# প্রতিটি ফোটন কণাই চার্জহীন অর্থাৎ নিস্তড়িৎ
# প্রতিটি ফোটন কণা আলোর বেগে বেগের হ্রাসবৃদ্ধি
# এক্সরে উৎপাদনের তিনটি পদ্ধতি যথা গ্যাস নল পদ্ধতি কুলীজ নল পদ্ধতি বিটাট্রন পদ্ধতি
# রশ্মির তীব্রতা ব্যস্তানুপাতিক সূত্র মেনে
# ধাতব পদার্থ নির্গত ইলেকট্রনকে ফটো ইলেকট্রন আলোক ইলেকট্রন
# আলোকের প্রভাবে ধাতব পদার্থ ইলেকট্রনের নির্গমনের প্রক্রিয়াকে আলোক তড়িৎ নির্গমন ক্রিয়াকে ফটোইলেকট্রিক ক্রিয়া আলোক তড়িৎ ক্রিয়া
# ধাতব পদার্থের উপযুক্ত কম্পাঙ্ক তরঙ্গদৈর্ঘ্যের আলোক আপতিত পদার্থ ইলেকট্রন নির্গত
# আলোকের প্রভাবে নির্গত ইলেকট্রনকে আলোক ইলেকট্রন ইলেকট্রনের নিঃসরণকে আলোক তড়িৎ ইলেকট্রনের নিঃসরণের বিদ্যুৎ প্রবাহ সৃষ্টি আলোক তড়িৎ প্রবাহ
# প্রত্যেক ধাতুর ন্যূনতম কম্পাঙ্ক কম কম্পাঙ্কবিশিষ্ট আলো ধাতু ইলেকট্রন নির্গত
# ক্যাথোড প্লেটের সাপেক্ষে অ্যানোড প্লেটে ন্যূনতম ঋণ বিভব দিলে আলোক তড়িৎ প্রবাহমাত্রা সদ্য বন্ধ বিভবকে নিবৃত্তি বিভব
# ধাতব পৃষ্ঠ শূন্য বেগসম্পন্ন ইলেকট্রন নির্গত যতটুকু শক্তির প্রয়োজন ধাতুর কার্য অপেক্ষক
# আলোক রশ্মি আপতিত সঙ্গেই আলোক তড়িৎ ক্রিয়া আরম্ভ আলোক রশ্মির আপতন বন্ধ সঙ্গেই ক্রিয়া বন্ধ অর্থাৎ তাৎক্ষণিক ঘটনা
# প্রত্যেক ধাতু আলোক ইলেকট্রন নির্গমনের আপতিত রশ্মির ন্যূনতম কম্পাঙ্ক নাম প্রারম্ভ কম্পাঙ্ক
# আলোক ইলেকট্রনের সর্বোচ্চ গতিবেগ আপতিত রশ্মির কম্পাঙ্কের সমানুপাতিক
# আলোক ইলেকট্রন নির্গমনের হার আপতিত আলোকের প্রাবল্যের সমানুপাতিক
# আলোক ইলেকট্রনের গতিবেগ গতিশক্তি আপতিত আলোকের প্রাবল্যের ওপর নির্ভর আপতিত আলোকের কম্পাঙ্ক নিঃসারক নির্গমকএর প্রকৃতির নির্ভর
# ধাতব পৃষ্ঠ শূন্য বেগসম্পন্ন ইলেকট্রন নির্গত যতটুকু শক্তির প্রয়োজন ধাতুর কার্য অপেক্ষক
# কোয়ান্টাম তত্ত্ব প্রমাণিত বিকিরণ শক্তির দ্বৈত ধর্ম রয়েছেএকটি কণা ধর্ম অপরটি তরঙ্গ ধর্ম
# তরঙ্গকণা দ্বৈততা ধারণা উল্লেখ সকল শক্তি তরঙ্গসদৃশ কণা সদৃশ উভয় ধর্ম প্রদর্শন
# দৃশ্যমান আলোকের এক্সরে বিদ্যুৎচুম্বকীয় তরঙ্গ
# গ্যাস নলের ভেতরে গ্যাসের চাপ অপেক্ষাকৃত কম বিভব পার্থক্যেও এক্স রশ্মি উৎপন্ন
# নলের ভেতর গ্যাসের চাপ কম অধিক বিভব পার্থক্য প্রয়োগে এক্স রশ্মি উৎপন্ন
# প্রত্যেক চলমান পদার্থ কণার তরঙ্গ যুক্ত তরঙ্গকে ডি ব্রগলী তরঙ্গ
# হালকা পদার্থের ইলেকট্রন এক্সরশ্মি বিক্ষিপ্ত বিক্ষিপ্ত রশ্মির ভেতর আপতিত তরঙ্গদৈর্ঘ্য পরিবর্তিত তরঙ্গদৈর্ঘ্যের এক্সরশ্মি
# কণার নির্দিষ্ট সময়ে অবস্থানের অনিশ্চয়তা ভরবেগের অনিশ্চয়তা গুণফল প্লাংকের ধ্রুবকের সমান বড়
# তেজস্ক্রিয়তা স্বতঃস্ফূর্ত স্বীয় বিচ্ছিন্নকারী প্রক্রিয়া
# পদার্থ স্বতঃস্ফূর্তভাবে কণা রশ্মি নির্গত প্রক্রিয়াকে তেজস্ক্রিয়তা পদার্থ কণা রশ্মি নির্গত এদেরকে যথাক্রমে তেজস্ক্রিয় পদার্থ তেজস্ক্রিয় রশ্মি
# মৌলের পারমাণবিক সংখ্যা সেসব পদার্থই তেজস্ক্রিয় ধর্ম দেখায়
# তাপমাত্রা চাপের পরিবর্তন পারিপার্শ্বিক বিকিরণ বিদ্যুৎ চৌম্বক ক্ষেত্র বাহ্যিক বল তেজস্ক্রিয়াকে প্রভাবিত
# জিঙ্ক সালফাইড বেরিয়াম প্লাটিনোসায়ানাইডে আলফা রশ্মি প্রতিপ্রভা সৃষ্টি
# তেজস্ক্রিয় বস্তু আলফা রশ্মি বেগে নির্গত
# আলফা রশ্মি শরীরের অংশে পড়লে ক্ষত সৃষ্টি
# বিটা রশ্মি খুবই হাল্কা ইলেকট্রন প্রবাহ
# গামা রশ্মি অতি ক্ষুদ্র তরঙ্গদৈর্ঘ্যের বিদ্যুৎ চুম্বকীয় তরঙ্গ
# গামা রশ্মির ভর
# গামা রশ্মির চার্জ
# গামা রশ্মির তরঙ্গদৈর্ঘ্য দৃশ্যমান আলোকের তরঙ্গদৈর্ঘ্যের তুলনায় কম
# গামা রশ্মি বৈদ্যুতিক ক্ষেত্র বিক্ষিপ্ত
# গামা রশ্মি চৌম্বক ক্ষেত্র বিক্ষিপ্ত
# গামা রশ্মি ফটোগ্রাফিক প্লেটে প্রতিক্রিয়া সৃষ্টি
# গামা রশ্মির আয়নায়ন ক্ষমতা ক্ষমতা আলফা বিটা রশ্মির তুলনায় কম
# গামা রশ্মির ভেদন ক্ষমতা আলফা বিটা রশ্মির তুলনায় ভেদন ক্ষমতা
# তেজস্ক্রিয় পদার্থের পরমাণুর একক সময়ে ভাঙনের সম্ভাব্যতাকে পদার্থের অবক্ষয় ধ্রুবক
# মুহূর্তে তেজস্ক্রিয় পরমাণুর ভাঙন অবক্ষয়ের হার সময়ে উপস্থিত অক্ষত পরমাণুর সমানুপাতিক
# তেজস্ক্রিয় পদার্থের পরমাণুর একক সময়ে ভাঙ্গনের সম্ভাব্যতাকে পদার্থের ক্ষয় অবক্ষয় ভাঙ্গন ধ্রুবক
# তেজস্ক্রিয় পদার্থের প্রারম্ভিক উপস্থিত অক্ষত পরমাণুগুলোর অর্ধেক পরিমাণ ক্ষয় সময় লাগে অর্ধায়ু অর্ধপর্যায়
# প্রত্যেকটি তেজস্ক্রিয় পরমাণুর আয়ুর যোগফলকে পরমাণুর প্রারম্ভিক সংখ্যা ভাগ আয়ু তেজস্ক্রিয় পদার্থের গড় আয়ু
# পরমাণুর পারমাণবিক সংখ্যা ভর সংখ্যা পারমাণবিক ওজন ভিন্ন তাদেরকে আইসোটোপ একস্থানিক সমস্থানিক
# পরমাণুর প্রোটন ইলেকট্রন সংখ্যা সমান নিউট্রন সংখ্যা ভিন্ন তাদেরকে আইসোটোপ
# পরমাণুর ভর সংখ্যা পারমাণবিক ওজন পারমাণবিক সংখ্যা ভিন্ন তাদেরকে আইসোবার
# পরমাণুর পারমাণবিক সংখ্যা ভর সংখ্যা অভ্যন্তরীণ গঠন তাদেরকে আইসোমার
# পরমাণুতে সমান সংখ্যক নিউট্রন তাদেরকে আইসোটোন
# কতকগুলো আইসোটোপে একস্থানিকে অল্প সময়ের কৃত্রিম তেজস্ক্রিয়তা
# স্থায়ী নিউক্লিয়াসের ভর গঠনকারী উপাদানসমূহের যুক্তাবস্থার ভরের যোগফল অপেক্ষা কিছুটা কম
# প্রয়োজনীয় সংখ্যক নিউক্লিয়ন একত্রিত স্থায়ী নিউক্লিয়াস গঠন পরিমাণ শক্তি নির্গত শোষিত নিউক্লীয় বন্ধন শক্তি
# নিউক্লিয়াসকে ভেঙ্গে নিউক্লিয়নগুলোকে পরস্পরের প্রভাব মুক্ত নিউক্লিয়াসকে বাহির পরিমাণ শক্তি সরবরাহ বন্ধন শক্তি
# নিউক্লিয়াসের বন্ধন শক্তি ভর সংখ্যার অনুপাতকে নিউক্লিয়নে বন্ধন শক্তি
# বন্ধন শক্তিকে ভর সংখ্যা ভাগ নিউক্লিয়নে বন্ধন শক্তি নির্ণয়
# চেইন শৃঙ্খল বিক্রিয়া প্রক্রিয়া চালাবার অতিরিক্ত উৎস শক্তির প্রয়োজন
# প্রক্রিয়ায় একাধিক হালকা নিউক্লিয়াস একত্রিত অপেক্ষাকৃত ভারী নিউক্লিয়াস গঠন অত্যধিক শক্তি নির্গত নিউক্লিয় ফিউশন নিউক্লিয় সংযোজন
# ফিউশন অত্যধিক উচ্চ তাপমাত্রায় সংঘটিত বিক্রিয়াকে তাপনিউক্লিয় বিক্রিয়া
# প্রক্রিয়ায় ভারী পরমাণুর নিউক্লিয়াস বিশ্লিষ্ট সমান ভরের নিউক্লিয়াস তৈরি বিপুল পরিমাণ শক্তি নির্গত নিউক্লিয় ফিশন নিউক্লিয়ার বিভাজন
# পদার্থের ভেতর তড়িৎ সহজে চলাচল সেগুলোকে পরিবাহী
# এক ধরনের পদার্থ ভেতর তড়িৎ চলাচল এদেরকে অপরিবাহী
# পরিবাহী অন্তরকের মাঝামাঝি এক ধরনের পদার্থ তড়িৎ পরিবাহিতা পরিবাহী পদার্থের কম অন্তরকের এগুলোকে অর্ধপরিবাহী
# অর্ধপরিবাহী কেলাসকে উত্তপ্ত দ্রুত রোধ হারায় অর্থাৎ পরিবাহিতা বৃদ্ধি পায়
# বিশুদ্ধ অর্ধপরিবাহীর নির্দিষ্ট অপদ্রব্যের সামান্য অংশমাত্র দশ ভাগের এক ভাগমাত্র মেশানো রোধ গুণ কমে
# যোজন ইলেকট্রন যখনই পরিবহন ব্যান্ডে প্রবেশ তখনই যোজন ব্যান্ডে অবস্থানে শূন্যতার সৃষ্টি হোল
# অর্ধপরিবাহী পদার্থেকে ভাগে ভাগ যথাক ইনট্রিন্সিক সেমিকন্ডাক্টর স্বকীয় বিশুদ্ধ অর্ধপরিবাহী খ এক্সট্রিন্সিক সেমিকন্ডাক্টর বহিঃজাত অবিশুদ্ধ অর্ধপরিবাহী
# সকল অর্ধপরিবাহীতে অপদ্রব্য মিশ্রিত ইনট্রিন্সিক সেমিকন্ডাক্টর
# প্রক্রিয়া পদ্ধতিতে বিশুদ্ধ অর্ধপরিবাহীর সামান্য পরিমাণ অপদ্রব্য মিশ্রিত অর্ধপরিবাহীর তড়িৎ পরিবাহিতা বহুল পরিমাণে বৃদ্ধি ডোপিং
# মিশ্রিত অপদ্রব্যকে ডোপ্যান্ট
# অবিশুদ্ধ কেলাস অর্ধপরিবাহী পদার্থ দুরকমের যথা টাইপ টাইপ
# টাইপ অর্ধপরিবাহীতে ইলেকট্রন হোল উভয়েরই উপস্থিতি ইলেকট্রনের সংখ্যা হোলের তুলনায় বহুগুণ
# টাইপ অর্ধপরিবাহীতে ধনাত্মক তড়িতাধানই মুখ্য ভূমিকা পালন
# বিশুদ্ধ অর্ধপরিবাহীর যোজন ইলেকট্রনের অপদ্রব্যের যোজন ইলেকট্রন সংখ্যা টাইপ কেলাস কম টাইপ কেলাস তৈরি
# টাইপ টাইপ অর্ধপরিবাহীকে ব্যবস্থাধীনে সংযুক্ত সংযোগ পৃষ্ঠকে জাংশন
# সংযোগের পাশে সরু স্তর ধনাত্মক ঋণাত্মক আধানকে পৃথক রাখে গতিশীল আধান নিঃশেষ গতিশীল আধান বাহকের অস্তিত্ব স্তর অঞ্চলকে নিঃশেষিত স্তর অঞ্চল
# জাংশনের ভেতর তড়িৎ প্রবাহ একদিকে সহজেই বিপরীত উচ্চতর বহিঃভোল্টেজ প্রয়োগ
# বাইরে জাংশন বরাবর দুভাবে বিভব পার্থক্য প্রয়োগ যথা সম্মুখবর্তী ঝোঁক ফরোয়ার্ড বায়াস বিপরীত ঝোঁক রিভার্স বায়াস প্রয়োগ
# জাংশন ডায়োডের অভ্যন্তরে উভয় প্রকার সংখ্যাগুরু বাহকের তড়িৎ প্রবাহ উৎপন্ন বহিঃবর্তনীতে কেবলমাত্র ইলেকট্রন প্রবাহ উৎপন্ন
# সম্মুখবর্তী বায়াস প্রয়োগে সাধারণত মিলিঅ্যাম্পিয়ারের তড়িৎ প্রবাহ
# জাংশন ডায়োডের অভ্যন্তরে উভয় ধরনের সংখ্যাগুরু বাহকের তড়িৎ প্রবাহ উৎপন্ন বহিঃবর্তনীতে কেবলমাত্র ইলেকট্রনের প্রবাহ উৎপন্ন
# বিপরীত বায়াসে সাধারণত মাইক্রোঅ্যাম্পিয়ারের তড়িৎ প্রবাহ
# বিপরীত বায়াস ভোল্টেজ বৃদ্ধি ক্রান্তি মানে পৌঁছালে বিপরীত কারেন্ট হঠাৎ অনেকগুণ বেড়ে
# পদ্ধতিতে পরিবর্তী প্রবাহকে একমুখী প্রবাহে পরিবর্তন একমুখীকরণ রেকটিফিকেশন বর্তনী একমুখীকারক রেকটিফায়ার
# একমুখীকারক ধরনের যথাক অর্ধতরঙ্গ একমুখীকারক খ পূর্ণতরঙ্গ একমুখীকারক
# পরিবর্তী তরঙ্গ সময়ের দিক পরিবর্তন ডায়োডের ভেতর একমুখী তরঙ্গ উৎপন্ন
# পরিবর্তী প্রবাহকে পূর্ণ তরঙ্গ একমুখীকরণ দুভাবে যথা ক ট্রান্সফরমার জাংশন ডায়োডের সাহায্যে খ ট্রান্সফরমার চারটি জাংশন ডায়োডের সাহায্যে
# ডায়োড পূর্ণ তরঙ্গ একমুখীকরণ
# ধরনের একমুখীকারক যথা অর্থ তরঙ্গ একমুখীকারক পূর্ণ তরঙ্গ একমুখীকারক
# ট্রানজিস্টর তিন প্রান্তবিশিষ্ট অর্ধপরিবাহী ডিভাইস অন্তর্মুখী প্রবাহকে নিয়ন্ত্রণ বহির্মুখী প্রবাহ বিভব পার্থক্য ক্ষমতা নিয়ন্ত্রণ
# তিন প্রান্তবিশিষ্ট ক্ষুদ্র অর্ধপরিবাহক পদার্থে বহির্মুখী প্রবাহ ভোল্টেজ ক্ষমতা অন্তর্মুখী প্রবাহ নিয়ন্ত্রিত ট্রানজিস্টর
# যন্ত্র ডিভাইস মান বৃদ্ধি এ্যামপ্লিফায়ার
# ট্রানজিস্টর সিগন্যালকে বৃদ্ধি বেস কারেন্টের সাহায্যে কালেকটর কারেন্টকে নিয়ন্ত্রণ আউটপুট রোধকে ইনপুটের রোধের তুলনায় মানের
# ট্রানজিস্টরকে তিনটি বর্তনীর এ্যামপ্লিফায়ার হিসেবে যথা কমন বেস পীঠ কমন এমিটার নিঃসারক কমন কালেকটর সংগ্রাহক এ্যামপ্লিফায়ার
# এমিটার বেস জাংশনে প্রযুক্ত সিগন্যালের ধনাত্মক অর্ধাংশের সময় জাংশনটির সম্মুখ ঝোঁক বৃদ্ধি পায়
# আদর্শ সুইচকে অন সর্ট সার্কিট অফ ওপেন সার্কিট তৈরি
# কেলাস গঠনে কক্ষপথের ইলেকট্রনগুলোর সুনির্দিষ্ট শক্তিস্তর ব্যান্ডের আকার ধারণ
# বিশুদ্ধ অর্ধপরিবাহীর সামান্য পরিমাণে ত্রিযোজী মৌল মিশ্রিত অর্ধপরিবাহী তৈরি টাইপ অর্ধপরিবাহী
# টাইপ টাইপ অর্ধপরিবাহীকে ব্যবস্থাধীনে সংযুক্ত সংযোগ পৃষ্ঠকে জাংশন জাংশন ডায়োড
# জাংশনে এমনভাবে বাহ্য ভোল্টেজ প্রয়োগ জাংশনের বিভব প্রাচীর হ্রাস তড়িৎ প্রবাহ সম্মুখবর্তী ঝোঁক প্রয়োগ
# ডায়োডে জাংশনে বাহ্য ভোল্টেজ প্রয়োগ বিভব প্রাচীরের উচ্চতা বৃদ্ধি পায় বিপরীত ঝোঁক প্রয়োগ
# জাংশনকে পাশাপাশি কায়দায় সংযুক্ত ট্রানজিস্টর
# টাইপ টাইপ অর্ধপরিবাহীর মাঝখানে অত্যন্ত পাতলা খুবই হাল্কা ডোপিং সমৃদ্ধ যথাক্রমে টাইপ টাইপ অর্ধপরিবাহী সংযুক্ত ট্রানজিস্টর তৈরি
# জেনার ডায়োড বিপরীত ঝোঁকে ক্রিয়াশীল
# মহাবিশ্বের সৃষ্টি সংক্রান্ত বিজ্ঞান বিশ্ব সৃষ্টি তত্ত্ব
# অন্যান্য তারার সূর্যও উত্তপ্ত জ্বলন্ত গ্যাসের পিণ্ড
# বিজ্ঞানের বিষয় হিসেবে বিশ্ব সৃষ্টিতত্ত্বের জন্ম সালে আলবার্ট আইনস্টাইনের আপেক্ষিক তত্ত্ব প্রণয়নের
# বছর মহাবিশ্বের আকৃতি ডিম্বাকার
# দূরত্ব পরস্পর সরে যাবার গতিবেগও
# বিগ ক্রাঞ্চ তত্ত্বের সমাপ্তিই বিগ ব্যাংগ সূচনা
# মহাবিশ্ব প্লাজমা অবস্থায় অর্থাৎ অস্বচ্ছ আয়নিত গ্যাসে পূর্ণ
# মহাবিস্ফোরণের এক সেকেন্ডের শতভাগের একভাগ সময়টিতে মহাবিশ্ব পরিপূর্ণ বিকিরণ নিউট্রিনো ইলেকট্রনপজিট্রন যুগলে
# মহাবিস্ফোরণের তিন মিনিটের মাথায় প্রোটন নিউট্রন মিলে হিলিয়াম নিউক্লিয়াস সৃষ্টি
# বিশ্বের প্রসারণ বিশ্বে পর্যবেক্ষিত হাইড্রোজেন হিলিয়ামের শতাংশের অনুপাত
# বড় নক্ষত্র নিউক্লীয় ইন্ধন ফুরিয়ে দ্রুত সংকুচিত মহাকর্ষের টানে প্রচণ্ড চাপে ভয়াবহ হারে তাপ নিউক্লীয় শক্তি সৃষ্টি সহস্র নক্ষত্রের উজ্জ্বলতা ফেটে পড়ে তখনই সুপারনোভার সৃষ্টি
# আকাশগঙ্গা ছায়াপথ ধ্রুবমাতা অ্যান্ড্রোমিডা আরো ছোট গ্যালাক্সি মিলে লোকাল গ্যালাক্সি স্তবক তৈরি
# গ্যালাক্সি স্তবকটি পারস্পরিক মহাকর্ষীয় আকর্ষণে বাঁধা একক ব্যবস্থা
# মহাবিশ্বের ভবিষ্যৎ বর্তমান প্রসারণের হার বিশ্বের বক্রতা বিশ্বে বস্তুর পরিমাণ মহবিশ্বের গড় ঘনত্ব সংকট ঘনত্ব বিষয়ের নির্ভরশীল
# সলে এডুইন হাবল দেখিয়েছেন ছায়াপথসমূহ অপসারিত অপসারণ বেগের মান দূরত্বের সমানুপাতিক
# ক্রমাগত ছুটে চলার সম্ভাবনা জ্যোতির্বিদরা উন্মুক্ত মহাবিশ্ব ছুটে চলা থেমে ভেতর পড়ার সম্ভাবনা আবদ্ধ মহাবিশ্ব
# আবদ্ধ মহাবিশ্ব মডেলে মহাবিশ্বের সম্প্রসারণ ভবিষ্যতে একদিন থেমে সঙ্কুচিত মহাবিশ্ব বিন্দুতে ধসে পড়বে
# উন্মুক্ত মহাবিশ্ব মডেলে মহাবিশ্ব অনন্তকাল প্রসারিত
# সমতল মহাবিশ্ব মডেলে মহাবিশ্ব ধসে পড়বে অনন্তকাল প্রসারিতও
# সমমানের চার্জ শূন্য মিটার দূরে অবস্থান পরস্পরের বল প্রয়োগ চার্জ দুটির প্রত্যেককে একক চার্জ একক চার্জকে এক কুলম্ব
# প্রোটনকে অবাস্তব ক্ষুদ্র কৃষ্ণ বিবর গ্রাস পজিট্রনে পরিণত
# সংকট ঘনত্বের মান বর্তমান গড় ঘনত্বের সেক্ষেত্রে প্রসারণ আজীবন চলতে
# সংকট ঘনত্বের মান বর্তমান গড় ঘনত্বের সমান সেক্ষেত্রে বিশ্বের প্রসারণ ধীরে ধীরে কমে আসতে কখনোই একেবারে থেমে
# মহাবিশ্বের গড় ঘনত্ব সংকট ঘনত্বের মহাকর্ষীয় আকর্ষণ মহাবিশ্বের প্রসারণকে এক সময়ে থামিয়ে বিশ্ব জুড়ে মহাসংকোচন
# মহাকাশে অসংখ্য জ্বলন্ত গ্যাসপিণ্ড অবস্থান যেমনসূর্য নক্ষত্র গ্রহ উপগ্রহ উল্কা
# আজকাল চন্দ্র সূর্য গ্রহ নক্ষত্র ধূমকেতু উল্কা অনুজ্জ্বল নীহারিকা পালসার কৃষ্ণ বামন কৃষ্ণ গহ্বর কিছুকেই জ্যোতিষ্ক
# নক্ষত্রগুলো জ্বলন্ত গ্যাস পিণ্ড আলো উত্তাপ
# মহাকর্ষ বলের প্রভাবে গ্যাসীয় পদার্থের সংকোচন ফলশ্রুতিতে সৃষ্টি গ্যালাক্সি
# আধান চৌম্বক মোমেন্ট কণিকা প্রতিকণিকা
# মেসন ফোটন সকল কণিকার প্রতিকণা
# মৌলিক কণা তিন ধরনের ক ক্ষেত্ৰকণা খ লেপটন কণা গ হ্যাড্রন কণা
# ফোটন গেজ বোসন গ্রাভিটন সমন্বয়ে ক্ষেত্রকণা গঠিত
# কণা বিদ্যুৎ চুম্বকীয় দুর্বল নিউক্লীয় পরিক্রিয়ায় অংশগ্রহণ শক্তিশালী নিউক্লীয় পরিক্রিয়ায় অংশগ্রহণ
# লেপটন কণা তিন ধরনের ইলেকট্রন গোষ্ঠীয় লেপটন মিওন গোষ্ঠীয় লেপটন টাউ গোষ্ঠীয় লেপটন
# ইলেকট্রন উল্লেখযোগ্য লেপটন কণা
# সকল মৌলিক কণা শক্তিশালী নিউক্লীয় বিদ্যুৎ চুম্বকীয় দুর্বল নিউক্লীয় তিন প্রক্রিয়াতে অংশগ্রহণ তাদেরকে হ্যাড্রন কণা
# হ্যাড্রন কণা ধরনের যথা মেসন বেরিয়ন
# মেসনের স্পিন শূন্য বেরিয়নের স্পিন শূন্য
# কণিকা ভর স্পিন কণিকার সমান চার্জ বেরিয়ন সংখ্যা লেপটন সংখ্যা কণিকার সমান বিপরীতধর্মী এগুলোকে প্রতিকণা
# হিগস বোসন ক্ষেত্ৰনামক তাত্ত্বিক বল ক্ষেত্র বিশ্বে ছড়িয়ে
# কোয়ার্ক অতি পারমাণবিক কণা প্রোটন নিউট্রনসমূহ গঠিত
# নক্ষত্র জ্বলন্ত অগ্নিপিন্ড গ্যাস ধূলিকণার সমন্বয়ে গঠিত
# নক্ষত্র সৃষ্টির আদিতে মহাকাশের বিস্তৃত বিশাল অঞ্চল জুড়ে শীতল হাইড্রোজেন হিলিয়ামসহ অন্যান্য গ্যাসের পরমাণু ছড়ানো ছিটানো অবস্থায় গ্যাসের ধূলিমেঘ
# ধূলিমেঘে হাইড্রোজেন হিলিয়াম কার্বন নাইট্রোজেন অক্সিজেনসহ অন্যান্য গ্যাস
# সূর্যের ভরের তুলনায় ভারী নক্ষত্রগুলো জ্বালানি শেষ সঙ্কোচন অত্যন্ত তীব্র মূল অংশের ঘনত্ব বেড়ে প্রচণ্ড বিস্ফোরণের মধ্য মৃত্যুবরণ প্রচণ্ড বিস্ফোরণকে সুপারনোভা বিস্ফোরণ
# সবচেয়ে ছোট সবচেয়ে বড় তারার দশ ভাগ ছোট
# তারকার ভর সূর্যের ভর অপেক্ষা গুণ কম সেগুলো শ্বেত বামন
# শ্বেত বামন আস্তে আস্তে তাপীয় শক্তি বিকিরণের স্তিমিত কালো বামন জীবন চক্র শেষ
# তারকার ভর সেগুলো নিউট্রন তারকায় পরিণত
# তারকার ভর সেগুলো কালো বিবরএ পরিণত
# নক্ষত্রের মৃত্যুপূর্ব ভর সূর্যের ভরের তিনগুণের নক্ষত্রটির ভেতর মহাকর্ষ বলের কারণে সংকোচন ক্রিয়া অব্যাহত সংকোচিত অসীম ঘনত্বের বিন্দু বস্তুতে পরিণত
# কৃষ্ণ বিবর অঞ্চলের সীমাকে ঘটনা দিগন্ত
# কালো বিবরের ঘটনা দিগন্তের ব্যাসার্ধকে শোয়ার্জফিল্ড ব্যাসার্ধ
# রেডিও টেলিস্কোপ এক ধরনের দিক নির্দেশী বেতার এ্যান্টেনা বেতার জ্যোতির্বিদ্যায় ব্যবহৃত
# তেজস্ক্রিয় পদার্থ নির্গত রশ্মির চৌম্বক ক্ষেত্র প্রয়োগ রশ্মি বামে রশ্মি ডানে বিক্ষিপ্ত রশ্মি বিক্ষিপ্ত সোজা

# %%
data["label1"]=data.label1.replace({'Physics':0, 'Chemistry':1, 'Biology':2, 'ICT':3, 'Mathematics':4, 'Others':5})
data["label2"]=data.label2.replace({'Physics':0, 'Chemistry':1, 'Biology':2, 'ICT':3, 'Mathematics':4, 'Others':5})
data["label3"]=data.label3.replace({'Physics':0, 'Chemistry':1, 'Biology':2, 'ICT':3, 'Mathematics':4, 'Others':5})
data["final_label"]=data.final_label.replace({'Physics':0, 'Chemistry':1, 'Biology':2, 'ICT':3, 'Mathematics':4, 'Others':5})
print("First rows of dataset")
data.head()
# Out:
# First rows of dataset
#    ID                                               text       source  \
# 0   1  ভৌত জগৎ মূলত চারটি উপাদানের সমন্বয়ে তৈরি- (১)...  HSC Physics
# 1   2  বলবিদ্যা বস্তুর উপর বলের ক্রিয়া সংক্রান্ত বিভ...  HSC Physics
# 2   3       পদার্থের ধর্ম বস্তুর বিভিন্ন গুণ আলোচনা করে।  HSC Physics
# 3   4  স্থিতিবিদ্যা স্থিতিশীল বস্তুর উপর বলের ক্রিয়া...  HSC Physics
# 4   5  গতিবিদ্যা গতিশীল বস্তুর উপর বলের ক্রিয়া আলোচন...  HSC Physics
#
#                                            cleantext  label1  label2  label3  \
# 0  ভৌত জগৎ মূলত চারটি উপাদানের সমন্বয়ে তৈরি স্থা...       0       0       0
# 1  বলবিদ্যা বস্তুর বলের ক্রিয়া সংক্রান্ত বিষয় আ...       0       0       0
# 2                    পদার্থের ধর্ম বস্তুর গুণ আলোচনা       0       0       0
# 3  স্থিতিবিদ্যা স্থিতিশীল বস্তুর বলের ক্রিয়া আলোচনা       0       0       0
# 4        গতিবিদ্যা গতিশীল বস্তুর বলের ক্রিয়া আলোচনা       0       0       0
#
#    final_label
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0

# %%
# Drop single or multiple columns by specifying column names
data = data.drop(['text', 'source', 'label1', 'label2', 'label3'], axis=1)
data.head()
# Out:
#    ID                                          cleantext  final_label
# 0   1  ভৌত জগৎ মূলত চারটি উপাদানের সমন্বয়ে তৈরি স্থা...            0
# 1   2  বলবিদ্যা বস্তুর বলের ক্রিয়া সংক্রান্ত বিষয় আ...            0
# 2   3                    পদার্থের ধর্ম বস্তুর গুণ আলোচনা            0
# 3   4  স্থিতিবিদ্যা স্থিতিশীল বস্তুর বলের ক্রিয়া আলোচনা            0
# 4   5        গতিবিদ্যা গতিশীল বস্তুর বলের ক্রিয়া আলোচনা            0

# %%
# Split the data into training, validation, and testing sets
train_data, test_data = train_test_split(data, test_size=0.3, random_state=42)
val_data, test_data = train_test_split(test_data, test_size=0.5, random_state=42)

# Print the shapes of the resulting datasets
print("Training data shape:", train_data.shape)
print("Validation data shape:", val_data.shape)
print("Testing data shape:", test_data.shape)
# Out:
# Training data shape: (4200, 3)
# Validation data shape: (900, 3)
# Testing data shape: (900, 3)

# %%
! pip install tensorboardX pandas simpletransformers transformers torch
# Out:
# Collecting tensorboardX
#   Downloading tensorboardX-2.6.1-py2.py3-none-any.whl (101 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 12.8 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Collecting simpletransformers
#   Downloading simpletransformers-0.63.11-py3-none-any.whl (250 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.7/250.7 kB 33.2 MB/s eta 0:00:00
# Collecting transformers
#   Downloading transformers-4.30.2-py3-none-any.whl (7.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 121.8 MB/s eta 0:00:00
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.0.1+cu118)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from tensorboardX) (1.22.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorboardX) (23.1)
# Collecting protobuf>=4.22.3 (from tensorboardX)
#   Downloading protobuf-4.23.3-cp37-abi3-manylinux2014_x86_64.whl (304 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 304.5/304.5 kB 43.6 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2022.7.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from simpletransformers) (2.27.1)
# Requirement already satisfied: tqdm>=4.47.0 in /usr/local/lib/python3.10/dist-packages (from simpletransformers) (4.65.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from simpletransformers) (2022.10.31)
# Collecting datasets (from simpletransformers)
#   Downloading datasets-2.13.1-py3-none-any.whl (486 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 486.2/486.2 kB 51.8 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from simpletransformers) (1.10.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from simpletransformers) (1.2.2)
# Collecting seqeval (from simpletransformers)
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 6.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (from simpletransformers) (2.12.3)
# Collecting tokenizers (from simpletransformers)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 82.8 MB/s eta 0:00:00
# Collecting wandb>=0.10.32 (from simpletransformers)
#   Downloading wandb-0.15.5-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 78.1 MB/s eta 0:00:00
# Collecting streamlit (from simpletransformers)
#   Downloading streamlit-1.24.0-py2.py3-none-any.whl (8.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 95.2 MB/s eta 0:00:00
# Collecting sentencepiece (from simpletransformers)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 68.5 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.2)
# Collecting huggingface-hub<1.0,>=0.14.1 (from transformers)
#   Downloading huggingface_hub-0.16.2-py3-none-any.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.5/268.5 kB 33.9 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0)
# Collecting safetensors>=0.3.1 (from transformers)
#   Downloading safetensors-0.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 77.2 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch) (4.6.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (16.0.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2023.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: Click!=8.0.0,>=7.1 in /usr/local/lib/python3.10/dist-packages (from wandb>=0.10.32->simpletransformers) (8.1.3)
# Collecting GitPython!=3.1.29,>=1.0.0 (from wandb>=0.10.32->simpletransformers)
#   Downloading GitPython-3.1.31-py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 22.6 MB/s eta 0:00:00
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb>=0.10.32->simpletransformers) (5.9.5)
# Collecting sentry-sdk>=1.0.0 (from wandb>=0.10.32->simpletransformers)
#   Downloading sentry_sdk-1.27.0-py2.py3-none-any.whl (211 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.3/211.3 kB 25.5 MB/s eta 0:00:00
# Collecting docker-pycreds>=0.4.0 (from wandb>=0.10.32->simpletransformers)
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting pathtools (from wandb>=0.10.32->simpletransformers)
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Collecting setproctitle (from wandb>=0.10.32->simpletransformers)
#   Downloading setproctitle-1.3.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from wandb>=0.10.32->simpletransformers) (67.7.2)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.10/dist-packages (from wandb>=0.10.32->simpletransformers) (1.4.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->simpletransformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->simpletransformers) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->simpletransformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->simpletransformers) (3.4)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->simpletransformers) (9.0.0)
# Collecting dill<0.3.7,>=0.3.0 (from datasets->simpletransformers)
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 15.9 MB/s eta 0:00:00
# Collecting xxhash (from datasets->simpletransformers)
#   Downloading xxhash-3.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 25.9 MB/s eta 0:00:00
# Collecting multiprocess (from datasets->simpletransformers)
#   Downloading multiprocess-0.70.14-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 10.8 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->simpletransformers) (3.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->simpletransformers) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->simpletransformers) (3.1.0)
# Requirement already satisfied: altair<6,>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit->simpletransformers) (4.2.2)
# Collecting blinker<2,>=1.0.0 (from streamlit->simpletransformers)
#   Downloading blinker-1.6.2-py3-none-any.whl (13 kB)
# Requirement already satisfied: cachetools<6,>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit->simpletransformers) (5.3.1)
# Collecting importlib-metadata<7,>=1.4 (from streamlit->simpletransformers)
#   Downloading importlib_metadata-6.7.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: pillow<10,>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from streamlit->simpletransformers) (8.4.0)
# Collecting pympler<2,>=0.9 (from streamlit->simpletransformers)
#   Downloading Pympler-1.0.1-py3-none-any.whl (164 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.8/164.8 kB 22.3 MB/s eta 0:00:00
# Requirement already satisfied: rich<14,>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from streamlit->simpletransformers) (13.4.2)
# Requirement already satisfied: tenacity<9,>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from streamlit->simpletransformers) (8.2.2)
# Requirement already satisfied: toml<2 in /usr/local/lib/python3.10/dist-packages (from streamlit->simpletransformers) (0.10.2)
# Collecting tzlocal<5,>=1.1 (from streamlit->simpletransformers)
#   Downloading tzlocal-4.3.1-py3-none-any.whl (20 kB)
# Collecting validators<1,>=0.2 (from streamlit->simpletransformers)
#   Downloading validators-0.20.0.tar.gz (30 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pydeck<1,>=0.1.dev5 (from streamlit->simpletransformers)
#   Downloading pydeck-0.8.1b0-py2.py3-none-any.whl (4.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 69.1 MB/s eta 0:00:00
# Requirement already satisfied: tornado<7,>=6.0.3 in /usr/local/lib/python3.10/dist-packages (from streamlit->simpletransformers) (6.3.1)
# Collecting watchdog (from streamlit->simpletransformers)
#   Downloading watchdog-3.0.0-py3-none-manylinux2014_x86_64.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 12.4 MB/s eta 0:00:00
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard->simpletransformers) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard->simpletransformers) (1.56.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard->simpletransformers) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard->simpletransformers) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard->simpletransformers) (3.4.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->simpletransformers) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard->simpletransformers) (2.3.6)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.10/dist-packages (from tensorboard->simpletransformers) (0.40.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit->simpletransformers) (0.4)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit->simpletransformers) (4.3.3)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit->simpletransformers) (0.12.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->simpletransformers) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->simpletransformers) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->simpletransformers) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->simpletransformers) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->simpletransformers) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->simpletransformers) (1.3.1)
# Collecting gitdb<5,>=4.0.1 (from GitPython!=3.1.29,>=1.0.0->wandb>=0.10.32->simpletransformers)
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 6.6 MB/s eta 0:00:00
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->simpletransformers) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->simpletransformers) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard->simpletransformers) (1.3.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata<7,>=1.4->streamlit->simpletransformers) (3.15.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14,>=10.11.0->streamlit->simpletransformers) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich<14,>=10.11.0->streamlit->simpletransformers) (2.14.0)
# Collecting pytz-deprecation-shim (from tzlocal<5,>=1.1->streamlit->simpletransformers)
#   Downloading pytz_deprecation_shim-0.1.0.post0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: decorator>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from validators<1,>=0.2->streamlit->simpletransformers) (4.4.2)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb>=0.10.32->simpletransformers)
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->simpletransformers) (0.19.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<14,>=10.11.0->streamlit->simpletransformers) (0.1.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->simpletransformers) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard->simpletransformers) (3.2.2)
# Collecting tzdata (from pytz-deprecation-shim->tzlocal<5,>=1.1->streamlit->simpletransformers)
#   Downloading tzdata-2023.3-py2.py3-none-any.whl (341 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 38.5 MB/s eta 0:00:00
# Building wheels for collected packages: seqeval, validators, pathtools
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16165 sha256=bfd4492c17b57392af7da8bbb756d6ea5a184b93b70b4cc0b5ab1b2765cdfdd0
#   Stored in directory: /root/.cache/pip/wheels/1a/67/4a/ad4082dd7dfc30f2abfe4d80a2ed5926a506eb8a972b4767fa
#   Building wheel for validators (setup.py) ... done
#   Created wheel for validators: filename=validators-0.20.0-py3-none-any.whl size=19579 sha256=19657cd776d3892512bc0fb4cc75438fbd767fc07b90e9b57abe96c4edde5792
#   Stored in directory: /root/.cache/pip/wheels/f2/ed/dd/d3a556ad245ef9dc570c6bcd2f22886d17b0b408dd3bbb9ac3
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8791 sha256=844f0603f3eed3e41375eef22b38763e56ab673452f104faa7cf8d0c95743fd5
#   Stored in directory: /root/.cache/pip/wheels/e7/f3/22/152153d6eb222ee7a56ff8617d80ee5207207a8c00a7aab794
# Successfully built seqeval validators pathtools
# Installing collected packages: tokenizers, sentencepiece, safetensors, pathtools, xxhash, watchdog, validators, tzdata, smmap, setproctitle, sentry-sdk, pympler, protobuf, importlib-metadata, docker-pycreds, dill, blinker, tensorboardX, pytz-deprecation-shim, pydeck, multiprocess, huggingface-hub, gitdb, tzlocal, transformers, seqeval, GitPython, wandb, streamlit, datasets, simpletransformers
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: tzlocal
#     Found existing installation: tzlocal 5.0.1
#     Uninstalling tzlocal-5.0.1:
#       Successfully uninstalled tzlocal-5.0.1
# Successfully installed GitPython-3.1.31 blinker-1.6.2 datasets-2.13.1 dill-0.3.6 docker-pycreds-0.4.0 gitdb-4.0.10 huggingface-hub-0.16.2 importlib-metadata-6.7.0 multiprocess-0.70.14 pathtools-0.1.2 protobuf-4.23.3 pydeck-0.8.1b0 pympler-1.0.1 pytz-deprecation-shim-0.1.0.post0 safetensors-0.3.1 sentencepiece-0.1.99 sentry-sdk-1.27.0 seqeval-1.2.2 setproctitle-1.3.2 simpletransformers-0.63.11 smmap-5.0.0 streamlit-1.24.0 tensorboardX-2.6.1 tokenizers-0.13.3 transformers-4.30.2 tzdata-2023.3 tzlocal-4.3.1 validators-0.20.0 wandb-0.15.5 watchdog-3.0.0 xxhash-3.2.0

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2022 NVIDIA Corporation
# Built on Wed_Sep_21_10:33:58_PDT_2022
# Cuda compilation tools, release 11.8, V11.8.89
# Build cuda_11.8.r11.8/compiler.31833905_0

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from sklearn.metrics import classification_report, confusion_matrix

# Create a custom dataset class for handling the data
class CustomDataset(Dataset):
    def __init__(self, texts, labels, tokenizer, max_length):
        self.texts = texts
        self.labels = labels
        self.tokenizer = tokenizer
        self.max_length = max_length

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        text = str(self.texts.iloc[idx])  # Convert to string in case of numeric data
        label = self.labels.iloc[idx]
        encoding = self.tokenizer.encode_plus(
            text,
            add_special_tokens=True,
            max_length=self.max_length,
            padding='max_length',
            truncation=True,
            return_tensors='pt'
        )
        input_ids = encoding['input_ids'].squeeze()
        attention_mask = encoding['attention_mask'].squeeze()
        return input_ids, attention_mask, label

# Load indicBERT tokenizer and model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
tokenizer = AutoTokenizer.from_pretrained('xlm-roberta-base')
model = AutoModelForSequenceClassification.from_pretrained('xlm-roberta-base', num_labels=6)

# Add dropout layer to the model
dropout_prob = 0.1
model.config.attention_probs_dropout_prob = dropout_prob
model.config.hidden_dropout_prob = dropout_prob
model.to(device)

# Create data loaders for training, validation, and testing
max_length = 40
train_dataset = CustomDataset(train_data['cleantext'], train_data['final_label'], tokenizer, max_length)
val_dataset = CustomDataset(val_data['cleantext'], val_data['final_label'], tokenizer, max_length)
test_dataset = CustomDataset(test_data['cleantext'], test_data['final_label'], tokenizer, max_length)

batch_size = 32
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# Define training and evaluation functions and train the model
num_epochs = 20
early_stopping_patience = 5
best_model_path = 'best_model.pt'
best_val_loss = float('inf')
current_patience = 0

optimizer = torch.optim.AdamW(model.parameters(), lr=2e-5, weight_decay=0.01)
criterion = torch.nn.CrossEntropyLoss()

for epoch in range(num_epochs):
    model.train()
    train_loss = 0.0
    train_correct = 0

    for input_ids, attention_mask, labels in train_loader:
        input_ids = input_ids.to(device)
        attention_mask = attention_mask.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()
        outputs = model(input_ids, attention_mask=attention_mask, labels=labels)
        loss = outputs.loss
        logits = outputs.logits
        _, predicted = torch.max(logits, 1)

        loss.backward()
        optimizer.step()

        train_loss += loss.item() * input_ids.size(0)
        train_correct += (predicted == labels).sum().item()

    # Calculate average training loss and accuracy for the epoch
    train_loss /= len(train_dataset)
    train_accuracy = train_correct / len(train_dataset)

    # Evaluation on the validation set
    model.eval()
    val_loss = 0.0
    val_correct = 0

    with torch.no_grad():
        for input_ids, attention_mask, labels in val_loader:
            input_ids = input_ids.to(device)
            attention_mask = attention_mask.to(device)
            labels = labels.to(device)

            outputs = model(input_ids, attention_mask=attention_mask, labels=labels)
            loss = outputs.loss
            logits = outputs.logits
            _, predicted = torch.max(logits, 1)

            val_loss += loss.item() * input_ids.size(0)
            val_correct += (predicted == labels).sum().item()

    # Calculate average validation loss and accuracy for the epoch
    val_loss /= len(val_dataset)
    val_accuracy = val_correct / len(val_dataset)

    # Check for early stopping
    if val_loss < best_val_loss:
     best_val_loss = val_loss
     torch.save(model.state_dict(), best_model_path)
     current_patience = 0
    else:
      current_patience += 1
      if current_patience >= early_stopping_patience:
       print('Early stopping triggered.')
       break

    # Print the training and validation metrics for the epoch
    print(f'Epoch {epoch+1}/{num_epochs}:')
    print(f'Training Loss: {train_loss:.4f}, Training Accuracy: {train_accuracy:.4f}')
    print(f'Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_accuracy:.4f}')

# Load the best model
model.load_state_dict(torch.load(best_model_path))

# Evaluate the model on the test set
model.eval()
test_loss = 0.0
test_correct = 0
predicted_labels = []
true_labels = []

with torch.no_grad():
    for input_ids, attention_mask, labels in test_loader:
        input_ids = input_ids.to(device)
        attention_mask = attention_mask.to(device)
        labels = labels.to(device)

        outputs = model(input_ids, attention_mask=attention_mask, labels=labels)
        loss = outputs.loss
        logits = outputs.logits
        _, predicted = torch.max(logits, 1)

        test_loss += loss.item() * input_ids.size(0)
        test_correct += (predicted == labels).sum().item()

        predicted_labels.extend(predicted.tolist())
        true_labels.extend(labels.tolist())

# Calculate average test loss and accuracy
test_loss /= len(test_dataset)
test_accuracy = test_correct / len(test_dataset)

# Print the test metrics
print(f'Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}')

# Calculate precision, recall, F1 score, and confusion matrix
class_names = ['Physics', 'Chemistry', 'Biology', 'ICT', 'Mathematics', 'Others']
print(classification_report(true_labels, predicted_labels, target_names=class_names))
confusion = confusion_matrix(true_labels, predicted_labels)
confusion_df = pd.DataFrame(confusion, index=class_names, columns=class_names)
print("Confusion Matrix:")
print(confusion_df)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/615 [00:00<?, ?B/s]
# Downloading (…)tencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/9.10M [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/1.12G [00:00<?, ?B/s]
# Some weights of the model checkpoint at xlm-roberta-base were not used when initializing XLMRobertaForSequenceClassification: ['lm_head.dense.bias', 'roberta.pooler.dense.weight', 'roberta.pooler.dense.bias', 'lm_head.dense.weight', 'lm_head.layer_norm.bias', 'lm_head.layer_norm.weight', 'lm_head.bias']
# - This IS expected if you are initializing XLMRobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing XLMRobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of XLMRobertaForSequenceClassification were not initialized from the model checkpoint at xlm-roberta-base and are newly initialized: ['classifier.out_proj.bias', 'classifier.out_proj.weight', 'classifier.dense.bias', 'classifier.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch 1/20:
# Training Loss: 1.1904, Training Accuracy: 0.5505
# Validation Loss: 0.5994, Validation Accuracy: 0.7989
# Epoch 2/20:
# Training Loss: 0.5780, Training Accuracy: 0.8138
# Validation Loss: 0.5408, Validation Accuracy: 0.8233
# Epoch 3/20:
# Training Loss: 0.3802, Training Accuracy: 0.8807
# Validation Loss: 0.4378, Validation Accuracy: 0.8722
# Epoch 4/20:
# Training Loss: 0.2843, Training Accuracy: 0.9131
# Validation Loss: 0.3929, Validation Accuracy: 0.8856
# Epoch 5/20:
# Training Loss: 0.2310, Training Accuracy: 0.9262
# Validation Loss: 0.4028, Validation Accuracy: 0.8789
# Epoch 6/20:
# Training Loss: 0.1641, Training Accuracy: 0.9474
# Validation Loss: 0.4077, Validation Accuracy: 0.8911
# Epoch 7/20:
# Training Loss: 0.1312, Training Accuracy: 0.9548
# Validation Loss: 0.4117, Validation Accuracy: 0.8889
# Epoch 8/20:
# Training Loss: 0.1261, Training Accuracy: 0.9617
# Validation Loss: 0.4522, Validation Accuracy: 0.8911
# Epoch 9/20:
# Training Loss: 0.0876, Training Accuracy: 0.9712
# Validation Loss: 0.3863, Validation Accuracy: 0.9078
# Epoch 10/20:
# Training Loss: 0.0680, Training Accuracy: 0.9812
# Validation Loss: 0.4094, Validation Accuracy: 0.9000
# Epoch 11/20:
# Training Loss: 0.0462, Training Accuracy: 0.9836
# Validation Loss: 0.4169, Validation Accuracy: 0.9078
# Epoch 12/20:
# Training Loss: 0.0555, Training Accuracy: 0.9833
# Validation Loss: 0.3826, Validation Accuracy: 0.9067
# Epoch 13/20:
# Training Loss: 0.0548, Training Accuracy: 0.9821
# Validation Loss: 0.4336, Validation Accuracy: 0.9167
# Epoch 14/20:
# Training Loss: 0.0489, Training Accuracy: 0.9848
# Validation Loss: 0.3972, Validation Accuracy: 0.9044
# Epoch 15/20:
# Training Loss: 0.0519, Training Accuracy: 0.9848
# Validation Loss: 0.4526, Validation Accuracy: 0.9111
# Epoch 16/20:
# Training Loss: 0.0424, Training Accuracy: 0.9879
# Validation Loss: 0.4565, Validation Accuracy: 0.9067
# Early stopping triggered.
# Test Loss: 0.3733, Test Accuracy: 0.9111
#               precision    recall  f1-score   support
#
#      Physics       0.91      0.78      0.84       159
#    Chemistry       0.88      0.94      0.91       163
#      Biology       0.94      0.92      0.93       138
#          ICT       0.98      0.93      0.95       151
#  Mathematics       0.83      0.93      0.88       143
#       Others       0.95      0.97      0.96       146
#
#     accuracy                           0.91       900
#    macro avg       0.91      0.91      0.91       900
# weighted avg       0.91      0.91      0.91       900
#
# Confusion Matrix:
#              Physics  Chemistry  Biology  ICT  Mathematics  Others
# Physics          124         11        0    0           22       2
# Chemistry          4        154        4    1            0       0
# Biology            0          7      127    1            2       1
# ICT                0          3        2  140            2       4
# Mathematics        7          1        0    1          133       1
# Others             1          0        2    0            1     142

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Plot Confusion Matrix
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_df, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()
